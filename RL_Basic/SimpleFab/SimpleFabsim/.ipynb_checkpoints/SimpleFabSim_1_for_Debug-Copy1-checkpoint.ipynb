# %%
import pandas as pd
import numpy as np
import random
import time

# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import numpy as np
from IPython.display import HTML
import os

class BatchProcessingMachine:
    def __init__(self, processing_time, batch_size):
        self.processing_time = processing_time
        self.batch_size = batch_size
        self.batch = []
        self.finish_time = 0
        self.busy = False
        self.event_log = []

    def process(self, current_time):
        if len(self.batch) == self.batch_size:
            self.busy = True
            self.finish_time = current_time + self.processing_time
            processed_product = self.batch[0]
            self.event_log.append((processed_product, current_time, self.finish_time, self.batch_size))
            self.batch = []
            return processed_product
        return None

    def add_to_batch(self, product, current_time):
        if not self.busy:
            if self.batch and self.batch[0] != product:
                # If a different product is added, clear the existing batch and reset (this should not happen by design)
                self.batch.clear()
            self.batch.append(product)
            if len(self.batch) == self.batch_size:
                return self.process(current_time)
        return None

    def update(self, current_time):
        if current_time >= self.finish_time and self.busy:
            self.busy = False
            return True
        return False

    def print_event_log(self):
        for event in self.event_log:
            print(f"Batch of Product {event[0]} processed from {event[1]} to {event[2]}")


class Machine:
    def __init__(self, processing_times, setup_times):
        self.processing_times = processing_times
        self.setup_times = setup_times
        self.current_product = None
        self.finish_time = 0
        self.busy = False
        self.event_log = []

    def process(self, product, current_time):
        setup_time = self.setup_times[self.current_product][product] if self.current_product is not None else 0
        self.current_product = product
        start_time = current_time + setup_time
        self.finish_time = start_time + self.processing_times[product]
        self.busy = True
        self.event_log.append((product, start_time, self.finish_time))
        return self.finish_time

    def update(self, current_time):
        if current_time >= self.finish_time and self.busy:
            self.busy = False
            return self.current_product
        return None

    def print_event_log(self):
        for event in self.event_log:
            print(f"Product {event[0]} processed from {event[1]} to {event[2]}")


class ProductionLine:
    def __init__(self, batch_machine_time, machine1_times, machine1_setups, machine2_times, machine2_setups, arrival_rate1, arrival_rate2):
        self.machine0 = BatchProcessingMachine(batch_machine_time, 4)
        self.machine1 = Machine(machine1_times, machine1_setups)
        self.machine2 = Machine(machine2_times, machine2_setups)
        self.arrival_rate1 = arrival_rate1
        self.arrival_rate2 = arrival_rate2
        self.next_arrival1 = 0
        self.next_arrival2 = 0
        self.queue0 = []  # Queue for machine0
        self.queue = []  # Queue between machine0 and machine1
        self.buffer = []  # Buffer for machine2
        self.finished_products = [0, 0]
        self.queue_log = []
        self.buffer_log = []

    def add_item_to_queue0(self, product, current_time):
        self.queue0.append((product, current_time))
        self.log_queue0(current_time)

    def log_queue0(self, current_time):
        queue_size_0 = sum(1 for p, _ in self.queue0 if p == 0)
        queue_size_1 = sum(1 for p, _ in self.queue0 if p == 1)
        self.queue_log.append(((queue_size_0, queue_size_1), current_time))
    
    def process_batch_machine0(self, current_time):
        if not self.machine0.busy and len(self.queue0) >= 4:
            # Check if the first 4 items in the queue are of the same type
            first_product_type = self.queue0[0][0]
            if all(item[0] == first_product_type for item in self.queue0[:4]):
                print(f"Processing batch at time {current_time}: All items match type {first_product_type}")
                for _ in range(4):
                    product, _ = self.queue0.pop(0)
                    self.machine0.add_to_batch(product, current_time)

                # Trigger batch processing
                processed_product = self.machine0.process(current_time)
                if processed_product is not None:
                    self.queue.append(processed_product)
                    print(f"Batch processed: Product {processed_product}")
            else:
                print(f"Failed to process batch at time {current_time}: Items do not match")
        else:
            if self.machine0.busy:
                print(f"Machine0 is busy at time {current_time}")
            elif len(self.queue0) < 4:
                print(f"Not enough items to process at time {current_time}, only {len(self.queue0)} items available")


    def run_step(self, current_time):
        # Handle arrivals
        if current_time >= self.next_arrival1:
            self.add_item_to_queue0(0, current_time)
            self.next_arrival1 = current_time + self.arrival_rate1
        if current_time >= self.next_arrival2:
            self.add_item_to_queue0(1, current_time)
            self.next_arrival2 = current_time + self.arrival_rate2

        # Process batch in Machine 0
        self.process_batch_machine0(current_time)

        # Machine 1 processing
        if self.queue and not self.machine1.busy:
            next_product = self.queue.pop(0)
            self.machine1.process(next_product, current_time)

        # Update Machine 1 and handle buffer for Machine 2
        if self.machine1.update(current_time):
            finished_product = self.machine1.current_product
            if not self.machine2.busy:
                self.machine2.process(finished_product, current_time)
            else:
                self.buffer.append(finished_product)

        # Update Machine 2 and handle finished products
        if self.machine2.update(current_time):
            finished_product = self.machine2.current_product
            self.finished_products[finished_product] += 1

            # Process buffer if Machine 2 is available
            while self.buffer and not self.machine2.busy:
                next_product = self.buffer.pop(0)
                self.machine2.process(next_product, current_time)

        # Log buffer status
        self.log_buffer_status(current_time)


    def log_buffer_status(self, current_time):
        buffer_size_0 = sum(1 for p in self.buffer if p == 0)
        buffer_size_1 = sum(1 for p in self.buffer if p == 1)
        self.buffer_log.append(((buffer_size_0, buffer_size_1), current_time))

    def print_logs(self):
        print("Queue0 Event Log:")
        for log in self.queue_log:
            print(f"Time {log[1]}: Queue Sizes - Product 0: {log[0][0]}, Product 1: {log[0][1]}")

        print("\nMachine0 Batch Processing Log:")
        self.machine0.print_event_log()

        print("\nMachine1 Processing Log:")
        self.machine1.print_event_log()

        print("\nMachine2 Processing Log:")
        self.machine2.print_event_log()

        print("\nBuffer Status Log:")
        for log in self.buffer_log:
            print(f"Time {log[1]}: Buffer Sizes - Product 0: {log[0][0]}, Product 1: {log[0][1]}")

# Simulation setup
production_line = ProductionLine(10, {0: 3, 1: 4}, {None: {0: 5, 1: 3}, 0: {0: 0, 1: 10}, 1: {0: 5, 1: 0}},
                                 {0: 10, 1: 12}, {None: {0: 0, 1: 0}, 0: {0: 0, 1: 2}, 1: {0: 3, 1: 0}}, 20, 10)

# Run the production line for a specific period
for current_time in range(100):
    production_line.run_step(current_time)

# Print event logs of each machine and the buffer
production_line.print_logs()
# Out:
# Not enough items to process at time 0, only 2 items available
# Not enough items to process at time 1, only 2 items available
# Not enough items to process at time 2, only 2 items available
# Not enough items to process at time 3, only 2 items available
# Not enough items to process at time 4, only 2 items available
# Not enough items to process at time 5, only 2 items available
# Not enough items to process at time 6, only 2 items available
# Not enough items to process at time 7, only 2 items available
# Not enough items to process at time 8, only 2 items available
# Not enough items to process at time 9, only 2 items available
# Not enough items to process at time 10, only 3 items available
# Not enough items to process at time 11, only 3 items available
# Not enough items to process at time 12, only 3 items available
# Not enough items to process at time 13, only 3 items available
# Not enough items to process at time 14, only 3 items available
# Not enough items to process at time 15, only 3 items available
# Not enough items to process at time 16, only 3 items available
# Not enough items to process at time 17, only 3 items available
# Not enough items to process at time 18, only 3 items available
# Not enough items to process at time 19, only 3 items available
# Failed to process batch at time 20: Items do not match
# Failed to process batch at time 21: Items do not match
# Failed to process batch at time 22: Items do not match
# Failed to process batch at time 23: Items do not match
# Failed to process batch at time 24: Items do not match
# Failed to process batch at time 25: Items do not match
# Failed to process batch at time 26: Items do not match
# Failed to process batch at time 27: Items do not match
# Failed to process batch at time 28: Items do not match
# Failed to process batch at time 29: Items do not match
# Failed to process batch at time 30: Items do not match
# Failed to process batch at time 31: Items do not match
# Failed to process batch at time 32: Items do not match
# Failed to process batch at time 33: Items do not match
# Failed to process batch at time 34: Items do not match
# Failed to process batch at time 35: Items do not match
# Failed to process batch at time 36: Items do not match
# Failed to process batch at time 37: Items do not match
# Failed to process batch at time 38: Items do not match
# Failed to process batch at time 39: Items do not match
# Failed to process batch at time 40: Items do not match
# Failed to process batch at time 41: Items do not match
# Failed to process batch at time 42: Items do not match
# Failed to process batch at time 43: Items do not match
# Failed to process batch at time 44: Items do not match
# Failed to process batch at time 45: Items do not match
# Failed to process batch at time 46: Items do not match
# Failed to process batch at time 47: Items do not match
# Failed to process batch at time 48: Items do not match
# Failed to process batch at time 49: Items do not match
# Failed to process batch at time 50: Items do not match
# Failed to process batch at time 51: Items do not match
# Failed to process batch at time 52: Items do not match
# Failed to process batch at time 53: Items do not match
# Failed to process batch at time 54: Items do not match
# Failed to process batch at time 55: Items do not match
# Failed to process batch at time 56: Items do not match
# Failed to process batch at time 57: Items do not match
# Failed to process batch at time 58: Items do not match
# Failed to process batch at time 59: Items do not match
# Failed to process batch at time 60: Items do not match
# Failed to process batch at time 61: Items do not match
# Failed to process batch at time 62: Items do not match
# Failed to process batch at time 63: Items do not match
# Failed to process batch at time 64: Items do not match
# Failed to process batch at time 65: Items do not match
# Failed to process batch at time 66: Items do not match
# Failed to process batch at time 67: Items do not match
# Failed to process batch at time 68: Items do not match
# Failed to process batch at time 69: Items do not match
# Failed to process batch at time 70: Items do not match
# Failed to process batch at time 71: Items do not match
# Failed to process batch at time 72: Items do not match
# Failed to process batch at time 73: Items do not match
# Failed to process batch at time 74: Items do not match
# Failed to process batch at time 75: Items do not match
# Failed to process batch at time 76: Items do not match
# Failed to process batch at time 77: Items do not match
# Failed to process batch at time 78: Items do not match
# Failed to process batch at time 79: Items do not match
# Failed to process batch at time 80: Items do not match
# Failed to process batch at time 81: Items do not match
# Failed to process batch at time 82: Items do not match
# Failed to process batch at time 83: Items do not match
# Failed to process batch at time 84: Items do not match
# Failed to process batch at time 85: Items do not match
# Failed to process batch at time 86: Items do not match
# Failed to process batch at time 87: Items do not match
# Failed to process batch at time 88: Items do not match
# Failed to process batch at time 89: Items do not match
# Failed to process batch at time 90: Items do not match
# Failed to process batch at time 91: Items do not match
# Failed to process batch at time 92: Items do not match
# Failed to process batch at time 93: Items do not match
# Failed to process batch at time 94: Items do not match
# Failed to process batch at time 95: Items do not match
# Failed to process batch at time 96: Items do not match
# Failed to process batch at time 97: Items do not match
# Failed to process batch at time 98: Items do not match
# Failed to process batch at time 99: Items do not match
# Queue0 Event Log:
# Time 0: Queue Sizes - Product 0: 1, Product 1: 0
# Time 0: Queue Sizes - Product 0: 1, Product 1: 1
# Time 10: Queue Sizes - Product 0: 1, Product 1: 2
# Time 20: Queue Sizes - Product 0: 2, Product 1: 2
# Time 20: Queue Sizes - Product 0: 2, Product 1: 3
# Time 30: Queue Sizes - Product 0: 2, Product 1: 4
# Time 40: Queue Sizes - Product 0: 3, Product 1: 4
# Time 40: Queue Sizes - Product 0: 3, Product 1: 5
# Time 50: Queue Sizes - Product 0: 3, Product 1: 6
# Time 60: Queue Sizes - Product 0: 4, Product 1: 6
# Time 60: Queue Sizes - Product 0: 4, Product 1: 7
# Time 70: Queue Sizes - Product 0: 4, Product 1: 8
# Time 80: Queue Sizes - Product 0: 5, Product 1: 8
# Time 80: Queue Sizes - Product 0: 5, Product 1: 9
# Time 90: Queue Sizes - Product 0: 5, Product 1: 10
#
# Machine0 Batch Processing Log:
#
# Machine1 Processing Log:
#
# Machine2 Processing Log:
#
# Buffer Status Log:
# Time 0: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 1: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 2: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 3: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 4: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 5: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 6: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 7: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 8: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 9: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 10: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 11: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 12: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 13: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 14: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 15: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 16: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 17: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 18: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 19: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 20: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 21: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 22: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 23: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 24: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 25: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 26: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 27: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 28: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 29: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 30: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 31: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 32: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 33: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 34: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 35: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 36: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 37: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 38: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 39: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 40: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 41: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 42: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 43: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 44: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 45: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 46: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 47: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 48: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 49: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 50: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 51: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 52: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 53: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 54: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 55: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 56: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 57: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 58: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 59: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 60: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 61: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 62: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 63: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 64: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 65: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 66: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 67: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 68: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 69: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 70: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 71: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 72: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 73: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 74: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 75: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 76: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 77: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 78: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 79: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 80: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 81: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 82: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 83: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 84: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 85: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 86: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 87: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 88: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 89: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 90: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 91: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 92: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 93: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 94: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 95: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 96: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 97: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 98: Buffer Sizes - Product 0: 0, Product 1: 0
# Time 99: Buffer Sizes - Product 0: 0, Product 1: 0

# %%
#Next steps
# 1) Introduce a demand forecast into the state space and reward it for meeting future excess demand
# 2) See if it can switch demand patterns quickly 
# 3) Q-learning implementaion to achive the same result
# 4) Write a LP program of this
