# %%
import random
import pandas as pd

# Map product names to identifiers
product_id_mapping = {'Product 1': 0, 'Product 2': 1}

def generate_events_fixed(quantity, interval, time_period, product_id, event_type):
    """Generate events at fixed intervals with a fixed quantity over a specified time period."""
    num_events = time_period // interval
    times = [i * interval for i in range(num_events)]
    quantities = [quantity] * num_events
    return pd.DataFrame({'Time': times, 'Quantity': quantities, 'Product': product_id, 'Type': event_type})

def generate_events_random(num_events, time_period, max_quantity, product_id, event_type):
    """Generate random events over a specified time period."""
    times = sorted([random.randint(0, time_period) for _ in range(num_events)])
    quantities = [random.randint(1, max_quantity) for _ in range(num_events)]
    return pd.DataFrame({'Time': times, 'Quantity': quantities, 'Product': product_id, 'Type': event_type})

def simulate_events(time_period, product_settings):
    arrivals = []
    demands = []
    for config_name, settings in product_settings.items():
        # Extract the product name (excluding the event type) and map it to its numeric identifier
        product_name = ' '.join(config_name.split()[:-1])
        product_id = product_id_mapping[product_name]
        
        # Generate either fixed or random events for each product
        if settings['interval_type'] == 'fixed':
            df = generate_events_fixed(settings['quantity'], settings['interval'], time_period, product_id, settings['event_type'])
        else:  # Random generation
            num_events = random.randint(10, 20)
            df = generate_events_random(num_events, time_period, settings['max_quantity'], product_id, settings['event_type'])
        
        if settings['event_type'] == 'Arrival':
            arrivals.append(df)
        else:
            demands.append(df)
    
    # Combine all events into separate DataFrames for arrivals and demands, and sort by time
    arrivals_df = pd.concat(arrivals).sort_values('Time').reset_index(drop=True) if arrivals else pd.DataFrame()
    demands_df = pd.concat(demands).sort_values('Time').reset_index(drop=True) if demands else pd.DataFrame()
    return arrivals_df, demands_df

# Set the simulation time period
time_period = 150

# Configuration for each product and event type
product_settings = {
    'Product 1 Arrival': {'event_type': 'Arrival', 'interval_type': 'fixed', 'quantity': 1,'interval': 1},
    'Product 2 Arrival': {'event_type': 'Arrival', 'interval_type': 'fixed', 'quantity': 1, 'interval': 3},
    'Product 1 Demand': {'event_type': 'Demand', 'interval_type': 'fixed', 'quantity': 1, 'interval': 2},
    'Product 2 Demand': {'event_type': 'Demand', 'interval_type': 'fixed', 'quantity': 1, 'interval': 6},
}

# Simulate events for Arrivals and Demands
arrivals_df, demands_df = simulate_events(time_period, product_settings)

# Display the events for Arrivals and Demands
print("Arrivals:")
print(arrivals_df)
print("\nDemands:")
print(demands_df)

#'Product 2 Arrival': {'event_type': 'Arrival', 'interval_type': 'random', 'max_quantity': 5},
# Out:
# Arrivals:
#      Time  Quantity  Product     Type
# 0       0         1        0  Arrival
# 1       0         1        1  Arrival
# 2       1         1        0  Arrival
# 3       2         1        0  Arrival
# 4       3         1        1  Arrival
# ..    ...       ...      ...      ...
# 195   146         1        0  Arrival
# 196   147         1        1  Arrival
# 197   147         1        0  Arrival
# 198   148         1        0  Arrival
# 199   149         1        0  Arrival
#
# [200 rows x 4 columns]
#
# Demands:
#     Time  Quantity  Product    Type
# 0      0         1        0  Demand
# 1      0         1        1  Demand
# 2      2         1        0  Demand
# 3      4         1        0  Demand
# 4      6         1        1  Demand
# ..   ...       ...      ...     ...
# 95   142         1        0  Demand
# 96   144         1        0  Demand
# 97   144         1        1  Demand
# 98   146         1        0  Demand
# 99   148         1        0  Demand
#
# [100 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import numpy as np
from IPython.display import HTML
import os
import matplotlib.pyplot as plt
import plotly.express as px

# %%
class BatchProcessingMachine:
    def __init__(self, processing_times, batch_size):
        self.processing_times = processing_times
        self.batch_size = batch_size
        self.current_product = None
        self.finish_time = 0
        self.busy = False
        self.event_log = []

    def process(self, product, current_time):
        self.busy = True
        self.finish_time = current_time + self.processing_times[product]
        self.current_product = product
        self.event_log.append((self.current_product, current_time, self.finish_time, self.batch_size))
        return self.finish_time

    def update(self, current_time):
        if current_time >= self.finish_time and self.busy:
            self.busy = False
            return self.current_product
        return False
    
    def print_event_log(self, machine_name):
        for event in self.event_log:
            print(f"At machine {machine_name}: Batch of Product {event[0]} processed from {event[1]} to {event[2]}")

# %%
class Machine:
    def __init__(self, processing_times, setup_times):
        self.processing_times = processing_times
        self.setup_times = setup_times
        self.current_product = None
        self.finish_time = 0
        self.busy = False
        self.event_log = []

    def process(self, product, current_time):
        if self.current_product is not None:
            setup_time = self.setup_times[self.current_product][product]
        else:
            setup_time = self.setup_times[None][product]  # Use the setup time from 'None' to the new product
        self.current_product = product
        start_time = current_time + setup_time
        self.finish_time = start_time + self.processing_times[product]
        self.busy = True
        self.event_log.append((product, current_time, start_time, self.finish_time))
        return self.finish_time

    def update(self, current_time):
        if current_time >= self.finish_time and self.busy:
            self.busy = False
            return self.current_product
        return None

    def print_event_log(self, machine_name):
        for event in self.event_log:
            print(f"At machine {machine_name}: Product {event[0]} processed from {event[1]} to {event[3]}")

# %%
import os
class ProductionLine:
    def __init__(self, batch_machine0_times, machine1_times, machine1_setups, batch_machine2_times, machine3_times, machine3_setups, 
                 arrivals_df,demands_df):
        self.machine0 = BatchProcessingMachine(batch_machine0_times, 4)
        self.machine1 = Machine(machine1_times, machine1_setups)
        self.machine2 = BatchProcessingMachine(batch_machine2_times, 4)
        self.machine3 = Machine(machine3_times, machine3_setups)
        self.arrivals_df = arrivals_df
        self.demands_df = demands_df
        self.queues = {'queue0': [[], []], 'queue1': [[], []], 'queue2': [[], []], 'queue3': [[], []],'queue_fin': [[], []],'demand': [[], []]}
        self.logs = {key: [] for key in self.queues}  # Initialize logs for each queue
        self.demand_met_log = []
        self.event_log = []  # Log for capturing all event details

    def add_item_to_queue(self, queue_name, product_name, current_time):
        if queue_name == 'queue_fin':
            # Check if there is demand for this product
            if len(self.queues['demand'][product_name]) > 0:
                self.queues['demand'][product_name].pop(0)  # Remove one demand unit
                self.demand_met_log.append((product_name, current_time))  # Log the demand fulfillment
                queue_sizes = [len(q) for q in self.queues['demand']]
                self.logs['demand'].append((queue_sizes, current_time))
                self.log_current_state(current_time)
                return  # Demand fulfilled, no need to add to queue_fin        
        self.queues[queue_name][product_name].append(current_time)
        queue_sizes = [len(q) for q in self.queues[queue_name]]
        self.logs[queue_name].append((queue_sizes, current_time))
        #self.log_current_state(current_time)

    def log_current_state(self, current_time):
        # Log queue sizes and current products in machines
        log_entry = {
            'Time': current_time,
            'Queue 0 Product 0': len(self.queues['queue0'][0]),
            'Queue 0 Product 1': len(self.queues['queue0'][1]),
            'Queue 1 Product 0': len(self.queues['queue1'][0]),
            'Queue 1 Product 1': len(self.queues['queue1'][1]),
            'Queue 2 Product 0': len(self.queues['queue2'][0]),
            'Queue 2 Product 1': len(self.queues['queue2'][1]),
            'Queue 3 Product 0': len(self.queues['queue3'][0]),
            'Queue 3 Product 1': len(self.queues['queue3'][1]),
            'Demand Queue Product 0': len(self.queues['demand'][0]),
            'Demand Queue Product 1': len(self.queues['demand'][1]),
            'Machine 1 Current Product': 'None' if self.machine1.current_product is None else self.machine1.current_product,
            'Machine 3 Current Product': 'None' if self.machine3.current_product is None else self.machine3.current_product
        }
        self.event_log.append(log_entry)


    def run_step(self, current_time):
        # Handle product arrivals from the DataFrame
        arrivals_this_step = self.arrivals_df[self.arrivals_df['Time'] == current_time]
        for _, row in arrivals_this_step.iterrows():
            self.add_item_to_queue('queue0', row['Product'], current_time)

        # Handle product demand from the DataFrame
        demand_this_step = self.demands_df[self.demands_df['Time'] == current_time]
        for _, row in demand_this_step.iterrows():
            self.add_item_to_queue('demand', row['Product'], current_time)
        
        # Process batches in Machine 0
        for product_type in range(2):
            # When current processing lot is completed
            if current_time >= self.machine0.finish_time and self.machine0.busy:
                finished_product = self.machine0.update(current_time)
                # Transfer the whole batch to the next queue
                for i in range(self.machine0.batch_size):
                    self.add_item_to_queue('queue1', finished_product, current_time)
            total_demand_length = len(self.queues['demand'][0]) + len(self.queues['demand'][1])
            queue_ratio = 0.5 if total_demand_length == 0 else len(self.queues['demand'][product_type]) / total_demand_length  
            #print(f'currenttime is:{current_time} and queue ratio is: {queue_ratio}')
            # Checking if new batch can be started on the machine
            while len(self.queues['queue0'][product_type]) >= self.machine0.batch_size and not self.machine0.busy and queue_ratio >= 0.5:
                temp = len(self.queues['demand'][product_type])
                #print(f'I have entered the loop at time{current_time} machine 0 to produce {product_type} as queue ratio is {queue_ratio}, total demand is {total_demand_length} and length of product quueue is {temp}')
                # Batch is full and machine is not busy
                finish_time = self.machine0.process(product_type,current_time)  # Process batch
                self.queues['queue0'][product_type] = self.queues['queue0'][product_type][self.machine0.batch_size:]
                #logging
                queue_sizes = [len(q) for q in self.queues['queue0']]
                self.logs['queue0'].append((queue_sizes, current_time))
                #self.log_current_state(current_time)

        # Process products at Machine 1
        for product_type in range(2):
            # When current processing lot is completed
            if current_time >= self.machine1.finish_time and self.machine1.busy:
                finished_product1 = self.machine1.update(current_time)
                if finished_product1 is not None:  # Move to next queue if not the last machine
                    self.add_item_to_queue('queue2', finished_product1, current_time)
            total_demand_length = len(self.queues['demand'][0]) + len(self.queues['demand'][1])
            queue_ratio = 0.5 if total_demand_length == 0 else len(self.queues['demand'][product_type]) / total_demand_length  
            # Checking if new product can be started on the machine
            if self.queues['queue1'][product_type] and not self.machine1.busy and queue_ratio >= 0.5:
                product_time = self.queues['queue1'][product_type].pop(0)
                self.machine1.process(product_type, current_time)
                #logging
                queue_sizes = [len(q) for q in self.queues['queue1']]
                self.logs['queue1'].append((queue_sizes, current_time))
                #self.log_current_state(current_time)

        # Process batches in Machine 2
        for product_type in range(2):
            # When current processing lot is completed
            if current_time >= self.machine2.finish_time and self.machine2.busy:
                finished_product2 = self.machine2.update(current_time)
                # Transfer the whole batch to the next queue
                for i in range(self.machine2.batch_size):
                    self.add_item_to_queue('queue3', finished_product2, current_time)
            total_demand_length = len(self.queues['demand'][0]) + len(self.queues['demand'][1])
            queue_ratio = 0.5 if total_demand_length == 0 else len(self.queues['demand'][product_type]) / total_demand_length  
            # Checking if new batch can be started on the machine
            while len(self.queues['queue2'][product_type]) >= self.machine2.batch_size and not self.machine2.busy and queue_ratio >= 0.5:
                # Batch is full and machine is not busy
                finish_time = self.machine2.process(product_type,current_time)  # Process batch
                self.queues['queue2'][product_type] = self.queues['queue2'][product_type][self.machine2.batch_size:]
                #logging
                queue_sizes = [len(q) for q in self.queues['queue2']]
                self.logs['queue2'].append((queue_sizes, current_time))
                #self.log_current_state(current_time)        
        
        # Process products at Machine 3
        for product_type in range(2):
            # When current processing lot is completed
            if current_time >= self.machine3.finish_time and self.machine3.busy:
                finished_product3 = self.machine3.update(current_time)
                if finished_product3 is not None:  # Move to next queue if not the last machine
                    self.add_item_to_queue('queue_fin', finished_product3, current_time)
            total_demand_length = len(self.queues['demand'][0]) + len(self.queues['demand'][1])
            queue_ratio = 0.5 if total_demand_length == 0 else len(self.queues['demand'][product_type]) / total_demand_length          
            # Checking if new product can be started on the machine
            if self.queues['queue3'][product_type] and not self.machine3.busy and queue_ratio >= 0.5:
                product_time = self.queues['queue3'][product_type].pop(0)
                self.machine3.process(product_type, current_time)
                #logging
                queue_sizes = [len(q) for q in self.queues['queue3']]
                self.logs['queue3'].append((queue_sizes, current_time))
                #self.log_current_state(current_time)

        self.log_current_state(current_time)

    def print_demand_met_log(self):
        print("Demand Met Log:")
        for log in self.demand_met_log:
            print(f"Time {log[1]}: Demand for Product {log[0]} met")
    
    def print_logs(self):
        # Printing logs for all queues
        for key in self.queues:
            print(f"{key} Event Log:")
            for log in self.logs[key]:
                print(f"Time {log[1]}: Queue Sizes - Product 0: {log[0][0]}, Product 1: {log[0][1]}")

        # Print machine logs
        print("\nMachine Logs:")
        machine_names = ['Machine 0', 'Machine 1', 'Machine 2', 'Machine 3']
        for i in range(4):
            machine = getattr(self, f'machine{i}')
            machine.print_event_log(machine_names[i])

        self.print_demand_met_log()  # Print the demand met logs

# Example simulation setup
production_line = ProductionLine({0: 240, 1:300}, {0: 30, 1: 30}, {None: {0: 15, 1: 15}, 0: {0: 0, 1: 15}, 1: {0: 15, 1: 0}},
                                {0: 240, 1:300}, {0: 30, 1: 30}, {None: {0: 15, 1: 15}, 0: {0: 0, 1: 15}, 1: {0: 15, 1: 0}}, arrivals_df,demands_df)

for current_time in range(20000):
    production_line.run_step(current_time)
production_line.print_logs()
print(production_line.queues)

# After the simulation, create a DataFrame from the logs
event_log_df = pd.DataFrame(production_line.event_log)
#print(event_log_df)

# Get the current directory where your Python script is located
current_directory = os.getcwd()

# Define the new folder name and path
new_folder = "output_data"
new_folder_path = os.path.join(current_directory, new_folder)

# Create the new folder if it doesn't exist
if not os.path.exists(new_folder_path):
    os.makedirs(new_folder_path)

# Define the filename and complete path
file_name = "final_event_log_Exp2.csv"
file_path = os.path.join(new_folder_path, file_name)

event_log_df.to_csv(file_path, index=False)
# Out:
# queue0 Event Log:
# Time 0: Queue Sizes - Product 0: 1, Product 1: 0
# Time 0: Queue Sizes - Product 0: 1, Product 1: 1
# Time 1: Queue Sizes - Product 0: 2, Product 1: 1
# Time 2: Queue Sizes - Product 0: 3, Product 1: 1
# Time 3: Queue Sizes - Product 0: 3, Product 1: 2
# Time 3: Queue Sizes - Product 0: 4, Product 1: 2
# Time 3: Queue Sizes - Product 0: 0, Product 1: 2
# Time 4: Queue Sizes - Product 0: 1, Product 1: 2
# Time 5: Queue Sizes - Product 0: 2, Product 1: 2
# Time 6: Queue Sizes - Product 0: 3, Product 1: 2
# Time 6: Queue Sizes - Product 0: 3, Product 1: 3
# Time 7: Queue Sizes - Product 0: 4, Product 1: 3
# Time 8: Queue Sizes - Product 0: 5, Product 1: 3
# Time 9: Queue Sizes - Product 0: 6, Product 1: 3
# Time 9: Queue Sizes - Product 0: 6, Product 1: 4
# Time 10: Queue Sizes - Product 0: 7, Product 1: 4
# Time 11: Queue Sizes - Product 0: 8, Product 1: 4
# Time 12: Queue Sizes - Product 0: 9, Product 1: 4
# Time 12: Queue Sizes - Product 0: 9, Product 1: 5
# Time 13: Queue Sizes - Product 0: 10, Product 1: 5
# Time 14: Queue Sizes - Product 0: 11, Product 1: 5
# Time 15: Queue Sizes - Product 0: 12, Product 1: 5
# Time 15: Queue Sizes - Product 0: 12, Product 1: 6
# Time 16: Queue Sizes - Product 0: 13, Product 1: 6
# Time 17: Queue Sizes - Product 0: 14, Product 1: 6
# Time 18: Queue Sizes - Product 0: 14, Product 1: 7
# Time 18: Queue Sizes - Product 0: 15, Product 1: 7
# Time 19: Queue Sizes - Product 0: 16, Product 1: 7
# Time 20: Queue Sizes - Product 0: 17, Product 1: 7
# Time 21: Queue Sizes - Product 0: 18, Product 1: 7
# Time 21: Queue Sizes - Product 0: 18, Product 1: 8
# Time 22: Queue Sizes - Product 0: 19, Product 1: 8
# Time 23: Queue Sizes - Product 0: 20, Product 1: 8
# Time 24: Queue Sizes - Product 0: 21, Product 1: 8
# Time 24: Queue Sizes - Product 0: 21, Product 1: 9
# Time 25: Queue Sizes - Product 0: 22, Product 1: 9
# Time 26: Queue Sizes - Product 0: 23, Product 1: 9
# Time 27: Queue Sizes - Product 0: 24, Product 1: 9
# Time 27: Queue Sizes - Product 0: 24, Product 1: 10
# Time 28: Queue Sizes - Product 0: 25, Product 1: 10
# Time 29: Queue Sizes - Product 0: 26, Product 1: 10
# Time 30: Queue Sizes - Product 0: 27, Product 1: 10
# Time 30: Queue Sizes - Product 0: 27, Product 1: 11
# Time 31: Queue Sizes - Product 0: 28, Product 1: 11
# Time 32: Queue Sizes - Product 0: 29, Product 1: 11
# Time 33: Queue Sizes - Product 0: 30, Product 1: 11
# Time 33: Queue Sizes - Product 0: 30, Product 1: 12
# Time 34: Queue Sizes - Product 0: 31, Product 1: 12
# Time 35: Queue Sizes - Product 0: 32, Product 1: 12
# Time 36: Queue Sizes - Product 0: 32, Product 1: 13
# Time 36: Queue Sizes - Product 0: 33, Product 1: 13
# Time 37: Queue Sizes - Product 0: 34, Product 1: 13
# Time 38: Queue Sizes - Product 0: 35, Product 1: 13
# Time 39: Queue Sizes - Product 0: 35, Product 1: 14
# Time 39: Queue Sizes - Product 0: 36, Product 1: 14
# Time 40: Queue Sizes - Product 0: 37, Product 1: 14
# Time 41: Queue Sizes - Product 0: 38, Product 1: 14
# Time 42: Queue Sizes - Product 0: 38, Product 1: 15
# Time 42: Queue Sizes - Product 0: 39, Product 1: 15
# Time 43: Queue Sizes - Product 0: 40, Product 1: 15
# Time 44: Queue Sizes - Product 0: 41, Product 1: 15
# Time 45: Queue Sizes - Product 0: 41, Product 1: 16
# Time 45: Queue Sizes - Product 0: 42, Product 1: 16
# Time 46: Queue Sizes - Product 0: 43, Product 1: 16
# Time 47: Queue Sizes - Product 0: 44, Product 1: 16
# Time 48: Queue Sizes - Product 0: 44, Product 1: 17
# Time 48: Queue Sizes - Product 0: 45, Product 1: 17
# Time 49: Queue Sizes - Product 0: 46, Product 1: 17
# Time 50: Queue Sizes - Product 0: 47, Product 1: 17
# Time 51: Queue Sizes - Product 0: 47, Product 1: 18
# Time 51: Queue Sizes - Product 0: 48, Product 1: 18
# Time 52: Queue Sizes - Product 0: 49, Product 1: 18
# Time 53: Queue Sizes - Product 0: 50, Product 1: 18
# Time 54: Queue Sizes - Product 0: 50, Product 1: 19
# Time 54: Queue Sizes - Product 0: 51, Product 1: 19
# Time 55: Queue Sizes - Product 0: 52, Product 1: 19
# Time 56: Queue Sizes - Product 0: 53, Product 1: 19
# Time 57: Queue Sizes - Product 0: 53, Product 1: 20
# Time 57: Queue Sizes - Product 0: 54, Product 1: 20
# Time 58: Queue Sizes - Product 0: 55, Product 1: 20
# Time 59: Queue Sizes - Product 0: 56, Product 1: 20
# Time 60: Queue Sizes - Product 0: 57, Product 1: 20
# Time 60: Queue Sizes - Product 0: 57, Product 1: 21
# Time 61: Queue Sizes - Product 0: 58, Product 1: 21
# Time 62: Queue Sizes - Product 0: 59, Product 1: 21
# Time 63: Queue Sizes - Product 0: 60, Product 1: 21
# Time 63: Queue Sizes - Product 0: 60, Product 1: 22
# Time 64: Queue Sizes - Product 0: 61, Product 1: 22
# Time 65: Queue Sizes - Product 0: 62, Product 1: 22
# Time 66: Queue Sizes - Product 0: 62, Product 1: 23
# Time 66: Queue Sizes - Product 0: 63, Product 1: 23
# Time 67: Queue Sizes - Product 0: 64, Product 1: 23
# Time 68: Queue Sizes - Product 0: 65, Product 1: 23
# Time 69: Queue Sizes - Product 0: 66, Product 1: 23
# Time 69: Queue Sizes - Product 0: 66, Product 1: 24
# Time 70: Queue Sizes - Product 0: 67, Product 1: 24
# Time 71: Queue Sizes - Product 0: 68, Product 1: 24
# Time 72: Queue Sizes - Product 0: 69, Product 1: 24
# Time 72: Queue Sizes - Product 0: 69, Product 1: 25
# Time 73: Queue Sizes - Product 0: 70, Product 1: 25
# Time 74: Queue Sizes - Product 0: 71, Product 1: 25
# Time 75: Queue Sizes - Product 0: 72, Product 1: 25
# Time 75: Queue Sizes - Product 0: 72, Product 1: 26
# Time 76: Queue Sizes - Product 0: 73, Product 1: 26
# Time 77: Queue Sizes - Product 0: 74, Product 1: 26
# Time 78: Queue Sizes - Product 0: 75, Product 1: 26
# Time 78: Queue Sizes - Product 0: 75, Product 1: 27
# Time 79: Queue Sizes - Product 0: 76, Product 1: 27
# Time 80: Queue Sizes - Product 0: 77, Product 1: 27
# Time 81: Queue Sizes - Product 0: 78, Product 1: 27
# Time 81: Queue Sizes - Product 0: 78, Product 1: 28
# Time 82: Queue Sizes - Product 0: 79, Product 1: 28
# Time 83: Queue Sizes - Product 0: 80, Product 1: 28
# Time 84: Queue Sizes - Product 0: 80, Product 1: 29
# Time 84: Queue Sizes - Product 0: 81, Product 1: 29
# Time 85: Queue Sizes - Product 0: 82, Product 1: 29
# Time 86: Queue Sizes - Product 0: 83, Product 1: 29
# Time 87: Queue Sizes - Product 0: 84, Product 1: 29
# Time 87: Queue Sizes - Product 0: 84, Product 1: 30
# Time 88: Queue Sizes - Product 0: 85, Product 1: 30
# Time 89: Queue Sizes - Product 0: 86, Product 1: 30
# Time 90: Queue Sizes - Product 0: 86, Product 1: 31
# Time 90: Queue Sizes - Product 0: 87, Product 1: 31
# Time 91: Queue Sizes - Product 0: 88, Product 1: 31
# Time 92: Queue Sizes - Product 0: 89, Product 1: 31
# Time 93: Queue Sizes - Product 0: 89, Product 1: 32
# Time 93: Queue Sizes - Product 0: 90, Product 1: 32
# Time 94: Queue Sizes - Product 0: 91, Product 1: 32
# Time 95: Queue Sizes - Product 0: 92, Product 1: 32
# Time 96: Queue Sizes - Product 0: 92, Product 1: 33
# Time 96: Queue Sizes - Product 0: 93, Product 1: 33
# Time 97: Queue Sizes - Product 0: 94, Product 1: 33
# Time 98: Queue Sizes - Product 0: 95, Product 1: 33
# Time 99: Queue Sizes - Product 0: 95, Product 1: 34
# Time 99: Queue Sizes - Product 0: 96, Product 1: 34
# Time 100: Queue Sizes - Product 0: 97, Product 1: 34
# Time 101: Queue Sizes - Product 0: 98, Product 1: 34
# Time 102: Queue Sizes - Product 0: 99, Product 1: 34
# Time 102: Queue Sizes - Product 0: 99, Product 1: 35
# Time 103: Queue Sizes - Product 0: 100, Product 1: 35
# Time 104: Queue Sizes - Product 0: 101, Product 1: 35
# Time 105: Queue Sizes - Product 0: 101, Product 1: 36
# Time 105: Queue Sizes - Product 0: 102, Product 1: 36
# Time 106: Queue Sizes - Product 0: 103, Product 1: 36
# Time 107: Queue Sizes - Product 0: 104, Product 1: 36
# Time 108: Queue Sizes - Product 0: 104, Product 1: 37
# Time 108: Queue Sizes - Product 0: 105, Product 1: 37
# Time 109: Queue Sizes - Product 0: 106, Product 1: 37
# Time 110: Queue Sizes - Product 0: 107, Product 1: 37
# Time 111: Queue Sizes - Product 0: 107, Product 1: 38
# Time 111: Queue Sizes - Product 0: 108, Product 1: 38
# Time 112: Queue Sizes - Product 0: 109, Product 1: 38
# Time 113: Queue Sizes - Product 0: 110, Product 1: 38
# Time 114: Queue Sizes - Product 0: 110, Product 1: 39
# Time 114: Queue Sizes - Product 0: 111, Product 1: 39
# Time 115: Queue Sizes - Product 0: 112, Product 1: 39
# Time 116: Queue Sizes - Product 0: 113, Product 1: 39
# Time 117: Queue Sizes - Product 0: 114, Product 1: 39
# Time 117: Queue Sizes - Product 0: 114, Product 1: 40
# Time 118: Queue Sizes - Product 0: 115, Product 1: 40
# Time 119: Queue Sizes - Product 0: 116, Product 1: 40
# Time 120: Queue Sizes - Product 0: 117, Product 1: 40
# Time 120: Queue Sizes - Product 0: 117, Product 1: 41
# Time 121: Queue Sizes - Product 0: 118, Product 1: 41
# Time 122: Queue Sizes - Product 0: 119, Product 1: 41
# Time 123: Queue Sizes - Product 0: 120, Product 1: 41
# Time 123: Queue Sizes - Product 0: 120, Product 1: 42
# Time 124: Queue Sizes - Product 0: 121, Product 1: 42
# Time 125: Queue Sizes - Product 0: 122, Product 1: 42
# Time 126: Queue Sizes - Product 0: 123, Product 1: 42
# Time 126: Queue Sizes - Product 0: 123, Product 1: 43
# Time 127: Queue Sizes - Product 0: 124, Product 1: 43
# Time 128: Queue Sizes - Product 0: 125, Product 1: 43
# Time 129: Queue Sizes - Product 0: 125, Product 1: 44
# Time 129: Queue Sizes - Product 0: 126, Product 1: 44
# Time 130: Queue Sizes - Product 0: 127, Product 1: 44
# Time 131: Queue Sizes - Product 0: 128, Product 1: 44
# Time 132: Queue Sizes - Product 0: 128, Product 1: 45
# Time 132: Queue Sizes - Product 0: 129, Product 1: 45
# Time 133: Queue Sizes - Product 0: 130, Product 1: 45
# Time 134: Queue Sizes - Product 0: 131, Product 1: 45
# Time 135: Queue Sizes - Product 0: 132, Product 1: 45
# Time 135: Queue Sizes - Product 0: 132, Product 1: 46
# Time 136: Queue Sizes - Product 0: 133, Product 1: 46
# Time 137: Queue Sizes - Product 0: 134, Product 1: 46
# Time 138: Queue Sizes - Product 0: 134, Product 1: 47
# Time 138: Queue Sizes - Product 0: 135, Product 1: 47
# Time 139: Queue Sizes - Product 0: 136, Product 1: 47
# Time 140: Queue Sizes - Product 0: 137, Product 1: 47
# Time 141: Queue Sizes - Product 0: 137, Product 1: 48
# Time 141: Queue Sizes - Product 0: 138, Product 1: 48
# Time 142: Queue Sizes - Product 0: 139, Product 1: 48
# Time 143: Queue Sizes - Product 0: 140, Product 1: 48
# Time 144: Queue Sizes - Product 0: 140, Product 1: 49
# Time 144: Queue Sizes - Product 0: 141, Product 1: 49
# Time 145: Queue Sizes - Product 0: 142, Product 1: 49
# Time 146: Queue Sizes - Product 0: 143, Product 1: 49
# Time 147: Queue Sizes - Product 0: 143, Product 1: 50
# Time 147: Queue Sizes - Product 0: 144, Product 1: 50
# Time 148: Queue Sizes - Product 0: 145, Product 1: 50
# Time 149: Queue Sizes - Product 0: 146, Product 1: 50
# Time 243: Queue Sizes - Product 0: 142, Product 1: 50
# Time 483: Queue Sizes - Product 0: 138, Product 1: 50
# Time 723: Queue Sizes - Product 0: 134, Product 1: 50
# Time 963: Queue Sizes - Product 0: 130, Product 1: 50
# Time 1203: Queue Sizes - Product 0: 126, Product 1: 50
# Time 1443: Queue Sizes - Product 0: 122, Product 1: 50
# Time 1683: Queue Sizes - Product 0: 118, Product 1: 50
# Time 1923: Queue Sizes - Product 0: 114, Product 1: 50
# Time 2163: Queue Sizes - Product 0: 110, Product 1: 50
# Time 2403: Queue Sizes - Product 0: 106, Product 1: 50
# Time 2643: Queue Sizes - Product 0: 102, Product 1: 50
# Time 2883: Queue Sizes - Product 0: 98, Product 1: 50
# Time 3123: Queue Sizes - Product 0: 94, Product 1: 50
# Time 3363: Queue Sizes - Product 0: 90, Product 1: 50
# Time 3603: Queue Sizes - Product 0: 90, Product 1: 46
# Time 3903: Queue Sizes - Product 0: 90, Product 1: 42
# Time 4203: Queue Sizes - Product 0: 90, Product 1: 38
# Time 4503: Queue Sizes - Product 0: 86, Product 1: 38
# Time 4743: Queue Sizes - Product 0: 86, Product 1: 34
# Time 5043: Queue Sizes - Product 0: 82, Product 1: 34
# Time 5283: Queue Sizes - Product 0: 82, Product 1: 30
# Time 5583: Queue Sizes - Product 0: 82, Product 1: 26
# Time 5883: Queue Sizes - Product 0: 78, Product 1: 26
# Time 6123: Queue Sizes - Product 0: 74, Product 1: 26
# Time 6363: Queue Sizes - Product 0: 74, Product 1: 22
# Time 6663: Queue Sizes - Product 0: 70, Product 1: 22
# Time 6903: Queue Sizes - Product 0: 66, Product 1: 22
# Time 7143: Queue Sizes - Product 0: 62, Product 1: 22
# Time 7383: Queue Sizes - Product 0: 62, Product 1: 18
# Time 7683: Queue Sizes - Product 0: 62, Product 1: 14
# Time 7983: Queue Sizes - Product 0: 58, Product 1: 14
# Time 8223: Queue Sizes - Product 0: 54, Product 1: 14
# Time 8463: Queue Sizes - Product 0: 50, Product 1: 14
# Time 8703: Queue Sizes - Product 0: 46, Product 1: 14
# Time 8943: Queue Sizes - Product 0: 42, Product 1: 14
# Time 9183: Queue Sizes - Product 0: 38, Product 1: 14
# Time 9423: Queue Sizes - Product 0: 34, Product 1: 14
# Time 9663: Queue Sizes - Product 0: 30, Product 1: 14
# Time 9903: Queue Sizes - Product 0: 26, Product 1: 14
# Time 10143: Queue Sizes - Product 0: 22, Product 1: 14
# Time 10383: Queue Sizes - Product 0: 18, Product 1: 14
# Time 10623: Queue Sizes - Product 0: 14, Product 1: 14
# Time 10863: Queue Sizes - Product 0: 10, Product 1: 14
# Time 11103: Queue Sizes - Product 0: 6, Product 1: 14
# Time 11343: Queue Sizes - Product 0: 2, Product 1: 14
# Time 11583: Queue Sizes - Product 0: 2, Product 1: 10
# Time 11883: Queue Sizes - Product 0: 2, Product 1: 6
# Time 12183: Queue Sizes - Product 0: 2, Product 1: 2
# queue1 Event Log:
# Time 243: Queue Sizes - Product 0: 1, Product 1: 0
# Time 243: Queue Sizes - Product 0: 2, Product 1: 0
# Time 243: Queue Sizes - Product 0: 3, Product 1: 0
# Time 243: Queue Sizes - Product 0: 4, Product 1: 0
# Time 243: Queue Sizes - Product 0: 3, Product 1: 0
# Time 288: Queue Sizes - Product 0: 2, Product 1: 0
# Time 318: Queue Sizes - Product 0: 1, Product 1: 0
# Time 348: Queue Sizes - Product 0: 0, Product 1: 0
# Time 483: Queue Sizes - Product 0: 1, Product 1: 0
# Time 483: Queue Sizes - Product 0: 2, Product 1: 0
# Time 483: Queue Sizes - Product 0: 3, Product 1: 0
# Time 483: Queue Sizes - Product 0: 4, Product 1: 0
# Time 483: Queue Sizes - Product 0: 3, Product 1: 0
# Time 513: Queue Sizes - Product 0: 2, Product 1: 0
# Time 543: Queue Sizes - Product 0: 1, Product 1: 0
# Time 573: Queue Sizes - Product 0: 0, Product 1: 0
# Time 723: Queue Sizes - Product 0: 1, Product 1: 0
# Time 723: Queue Sizes - Product 0: 2, Product 1: 0
# Time 723: Queue Sizes - Product 0: 3, Product 1: 0
# Time 723: Queue Sizes - Product 0: 4, Product 1: 0
# Time 723: Queue Sizes - Product 0: 3, Product 1: 0
# Time 753: Queue Sizes - Product 0: 2, Product 1: 0
# Time 783: Queue Sizes - Product 0: 1, Product 1: 0
# Time 813: Queue Sizes - Product 0: 0, Product 1: 0
# Time 963: Queue Sizes - Product 0: 1, Product 1: 0
# Time 963: Queue Sizes - Product 0: 2, Product 1: 0
# Time 963: Queue Sizes - Product 0: 3, Product 1: 0
# Time 963: Queue Sizes - Product 0: 4, Product 1: 0
# Time 963: Queue Sizes - Product 0: 3, Product 1: 0
# Time 993: Queue Sizes - Product 0: 2, Product 1: 0
# Time 1023: Queue Sizes - Product 0: 1, Product 1: 0
# Time 1053: Queue Sizes - Product 0: 0, Product 1: 0
# Time 1203: Queue Sizes - Product 0: 1, Product 1: 0
# Time 1203: Queue Sizes - Product 0: 2, Product 1: 0
# Time 1203: Queue Sizes - Product 0: 3, Product 1: 0
# Time 1203: Queue Sizes - Product 0: 4, Product 1: 0
# Time 1203: Queue Sizes - Product 0: 3, Product 1: 0
# Time 1233: Queue Sizes - Product 0: 2, Product 1: 0
# Time 1263: Queue Sizes - Product 0: 1, Product 1: 0
# Time 1293: Queue Sizes - Product 0: 0, Product 1: 0
# Time 1443: Queue Sizes - Product 0: 1, Product 1: 0
# Time 1443: Queue Sizes - Product 0: 2, Product 1: 0
# Time 1443: Queue Sizes - Product 0: 3, Product 1: 0
# Time 1443: Queue Sizes - Product 0: 4, Product 1: 0
# Time 1443: Queue Sizes - Product 0: 3, Product 1: 0
# Time 1473: Queue Sizes - Product 0: 2, Product 1: 0
# Time 1503: Queue Sizes - Product 0: 1, Product 1: 0
# Time 1533: Queue Sizes - Product 0: 0, Product 1: 0
# Time 1683: Queue Sizes - Product 0: 1, Product 1: 0
# Time 1683: Queue Sizes - Product 0: 2, Product 1: 0
# Time 1683: Queue Sizes - Product 0: 3, Product 1: 0
# Time 1683: Queue Sizes - Product 0: 4, Product 1: 0
# Time 1683: Queue Sizes - Product 0: 3, Product 1: 0
# Time 1713: Queue Sizes - Product 0: 2, Product 1: 0
# Time 1743: Queue Sizes - Product 0: 1, Product 1: 0
# Time 1773: Queue Sizes - Product 0: 0, Product 1: 0
# Time 1923: Queue Sizes - Product 0: 1, Product 1: 0
# Time 1923: Queue Sizes - Product 0: 2, Product 1: 0
# Time 1923: Queue Sizes - Product 0: 3, Product 1: 0
# Time 1923: Queue Sizes - Product 0: 4, Product 1: 0
# Time 1923: Queue Sizes - Product 0: 3, Product 1: 0
# Time 1953: Queue Sizes - Product 0: 2, Product 1: 0
# Time 1983: Queue Sizes - Product 0: 1, Product 1: 0
# Time 2013: Queue Sizes - Product 0: 0, Product 1: 0
# Time 2163: Queue Sizes - Product 0: 1, Product 1: 0
# Time 2163: Queue Sizes - Product 0: 2, Product 1: 0
# Time 2163: Queue Sizes - Product 0: 3, Product 1: 0
# Time 2163: Queue Sizes - Product 0: 4, Product 1: 0
# Time 2163: Queue Sizes - Product 0: 3, Product 1: 0
# Time 2193: Queue Sizes - Product 0: 2, Product 1: 0
# Time 2223: Queue Sizes - Product 0: 1, Product 1: 0
# Time 2253: Queue Sizes - Product 0: 0, Product 1: 0
# Time 2403: Queue Sizes - Product 0: 1, Product 1: 0
# Time 2403: Queue Sizes - Product 0: 2, Product 1: 0
# Time 2403: Queue Sizes - Product 0: 3, Product 1: 0
# Time 2403: Queue Sizes - Product 0: 4, Product 1: 0
# Time 2403: Queue Sizes - Product 0: 3, Product 1: 0
# Time 2433: Queue Sizes - Product 0: 2, Product 1: 0
# Time 2463: Queue Sizes - Product 0: 1, Product 1: 0
# Time 2493: Queue Sizes - Product 0: 0, Product 1: 0
# Time 2643: Queue Sizes - Product 0: 1, Product 1: 0
# Time 2643: Queue Sizes - Product 0: 2, Product 1: 0
# Time 2643: Queue Sizes - Product 0: 3, Product 1: 0
# Time 2643: Queue Sizes - Product 0: 4, Product 1: 0
# Time 2643: Queue Sizes - Product 0: 3, Product 1: 0
# Time 2673: Queue Sizes - Product 0: 2, Product 1: 0
# Time 2703: Queue Sizes - Product 0: 1, Product 1: 0
# Time 2733: Queue Sizes - Product 0: 0, Product 1: 0
# Time 2883: Queue Sizes - Product 0: 1, Product 1: 0
# Time 2883: Queue Sizes - Product 0: 2, Product 1: 0
# Time 2883: Queue Sizes - Product 0: 3, Product 1: 0
# Time 2883: Queue Sizes - Product 0: 4, Product 1: 0
# Time 2883: Queue Sizes - Product 0: 3, Product 1: 0
# Time 2913: Queue Sizes - Product 0: 2, Product 1: 0
# Time 2943: Queue Sizes - Product 0: 1, Product 1: 0
# Time 2973: Queue Sizes - Product 0: 0, Product 1: 0
# Time 3123: Queue Sizes - Product 0: 1, Product 1: 0
# Time 3123: Queue Sizes - Product 0: 2, Product 1: 0
# Time 3123: Queue Sizes - Product 0: 3, Product 1: 0
# Time 3123: Queue Sizes - Product 0: 4, Product 1: 0
# Time 3123: Queue Sizes - Product 0: 3, Product 1: 0
# Time 3153: Queue Sizes - Product 0: 2, Product 1: 0
# Time 3183: Queue Sizes - Product 0: 1, Product 1: 0
# Time 3213: Queue Sizes - Product 0: 0, Product 1: 0
# Time 3363: Queue Sizes - Product 0: 1, Product 1: 0
# Time 3363: Queue Sizes - Product 0: 2, Product 1: 0
# Time 3363: Queue Sizes - Product 0: 3, Product 1: 0
# Time 3363: Queue Sizes - Product 0: 4, Product 1: 0
# Time 3363: Queue Sizes - Product 0: 3, Product 1: 0
# Time 3393: Queue Sizes - Product 0: 2, Product 1: 0
# Time 3423: Queue Sizes - Product 0: 1, Product 1: 0
# Time 3453: Queue Sizes - Product 0: 0, Product 1: 0
# Time 3603: Queue Sizes - Product 0: 1, Product 1: 0
# Time 3603: Queue Sizes - Product 0: 2, Product 1: 0
# Time 3603: Queue Sizes - Product 0: 3, Product 1: 0
# Time 3603: Queue Sizes - Product 0: 4, Product 1: 0
# Time 3903: Queue Sizes - Product 0: 4, Product 1: 1
# Time 3903: Queue Sizes - Product 0: 4, Product 1: 2
# Time 3903: Queue Sizes - Product 0: 4, Product 1: 3
# Time 3903: Queue Sizes - Product 0: 4, Product 1: 4
# Time 3903: Queue Sizes - Product 0: 4, Product 1: 3
# Time 3948: Queue Sizes - Product 0: 4, Product 1: 2
# Time 3978: Queue Sizes - Product 0: 4, Product 1: 1
# Time 4008: Queue Sizes - Product 0: 4, Product 1: 0
# Time 4203: Queue Sizes - Product 0: 4, Product 1: 1
# Time 4203: Queue Sizes - Product 0: 4, Product 1: 2
# Time 4203: Queue Sizes - Product 0: 4, Product 1: 3
# Time 4203: Queue Sizes - Product 0: 4, Product 1: 4
# Time 4203: Queue Sizes - Product 0: 4, Product 1: 3
# Time 4233: Queue Sizes - Product 0: 4, Product 1: 2
# Time 4263: Queue Sizes - Product 0: 4, Product 1: 1
# Time 4293: Queue Sizes - Product 0: 4, Product 1: 0
# Time 4384: Queue Sizes - Product 0: 3, Product 1: 0
# Time 4474: Queue Sizes - Product 0: 2, Product 1: 0
# Time 4503: Queue Sizes - Product 0: 2, Product 1: 1
# Time 4503: Queue Sizes - Product 0: 2, Product 1: 2
# Time 4503: Queue Sizes - Product 0: 2, Product 1: 3
# Time 4503: Queue Sizes - Product 0: 2, Product 1: 4
# Time 4504: Queue Sizes - Product 0: 1, Product 1: 4
# Time 4534: Queue Sizes - Product 0: 1, Product 1: 3
# Time 4579: Queue Sizes - Product 0: 0, Product 1: 3
# Time 4624: Queue Sizes - Product 0: 0, Product 1: 2
# Time 4669: Queue Sizes - Product 0: 0, Product 1: 1
# Time 4699: Queue Sizes - Product 0: 0, Product 1: 0
# Time 4743: Queue Sizes - Product 0: 1, Product 1: 0
# Time 4743: Queue Sizes - Product 0: 2, Product 1: 0
# Time 4743: Queue Sizes - Product 0: 3, Product 1: 0
# Time 4743: Queue Sizes - Product 0: 4, Product 1: 0
# Time 4744: Queue Sizes - Product 0: 3, Product 1: 0
# Time 4834: Queue Sizes - Product 0: 2, Product 1: 0
# Time 4864: Queue Sizes - Product 0: 1, Product 1: 0
# Time 4894: Queue Sizes - Product 0: 0, Product 1: 0
# Time 5043: Queue Sizes - Product 0: 0, Product 1: 1
# Time 5043: Queue Sizes - Product 0: 0, Product 1: 2
# Time 5043: Queue Sizes - Product 0: 0, Product 1: 3
# Time 5043: Queue Sizes - Product 0: 0, Product 1: 4
# Time 5043: Queue Sizes - Product 0: 0, Product 1: 3
# Time 5088: Queue Sizes - Product 0: 0, Product 1: 2
# Time 5118: Queue Sizes - Product 0: 0, Product 1: 1
# Time 5148: Queue Sizes - Product 0: 0, Product 1: 0
# Time 5283: Queue Sizes - Product 0: 1, Product 1: 0
# Time 5283: Queue Sizes - Product 0: 2, Product 1: 0
# Time 5283: Queue Sizes - Product 0: 3, Product 1: 0
# Time 5283: Queue Sizes - Product 0: 4, Product 1: 0
# Time 5510: Queue Sizes - Product 0: 3, Product 1: 0
# Time 5583: Queue Sizes - Product 0: 3, Product 1: 1
# Time 5583: Queue Sizes - Product 0: 3, Product 1: 2
# Time 5583: Queue Sizes - Product 0: 3, Product 1: 3
# Time 5583: Queue Sizes - Product 0: 3, Product 1: 4
# Time 5583: Queue Sizes - Product 0: 3, Product 1: 3
# Time 5628: Queue Sizes - Product 0: 2, Product 1: 3
# Time 5673: Queue Sizes - Product 0: 2, Product 1: 2
# Time 5718: Queue Sizes - Product 0: 1, Product 1: 2
# Time 5763: Queue Sizes - Product 0: 1, Product 1: 1
# Time 5808: Queue Sizes - Product 0: 0, Product 1: 1
# Time 5853: Queue Sizes - Product 0: 0, Product 1: 0
# Time 5883: Queue Sizes - Product 0: 0, Product 1: 1
# Time 5883: Queue Sizes - Product 0: 0, Product 1: 2
# Time 5883: Queue Sizes - Product 0: 0, Product 1: 3
# Time 5883: Queue Sizes - Product 0: 0, Product 1: 4
# Time 5898: Queue Sizes - Product 0: 0, Product 1: 3
# Time 5928: Queue Sizes - Product 0: 0, Product 1: 2
# Time 5958: Queue Sizes - Product 0: 0, Product 1: 1
# Time 5988: Queue Sizes - Product 0: 0, Product 1: 0
# Time 6123: Queue Sizes - Product 0: 1, Product 1: 0
# Time 6123: Queue Sizes - Product 0: 2, Product 1: 0
# Time 6123: Queue Sizes - Product 0: 3, Product 1: 0
# Time 6123: Queue Sizes - Product 0: 4, Product 1: 0
# Time 6123: Queue Sizes - Product 0: 3, Product 1: 0
# Time 6168: Queue Sizes - Product 0: 2, Product 1: 0
# Time 6231: Queue Sizes - Product 0: 1, Product 1: 0
# Time 6261: Queue Sizes - Product 0: 0, Product 1: 0
# Time 6363: Queue Sizes - Product 0: 1, Product 1: 0
# Time 6363: Queue Sizes - Product 0: 2, Product 1: 0
# Time 6363: Queue Sizes - Product 0: 3, Product 1: 0
# Time 6363: Queue Sizes - Product 0: 4, Product 1: 0
# Time 6502: Queue Sizes - Product 0: 3, Product 1: 0
# Time 6532: Queue Sizes - Product 0: 2, Product 1: 0
# Time 6592: Queue Sizes - Product 0: 1, Product 1: 0
# Time 6622: Queue Sizes - Product 0: 0, Product 1: 0
# Time 6663: Queue Sizes - Product 0: 0, Product 1: 1
# Time 6663: Queue Sizes - Product 0: 0, Product 1: 2
# Time 6663: Queue Sizes - Product 0: 0, Product 1: 3
# Time 6663: Queue Sizes - Product 0: 0, Product 1: 4
# Time 6903: Queue Sizes - Product 0: 1, Product 1: 4
# Time 6903: Queue Sizes - Product 0: 2, Product 1: 4
# Time 6903: Queue Sizes - Product 0: 3, Product 1: 4
# Time 6903: Queue Sizes - Product 0: 4, Product 1: 4
# Time 6903: Queue Sizes - Product 0: 3, Product 1: 4
# Time 6933: Queue Sizes - Product 0: 2, Product 1: 4
# Time 6963: Queue Sizes - Product 0: 1, Product 1: 4
# Time 6993: Queue Sizes - Product 0: 0, Product 1: 4
# Time 7042: Queue Sizes - Product 0: 0, Product 1: 3
# Time 7087: Queue Sizes - Product 0: 0, Product 1: 2
# Time 7117: Queue Sizes - Product 0: 0, Product 1: 1
# Time 7143: Queue Sizes - Product 0: 1, Product 1: 1
# Time 7143: Queue Sizes - Product 0: 2, Product 1: 1
# Time 7143: Queue Sizes - Product 0: 3, Product 1: 1
# Time 7143: Queue Sizes - Product 0: 4, Product 1: 1
# Time 7147: Queue Sizes - Product 0: 3, Product 1: 1
# Time 7192: Queue Sizes - Product 0: 3, Product 1: 0
# Time 7237: Queue Sizes - Product 0: 2, Product 1: 0
# Time 7297: Queue Sizes - Product 0: 1, Product 1: 0
# Time 7327: Queue Sizes - Product 0: 0, Product 1: 0
# Time 7383: Queue Sizes - Product 0: 1, Product 1: 0
# Time 7383: Queue Sizes - Product 0: 2, Product 1: 0
# Time 7383: Queue Sizes - Product 0: 3, Product 1: 0
# Time 7383: Queue Sizes - Product 0: 4, Product 1: 0
# Time 7387: Queue Sizes - Product 0: 3, Product 1: 0
# Time 7417: Queue Sizes - Product 0: 2, Product 1: 0
# Time 7477: Queue Sizes - Product 0: 1, Product 1: 0
# Time 7507: Queue Sizes - Product 0: 0, Product 1: 0
# Time 7683: Queue Sizes - Product 0: 0, Product 1: 1
# Time 7683: Queue Sizes - Product 0: 0, Product 1: 2
# Time 7683: Queue Sizes - Product 0: 0, Product 1: 3
# Time 7683: Queue Sizes - Product 0: 0, Product 1: 4
# Time 7683: Queue Sizes - Product 0: 0, Product 1: 3
# Time 7728: Queue Sizes - Product 0: 0, Product 1: 2
# Time 7758: Queue Sizes - Product 0: 0, Product 1: 1
# Time 7788: Queue Sizes - Product 0: 0, Product 1: 0
# Time 7983: Queue Sizes - Product 0: 0, Product 1: 1
# Time 7983: Queue Sizes - Product 0: 0, Product 1: 2
# Time 7983: Queue Sizes - Product 0: 0, Product 1: 3
# Time 7983: Queue Sizes - Product 0: 0, Product 1: 4
# Time 7983: Queue Sizes - Product 0: 0, Product 1: 3
# Time 8013: Queue Sizes - Product 0: 0, Product 1: 2
# Time 8043: Queue Sizes - Product 0: 0, Product 1: 1
# Time 8073: Queue Sizes - Product 0: 0, Product 1: 0
# Time 8223: Queue Sizes - Product 0: 1, Product 1: 0
# Time 8223: Queue Sizes - Product 0: 2, Product 1: 0
# Time 8223: Queue Sizes - Product 0: 3, Product 1: 0
# Time 8223: Queue Sizes - Product 0: 4, Product 1: 0
# Time 8223: Queue Sizes - Product 0: 3, Product 1: 0
# Time 8268: Queue Sizes - Product 0: 2, Product 1: 0
# Time 8298: Queue Sizes - Product 0: 1, Product 1: 0
# Time 8328: Queue Sizes - Product 0: 0, Product 1: 0
# Time 8463: Queue Sizes - Product 0: 1, Product 1: 0
# Time 8463: Queue Sizes - Product 0: 2, Product 1: 0
# Time 8463: Queue Sizes - Product 0: 3, Product 1: 0
# Time 8463: Queue Sizes - Product 0: 4, Product 1: 0
# Time 8463: Queue Sizes - Product 0: 3, Product 1: 0
# Time 8493: Queue Sizes - Product 0: 2, Product 1: 0
# Time 8523: Queue Sizes - Product 0: 1, Product 1: 0
# Time 8553: Queue Sizes - Product 0: 0, Product 1: 0
# Time 8703: Queue Sizes - Product 0: 1, Product 1: 0
# Time 8703: Queue Sizes - Product 0: 2, Product 1: 0
# Time 8703: Queue Sizes - Product 0: 3, Product 1: 0
# Time 8703: Queue Sizes - Product 0: 4, Product 1: 0
# Time 8703: Queue Sizes - Product 0: 3, Product 1: 0
# Time 8733: Queue Sizes - Product 0: 2, Product 1: 0
# Time 8763: Queue Sizes - Product 0: 1, Product 1: 0
# Time 8793: Queue Sizes - Product 0: 0, Product 1: 0
# Time 8943: Queue Sizes - Product 0: 1, Product 1: 0
# Time 8943: Queue Sizes - Product 0: 2, Product 1: 0
# Time 8943: Queue Sizes - Product 0: 3, Product 1: 0
# Time 8943: Queue Sizes - Product 0: 4, Product 1: 0
# Time 8943: Queue Sizes - Product 0: 3, Product 1: 0
# Time 8973: Queue Sizes - Product 0: 2, Product 1: 0
# Time 9003: Queue Sizes - Product 0: 1, Product 1: 0
# Time 9033: Queue Sizes - Product 0: 0, Product 1: 0
# Time 9183: Queue Sizes - Product 0: 1, Product 1: 0
# Time 9183: Queue Sizes - Product 0: 2, Product 1: 0
# Time 9183: Queue Sizes - Product 0: 3, Product 1: 0
# Time 9183: Queue Sizes - Product 0: 4, Product 1: 0
# Time 9183: Queue Sizes - Product 0: 3, Product 1: 0
# Time 9213: Queue Sizes - Product 0: 2, Product 1: 0
# Time 9243: Queue Sizes - Product 0: 1, Product 1: 0
# Time 9273: Queue Sizes - Product 0: 0, Product 1: 0
# Time 9423: Queue Sizes - Product 0: 1, Product 1: 0
# Time 9423: Queue Sizes - Product 0: 2, Product 1: 0
# Time 9423: Queue Sizes - Product 0: 3, Product 1: 0
# Time 9423: Queue Sizes - Product 0: 4, Product 1: 0
# Time 9423: Queue Sizes - Product 0: 3, Product 1: 0
# Time 9453: Queue Sizes - Product 0: 2, Product 1: 0
# Time 9483: Queue Sizes - Product 0: 1, Product 1: 0
# Time 9513: Queue Sizes - Product 0: 0, Product 1: 0
# Time 9663: Queue Sizes - Product 0: 1, Product 1: 0
# Time 9663: Queue Sizes - Product 0: 2, Product 1: 0
# Time 9663: Queue Sizes - Product 0: 3, Product 1: 0
# Time 9663: Queue Sizes - Product 0: 4, Product 1: 0
# Time 9663: Queue Sizes - Product 0: 3, Product 1: 0
# Time 9693: Queue Sizes - Product 0: 2, Product 1: 0
# Time 9723: Queue Sizes - Product 0: 1, Product 1: 0
# Time 9753: Queue Sizes - Product 0: 0, Product 1: 0
# Time 9903: Queue Sizes - Product 0: 1, Product 1: 0
# Time 9903: Queue Sizes - Product 0: 2, Product 1: 0
# Time 9903: Queue Sizes - Product 0: 3, Product 1: 0
# Time 9903: Queue Sizes - Product 0: 4, Product 1: 0
# Time 9903: Queue Sizes - Product 0: 3, Product 1: 0
# Time 9933: Queue Sizes - Product 0: 2, Product 1: 0
# Time 9963: Queue Sizes - Product 0: 1, Product 1: 0
# Time 9993: Queue Sizes - Product 0: 0, Product 1: 0
# Time 10143: Queue Sizes - Product 0: 1, Product 1: 0
# Time 10143: Queue Sizes - Product 0: 2, Product 1: 0
# Time 10143: Queue Sizes - Product 0: 3, Product 1: 0
# Time 10143: Queue Sizes - Product 0: 4, Product 1: 0
# Time 10143: Queue Sizes - Product 0: 3, Product 1: 0
# Time 10173: Queue Sizes - Product 0: 2, Product 1: 0
# Time 10203: Queue Sizes - Product 0: 1, Product 1: 0
# Time 10233: Queue Sizes - Product 0: 0, Product 1: 0
# Time 10383: Queue Sizes - Product 0: 1, Product 1: 0
# Time 10383: Queue Sizes - Product 0: 2, Product 1: 0
# Time 10383: Queue Sizes - Product 0: 3, Product 1: 0
# Time 10383: Queue Sizes - Product 0: 4, Product 1: 0
# Time 10383: Queue Sizes - Product 0: 3, Product 1: 0
# Time 10413: Queue Sizes - Product 0: 2, Product 1: 0
# Time 10443: Queue Sizes - Product 0: 1, Product 1: 0
# Time 10473: Queue Sizes - Product 0: 0, Product 1: 0
# Time 10623: Queue Sizes - Product 0: 1, Product 1: 0
# Time 10623: Queue Sizes - Product 0: 2, Product 1: 0
# Time 10623: Queue Sizes - Product 0: 3, Product 1: 0
# Time 10623: Queue Sizes - Product 0: 4, Product 1: 0
# Time 10623: Queue Sizes - Product 0: 3, Product 1: 0
# Time 10653: Queue Sizes - Product 0: 2, Product 1: 0
# Time 10683: Queue Sizes - Product 0: 1, Product 1: 0
# Time 10713: Queue Sizes - Product 0: 0, Product 1: 0
# Time 10863: Queue Sizes - Product 0: 1, Product 1: 0
# Time 10863: Queue Sizes - Product 0: 2, Product 1: 0
# Time 10863: Queue Sizes - Product 0: 3, Product 1: 0
# Time 10863: Queue Sizes - Product 0: 4, Product 1: 0
# Time 10863: Queue Sizes - Product 0: 3, Product 1: 0
# Time 10893: Queue Sizes - Product 0: 2, Product 1: 0
# Time 10923: Queue Sizes - Product 0: 1, Product 1: 0
# Time 10953: Queue Sizes - Product 0: 0, Product 1: 0
# Time 11103: Queue Sizes - Product 0: 1, Product 1: 0
# Time 11103: Queue Sizes - Product 0: 2, Product 1: 0
# Time 11103: Queue Sizes - Product 0: 3, Product 1: 0
# Time 11103: Queue Sizes - Product 0: 4, Product 1: 0
# Time 11103: Queue Sizes - Product 0: 3, Product 1: 0
# Time 11133: Queue Sizes - Product 0: 2, Product 1: 0
# Time 11163: Queue Sizes - Product 0: 1, Product 1: 0
# Time 11193: Queue Sizes - Product 0: 0, Product 1: 0
# Time 11343: Queue Sizes - Product 0: 1, Product 1: 0
# Time 11343: Queue Sizes - Product 0: 2, Product 1: 0
# Time 11343: Queue Sizes - Product 0: 3, Product 1: 0
# Time 11343: Queue Sizes - Product 0: 4, Product 1: 0
# Time 11343: Queue Sizes - Product 0: 3, Product 1: 0
# Time 11373: Queue Sizes - Product 0: 2, Product 1: 0
# Time 11403: Queue Sizes - Product 0: 1, Product 1: 0
# Time 11433: Queue Sizes - Product 0: 0, Product 1: 0
# Time 11583: Queue Sizes - Product 0: 1, Product 1: 0
# Time 11583: Queue Sizes - Product 0: 2, Product 1: 0
# Time 11583: Queue Sizes - Product 0: 3, Product 1: 0
# Time 11583: Queue Sizes - Product 0: 4, Product 1: 0
# Time 11583: Queue Sizes - Product 0: 3, Product 1: 0
# Time 11613: Queue Sizes - Product 0: 2, Product 1: 0
# Time 11643: Queue Sizes - Product 0: 1, Product 1: 0
# Time 11673: Queue Sizes - Product 0: 0, Product 1: 0
# Time 11883: Queue Sizes - Product 0: 0, Product 1: 1
# Time 11883: Queue Sizes - Product 0: 0, Product 1: 2
# Time 11883: Queue Sizes - Product 0: 0, Product 1: 3
# Time 11883: Queue Sizes - Product 0: 0, Product 1: 4
# Time 11883: Queue Sizes - Product 0: 0, Product 1: 3
# Time 11928: Queue Sizes - Product 0: 0, Product 1: 2
# Time 11958: Queue Sizes - Product 0: 0, Product 1: 1
# Time 11988: Queue Sizes - Product 0: 0, Product 1: 0
# Time 12183: Queue Sizes - Product 0: 0, Product 1: 1
# Time 12183: Queue Sizes - Product 0: 0, Product 1: 2
# Time 12183: Queue Sizes - Product 0: 0, Product 1: 3
# Time 12183: Queue Sizes - Product 0: 0, Product 1: 4
# Time 12183: Queue Sizes - Product 0: 0, Product 1: 3
# Time 12213: Queue Sizes - Product 0: 0, Product 1: 2
# Time 12243: Queue Sizes - Product 0: 0, Product 1: 1
# Time 12273: Queue Sizes - Product 0: 0, Product 1: 0
# Time 12483: Queue Sizes - Product 0: 0, Product 1: 1
# Time 12483: Queue Sizes - Product 0: 0, Product 1: 2
# Time 12483: Queue Sizes - Product 0: 0, Product 1: 3
# Time 12483: Queue Sizes - Product 0: 0, Product 1: 4
# Time 12483: Queue Sizes - Product 0: 0, Product 1: 3
# Time 12513: Queue Sizes - Product 0: 0, Product 1: 2
# Time 12543: Queue Sizes - Product 0: 0, Product 1: 1
# Time 12573: Queue Sizes - Product 0: 0, Product 1: 0
# queue2 Event Log:
# Time 288: Queue Sizes - Product 0: 1, Product 1: 0
# Time 318: Queue Sizes - Product 0: 2, Product 1: 0
# Time 348: Queue Sizes - Product 0: 3, Product 1: 0
# Time 378: Queue Sizes - Product 0: 4, Product 1: 0
# Time 378: Queue Sizes - Product 0: 0, Product 1: 0
# Time 513: Queue Sizes - Product 0: 1, Product 1: 0
# Time 543: Queue Sizes - Product 0: 2, Product 1: 0
# Time 573: Queue Sizes - Product 0: 3, Product 1: 0
# Time 603: Queue Sizes - Product 0: 4, Product 1: 0
# Time 618: Queue Sizes - Product 0: 0, Product 1: 0
# Time 753: Queue Sizes - Product 0: 1, Product 1: 0
# Time 783: Queue Sizes - Product 0: 2, Product 1: 0
# Time 813: Queue Sizes - Product 0: 3, Product 1: 0
# Time 843: Queue Sizes - Product 0: 4, Product 1: 0
# Time 858: Queue Sizes - Product 0: 0, Product 1: 0
# Time 993: Queue Sizes - Product 0: 1, Product 1: 0
# Time 1023: Queue Sizes - Product 0: 2, Product 1: 0
# Time 1053: Queue Sizes - Product 0: 3, Product 1: 0
# Time 1083: Queue Sizes - Product 0: 4, Product 1: 0
# Time 1098: Queue Sizes - Product 0: 0, Product 1: 0
# Time 1233: Queue Sizes - Product 0: 1, Product 1: 0
# Time 1263: Queue Sizes - Product 0: 2, Product 1: 0
# Time 1293: Queue Sizes - Product 0: 3, Product 1: 0
# Time 1323: Queue Sizes - Product 0: 4, Product 1: 0
# Time 1338: Queue Sizes - Product 0: 0, Product 1: 0
# Time 1473: Queue Sizes - Product 0: 1, Product 1: 0
# Time 1503: Queue Sizes - Product 0: 2, Product 1: 0
# Time 1533: Queue Sizes - Product 0: 3, Product 1: 0
# Time 1563: Queue Sizes - Product 0: 4, Product 1: 0
# Time 1578: Queue Sizes - Product 0: 0, Product 1: 0
# Time 1713: Queue Sizes - Product 0: 1, Product 1: 0
# Time 1743: Queue Sizes - Product 0: 2, Product 1: 0
# Time 1773: Queue Sizes - Product 0: 3, Product 1: 0
# Time 1803: Queue Sizes - Product 0: 4, Product 1: 0
# Time 1818: Queue Sizes - Product 0: 0, Product 1: 0
# Time 1953: Queue Sizes - Product 0: 1, Product 1: 0
# Time 1983: Queue Sizes - Product 0: 2, Product 1: 0
# Time 2013: Queue Sizes - Product 0: 3, Product 1: 0
# Time 2043: Queue Sizes - Product 0: 4, Product 1: 0
# Time 2058: Queue Sizes - Product 0: 0, Product 1: 0
# Time 2193: Queue Sizes - Product 0: 1, Product 1: 0
# Time 2223: Queue Sizes - Product 0: 2, Product 1: 0
# Time 2253: Queue Sizes - Product 0: 3, Product 1: 0
# Time 2283: Queue Sizes - Product 0: 4, Product 1: 0
# Time 2298: Queue Sizes - Product 0: 0, Product 1: 0
# Time 2433: Queue Sizes - Product 0: 1, Product 1: 0
# Time 2463: Queue Sizes - Product 0: 2, Product 1: 0
# Time 2493: Queue Sizes - Product 0: 3, Product 1: 0
# Time 2523: Queue Sizes - Product 0: 4, Product 1: 0
# Time 2538: Queue Sizes - Product 0: 0, Product 1: 0
# Time 2673: Queue Sizes - Product 0: 1, Product 1: 0
# Time 2703: Queue Sizes - Product 0: 2, Product 1: 0
# Time 2733: Queue Sizes - Product 0: 3, Product 1: 0
# Time 2763: Queue Sizes - Product 0: 4, Product 1: 0
# Time 2778: Queue Sizes - Product 0: 0, Product 1: 0
# Time 2913: Queue Sizes - Product 0: 1, Product 1: 0
# Time 2943: Queue Sizes - Product 0: 2, Product 1: 0
# Time 2973: Queue Sizes - Product 0: 3, Product 1: 0
# Time 3003: Queue Sizes - Product 0: 4, Product 1: 0
# Time 3018: Queue Sizes - Product 0: 0, Product 1: 0
# Time 3153: Queue Sizes - Product 0: 1, Product 1: 0
# Time 3183: Queue Sizes - Product 0: 2, Product 1: 0
# Time 3213: Queue Sizes - Product 0: 3, Product 1: 0
# Time 3243: Queue Sizes - Product 0: 4, Product 1: 0
# Time 3258: Queue Sizes - Product 0: 0, Product 1: 0
# Time 3393: Queue Sizes - Product 0: 1, Product 1: 0
# Time 3423: Queue Sizes - Product 0: 2, Product 1: 0
# Time 3453: Queue Sizes - Product 0: 3, Product 1: 0
# Time 3483: Queue Sizes - Product 0: 4, Product 1: 0
# Time 3498: Queue Sizes - Product 0: 0, Product 1: 0
# Time 3948: Queue Sizes - Product 0: 0, Product 1: 1
# Time 3978: Queue Sizes - Product 0: 0, Product 1: 2
# Time 4008: Queue Sizes - Product 0: 0, Product 1: 3
# Time 4038: Queue Sizes - Product 0: 0, Product 1: 4
# Time 4038: Queue Sizes - Product 0: 0, Product 1: 0
# Time 4233: Queue Sizes - Product 0: 0, Product 1: 1
# Time 4263: Queue Sizes - Product 0: 0, Product 1: 2
# Time 4293: Queue Sizes - Product 0: 0, Product 1: 3
# Time 4323: Queue Sizes - Product 0: 0, Product 1: 4
# Time 4338: Queue Sizes - Product 0: 0, Product 1: 0
# Time 4429: Queue Sizes - Product 0: 1, Product 1: 0
# Time 4504: Queue Sizes - Product 0: 2, Product 1: 0
# Time 4534: Queue Sizes - Product 0: 3, Product 1: 0
# Time 4579: Queue Sizes - Product 0: 3, Product 1: 1
# Time 4624: Queue Sizes - Product 0: 4, Product 1: 1
# Time 4654: Queue Sizes - Product 0: 0, Product 1: 1
# Time 4669: Queue Sizes - Product 0: 0, Product 1: 2
# Time 4699: Queue Sizes - Product 0: 0, Product 1: 3
# Time 4729: Queue Sizes - Product 0: 0, Product 1: 4
# Time 4789: Queue Sizes - Product 0: 1, Product 1: 4
# Time 4864: Queue Sizes - Product 0: 2, Product 1: 4
# Time 4894: Queue Sizes - Product 0: 3, Product 1: 4
# Time 4924: Queue Sizes - Product 0: 4, Product 1: 4
# Time 4924: Queue Sizes - Product 0: 0, Product 1: 4
# Time 5088: Queue Sizes - Product 0: 0, Product 1: 5
# Time 5118: Queue Sizes - Product 0: 0, Product 1: 6
# Time 5148: Queue Sizes - Product 0: 0, Product 1: 7
# Time 5164: Queue Sizes - Product 0: 0, Product 1: 3
# Time 5178: Queue Sizes - Product 0: 0, Product 1: 4
# Time 5464: Queue Sizes - Product 0: 0, Product 1: 0
# Time 5555: Queue Sizes - Product 0: 1, Product 1: 0
# Time 5628: Queue Sizes - Product 0: 1, Product 1: 1
# Time 5673: Queue Sizes - Product 0: 2, Product 1: 1
# Time 5718: Queue Sizes - Product 0: 2, Product 1: 2
# Time 5763: Queue Sizes - Product 0: 3, Product 1: 2
# Time 5808: Queue Sizes - Product 0: 3, Product 1: 3
# Time 5853: Queue Sizes - Product 0: 4, Product 1: 3
# Time 5870: Queue Sizes - Product 0: 0, Product 1: 3
# Time 5898: Queue Sizes - Product 0: 0, Product 1: 4
# Time 5928: Queue Sizes - Product 0: 0, Product 1: 5
# Time 5958: Queue Sizes - Product 0: 0, Product 1: 6
# Time 5988: Queue Sizes - Product 0: 0, Product 1: 7
# Time 6018: Queue Sizes - Product 0: 0, Product 1: 8
# Time 6156: Queue Sizes - Product 0: 0, Product 1: 4
# Time 6168: Queue Sizes - Product 0: 1, Product 1: 4
# Time 6198: Queue Sizes - Product 0: 2, Product 1: 4
# Time 6261: Queue Sizes - Product 0: 3, Product 1: 4
# Time 6291: Queue Sizes - Product 0: 4, Product 1: 4
# Time 6456: Queue Sizes - Product 0: 4, Product 1: 0
# Time 6532: Queue Sizes - Product 0: 5, Product 1: 0
# Time 6562: Queue Sizes - Product 0: 6, Product 1: 0
# Time 6622: Queue Sizes - Product 0: 7, Product 1: 0
# Time 6652: Queue Sizes - Product 0: 8, Product 1: 0
# Time 6756: Queue Sizes - Product 0: 4, Product 1: 0
# Time 6933: Queue Sizes - Product 0: 5, Product 1: 0
# Time 6963: Queue Sizes - Product 0: 6, Product 1: 0
# Time 6993: Queue Sizes - Product 0: 7, Product 1: 0
# Time 6996: Queue Sizes - Product 0: 3, Product 1: 0
# Time 7023: Queue Sizes - Product 0: 4, Product 1: 0
# Time 7087: Queue Sizes - Product 0: 4, Product 1: 1
# Time 7117: Queue Sizes - Product 0: 4, Product 1: 2
# Time 7147: Queue Sizes - Product 0: 4, Product 1: 3
# Time 7192: Queue Sizes - Product 0: 5, Product 1: 3
# Time 7236: Queue Sizes - Product 0: 1, Product 1: 3
# Time 7237: Queue Sizes - Product 0: 1, Product 1: 4
# Time 7282: Queue Sizes - Product 0: 2, Product 1: 4
# Time 7327: Queue Sizes - Product 0: 3, Product 1: 4
# Time 7357: Queue Sizes - Product 0: 4, Product 1: 4
# Time 7417: Queue Sizes - Product 0: 5, Product 1: 4
# Time 7447: Queue Sizes - Product 0: 6, Product 1: 4
# Time 7476: Queue Sizes - Product 0: 6, Product 1: 0
# Time 7507: Queue Sizes - Product 0: 7, Product 1: 0
# Time 7537: Queue Sizes - Product 0: 8, Product 1: 0
# Time 7728: Queue Sizes - Product 0: 8, Product 1: 1
# Time 7758: Queue Sizes - Product 0: 8, Product 1: 2
# Time 7788: Queue Sizes - Product 0: 8, Product 1: 3
# Time 7818: Queue Sizes - Product 0: 8, Product 1: 4
# Time 7818: Queue Sizes - Product 0: 8, Product 1: 0
# Time 8013: Queue Sizes - Product 0: 8, Product 1: 1
# Time 8043: Queue Sizes - Product 0: 8, Product 1: 2
# Time 8073: Queue Sizes - Product 0: 8, Product 1: 3
# Time 8103: Queue Sizes - Product 0: 8, Product 1: 4
# Time 8118: Queue Sizes - Product 0: 4, Product 1: 4
# Time 8268: Queue Sizes - Product 0: 5, Product 1: 4
# Time 8298: Queue Sizes - Product 0: 6, Product 1: 4
# Time 8328: Queue Sizes - Product 0: 7, Product 1: 4
# Time 8358: Queue Sizes - Product 0: 8, Product 1: 4
# Time 8358: Queue Sizes - Product 0: 4, Product 1: 4
# Time 8493: Queue Sizes - Product 0: 5, Product 1: 4
# Time 8523: Queue Sizes - Product 0: 6, Product 1: 4
# Time 8553: Queue Sizes - Product 0: 7, Product 1: 4
# Time 8583: Queue Sizes - Product 0: 8, Product 1: 4
# Time 8598: Queue Sizes - Product 0: 4, Product 1: 4
# Time 8733: Queue Sizes - Product 0: 5, Product 1: 4
# Time 8763: Queue Sizes - Product 0: 6, Product 1: 4
# Time 8793: Queue Sizes - Product 0: 7, Product 1: 4
# Time 8823: Queue Sizes - Product 0: 8, Product 1: 4
# Time 8838: Queue Sizes - Product 0: 4, Product 1: 4
# Time 8973: Queue Sizes - Product 0: 5, Product 1: 4
# Time 9003: Queue Sizes - Product 0: 6, Product 1: 4
# Time 9033: Queue Sizes - Product 0: 7, Product 1: 4
# Time 9063: Queue Sizes - Product 0: 8, Product 1: 4
# Time 9078: Queue Sizes - Product 0: 4, Product 1: 4
# Time 9213: Queue Sizes - Product 0: 5, Product 1: 4
# Time 9243: Queue Sizes - Product 0: 6, Product 1: 4
# Time 9273: Queue Sizes - Product 0: 7, Product 1: 4
# Time 9303: Queue Sizes - Product 0: 8, Product 1: 4
# Time 9318: Queue Sizes - Product 0: 4, Product 1: 4
# Time 9453: Queue Sizes - Product 0: 5, Product 1: 4
# Time 9483: Queue Sizes - Product 0: 6, Product 1: 4
# Time 9513: Queue Sizes - Product 0: 7, Product 1: 4
# Time 9543: Queue Sizes - Product 0: 8, Product 1: 4
# Time 9558: Queue Sizes - Product 0: 4, Product 1: 4
# Time 9693: Queue Sizes - Product 0: 5, Product 1: 4
# Time 9723: Queue Sizes - Product 0: 6, Product 1: 4
# Time 9753: Queue Sizes - Product 0: 7, Product 1: 4
# Time 9783: Queue Sizes - Product 0: 8, Product 1: 4
# Time 9798: Queue Sizes - Product 0: 4, Product 1: 4
# Time 9933: Queue Sizes - Product 0: 5, Product 1: 4
# Time 9963: Queue Sizes - Product 0: 6, Product 1: 4
# Time 9993: Queue Sizes - Product 0: 7, Product 1: 4
# Time 10023: Queue Sizes - Product 0: 8, Product 1: 4
# Time 10038: Queue Sizes - Product 0: 4, Product 1: 4
# Time 10173: Queue Sizes - Product 0: 5, Product 1: 4
# Time 10203: Queue Sizes - Product 0: 6, Product 1: 4
# Time 10233: Queue Sizes - Product 0: 7, Product 1: 4
# Time 10263: Queue Sizes - Product 0: 8, Product 1: 4
# Time 10278: Queue Sizes - Product 0: 4, Product 1: 4
# Time 10413: Queue Sizes - Product 0: 5, Product 1: 4
# Time 10443: Queue Sizes - Product 0: 6, Product 1: 4
# Time 10473: Queue Sizes - Product 0: 7, Product 1: 4
# Time 10503: Queue Sizes - Product 0: 8, Product 1: 4
# Time 10518: Queue Sizes - Product 0: 4, Product 1: 4
# Time 10653: Queue Sizes - Product 0: 5, Product 1: 4
# Time 10683: Queue Sizes - Product 0: 6, Product 1: 4
# Time 10713: Queue Sizes - Product 0: 7, Product 1: 4
# Time 10743: Queue Sizes - Product 0: 8, Product 1: 4
# Time 10758: Queue Sizes - Product 0: 4, Product 1: 4
# Time 10893: Queue Sizes - Product 0: 5, Product 1: 4
# Time 10923: Queue Sizes - Product 0: 6, Product 1: 4
# Time 10953: Queue Sizes - Product 0: 7, Product 1: 4
# Time 10983: Queue Sizes - Product 0: 8, Product 1: 4
# Time 10998: Queue Sizes - Product 0: 4, Product 1: 4
# Time 11133: Queue Sizes - Product 0: 5, Product 1: 4
# Time 11163: Queue Sizes - Product 0: 6, Product 1: 4
# Time 11193: Queue Sizes - Product 0: 7, Product 1: 4
# Time 11223: Queue Sizes - Product 0: 8, Product 1: 4
# Time 11238: Queue Sizes - Product 0: 4, Product 1: 4
# Time 11373: Queue Sizes - Product 0: 5, Product 1: 4
# Time 11403: Queue Sizes - Product 0: 6, Product 1: 4
# Time 11433: Queue Sizes - Product 0: 7, Product 1: 4
# Time 11463: Queue Sizes - Product 0: 8, Product 1: 4
# Time 11478: Queue Sizes - Product 0: 4, Product 1: 4
# Time 11613: Queue Sizes - Product 0: 5, Product 1: 4
# Time 11643: Queue Sizes - Product 0: 6, Product 1: 4
# Time 11673: Queue Sizes - Product 0: 7, Product 1: 4
# Time 11703: Queue Sizes - Product 0: 8, Product 1: 4
# Time 11718: Queue Sizes - Product 0: 4, Product 1: 4
# Time 11928: Queue Sizes - Product 0: 4, Product 1: 5
# Time 11958: Queue Sizes - Product 0: 4, Product 1: 6
# Time 11958: Queue Sizes - Product 0: 0, Product 1: 6
# Time 11988: Queue Sizes - Product 0: 0, Product 1: 7
# Time 12018: Queue Sizes - Product 0: 0, Product 1: 8
# Time 12198: Queue Sizes - Product 0: 0, Product 1: 4
# Time 12213: Queue Sizes - Product 0: 0, Product 1: 5
# Time 12243: Queue Sizes - Product 0: 0, Product 1: 6
# Time 12273: Queue Sizes - Product 0: 0, Product 1: 7
# Time 12303: Queue Sizes - Product 0: 0, Product 1: 8
# Time 12498: Queue Sizes - Product 0: 0, Product 1: 4
# Time 12513: Queue Sizes - Product 0: 0, Product 1: 5
# Time 12543: Queue Sizes - Product 0: 0, Product 1: 6
# Time 12573: Queue Sizes - Product 0: 0, Product 1: 7
# Time 12603: Queue Sizes - Product 0: 0, Product 1: 8
# Time 12798: Queue Sizes - Product 0: 0, Product 1: 4
# Time 13098: Queue Sizes - Product 0: 0, Product 1: 0
# queue3 Event Log:
# Time 618: Queue Sizes - Product 0: 1, Product 1: 0
# Time 618: Queue Sizes - Product 0: 2, Product 1: 0
# Time 618: Queue Sizes - Product 0: 3, Product 1: 0
# Time 618: Queue Sizes - Product 0: 4, Product 1: 0
# Time 618: Queue Sizes - Product 0: 3, Product 1: 0
# Time 663: Queue Sizes - Product 0: 2, Product 1: 0
# Time 693: Queue Sizes - Product 0: 1, Product 1: 0
# Time 723: Queue Sizes - Product 0: 0, Product 1: 0
# Time 858: Queue Sizes - Product 0: 1, Product 1: 0
# Time 858: Queue Sizes - Product 0: 2, Product 1: 0
# Time 858: Queue Sizes - Product 0: 3, Product 1: 0
# Time 858: Queue Sizes - Product 0: 4, Product 1: 0
# Time 858: Queue Sizes - Product 0: 3, Product 1: 0
# Time 888: Queue Sizes - Product 0: 2, Product 1: 0
# Time 918: Queue Sizes - Product 0: 1, Product 1: 0
# Time 948: Queue Sizes - Product 0: 0, Product 1: 0
# Time 1098: Queue Sizes - Product 0: 1, Product 1: 0
# Time 1098: Queue Sizes - Product 0: 2, Product 1: 0
# Time 1098: Queue Sizes - Product 0: 3, Product 1: 0
# Time 1098: Queue Sizes - Product 0: 4, Product 1: 0
# Time 1098: Queue Sizes - Product 0: 3, Product 1: 0
# Time 1128: Queue Sizes - Product 0: 2, Product 1: 0
# Time 1158: Queue Sizes - Product 0: 1, Product 1: 0
# Time 1188: Queue Sizes - Product 0: 0, Product 1: 0
# Time 1338: Queue Sizes - Product 0: 1, Product 1: 0
# Time 1338: Queue Sizes - Product 0: 2, Product 1: 0
# Time 1338: Queue Sizes - Product 0: 3, Product 1: 0
# Time 1338: Queue Sizes - Product 0: 4, Product 1: 0
# Time 1338: Queue Sizes - Product 0: 3, Product 1: 0
# Time 1368: Queue Sizes - Product 0: 2, Product 1: 0
# Time 1398: Queue Sizes - Product 0: 1, Product 1: 0
# ...
# At machine Machine 3: Product 0 processed from 858 to 888
# At machine Machine 3: Product 0 processed from 888 to 918
# At machine Machine 3: Product 0 processed from 918 to 948
# At machine Machine 3: Product 0 processed from 948 to 978
# At machine Machine 3: Product 0 processed from 1098 to 1128
# At machine Machine 3: Product 0 processed from 1128 to 1158
# At machine Machine 3: Product 0 processed from 1158 to 1188
# At machine Machine 3: Product 0 processed from 1188 to 1218
# At machine Machine 3: Product 0 processed from 1338 to 1368
# At machine Machine 3: Product 0 processed from 1368 to 1398
# At machine Machine 3: Product 0 processed from 1398 to 1428
# At machine Machine 3: Product 0 processed from 1428 to 1458
# At machine Machine 3: Product 0 processed from 1578 to 1608
# At machine Machine 3: Product 0 processed from 1608 to 1638
# At machine Machine 3: Product 0 processed from 1638 to 1668
# At machine Machine 3: Product 0 processed from 1668 to 1698
# At machine Machine 3: Product 0 processed from 1818 to 1848
# At machine Machine 3: Product 0 processed from 1848 to 1878
# At machine Machine 3: Product 0 processed from 1878 to 1908
# At machine Machine 3: Product 0 processed from 1908 to 1938
# At machine Machine 3: Product 0 processed from 2058 to 2088
# At machine Machine 3: Product 0 processed from 2088 to 2118
# At machine Machine 3: Product 0 processed from 2118 to 2148
# At machine Machine 3: Product 0 processed from 2148 to 2178
# At machine Machine 3: Product 0 processed from 2298 to 2328
# At machine Machine 3: Product 0 processed from 2328 to 2358
# At machine Machine 3: Product 0 processed from 2358 to 2388
# At machine Machine 3: Product 0 processed from 2388 to 2418
# At machine Machine 3: Product 0 processed from 2538 to 2568
# At machine Machine 3: Product 0 processed from 2568 to 2598
# At machine Machine 3: Product 0 processed from 2598 to 2628
# At machine Machine 3: Product 0 processed from 2628 to 2658
# At machine Machine 3: Product 0 processed from 2778 to 2808
# At machine Machine 3: Product 0 processed from 2808 to 2838
# At machine Machine 3: Product 0 processed from 2838 to 2868
# At machine Machine 3: Product 0 processed from 2868 to 2898
# At machine Machine 3: Product 0 processed from 3018 to 3048
# At machine Machine 3: Product 0 processed from 3048 to 3078
# At machine Machine 3: Product 0 processed from 3078 to 3108
# At machine Machine 3: Product 0 processed from 3108 to 3138
# At machine Machine 3: Product 0 processed from 3258 to 3288
# At machine Machine 3: Product 0 processed from 3288 to 3318
# At machine Machine 3: Product 0 processed from 3318 to 3348
# At machine Machine 3: Product 0 processed from 3348 to 3378
# At machine Machine 3: Product 0 processed from 3498 to 3528
# At machine Machine 3: Product 0 processed from 3528 to 3558
# At machine Machine 3: Product 0 processed from 3558 to 3588
# At machine Machine 3: Product 1 processed from 4338 to 4383
# At machine Machine 3: Product 0 processed from 4383 to 4428
# At machine Machine 3: Product 1 processed from 4428 to 4473
# At machine Machine 3: Product 0 processed from 4473 to 4518
# At machine Machine 3: Product 1 processed from 4518 to 4563
# At machine Machine 3: Product 0 processed from 4563 to 4608
# At machine Machine 3: Product 1 processed from 4608 to 4653
# At machine Machine 3: Product 0 processed from 4653 to 4698
# At machine Machine 3: Product 1 processed from 4698 to 4743
# At machine Machine 3: Product 0 processed from 4743 to 4788
# At machine Machine 3: Product 1 processed from 4788 to 4833
# At machine Machine 3: Product 1 processed from 4833 to 4863
# At machine Machine 3: Product 0 processed from 4894 to 4939
# At machine Machine 3: Product 0 processed from 4939 to 4969
# At machine Machine 3: Product 1 processed from 4969 to 5014
# At machine Machine 3: Product 0 processed from 5014 to 5059
# At machine Machine 3: Product 1 processed from 5464 to 5509
# At machine Machine 3: Product 0 processed from 5509 to 5554
# At machine Machine 3: Product 1 processed from 5554 to 5599
# At machine Machine 3: Product 0 processed from 5599 to 5644
# At machine Machine 3: Product 1 processed from 5644 to 5689
# At machine Machine 3: Product 0 processed from 5689 to 5734
# At machine Machine 3: Product 1 processed from 5734 to 5779
# At machine Machine 3: Product 0 processed from 5779 to 5824
# At machine Machine 3: Product 1 processed from 5824 to 5869
# At machine Machine 3: Product 0 processed from 5869 to 5914
# At machine Machine 3: Product 1 processed from 5914 to 5959
# At machine Machine 3: Product 1 processed from 5959 to 5989
# At machine Machine 3: Product 0 processed from 6110 to 6155
# At machine Machine 3: Product 0 processed from 6155 to 6185
# At machine Machine 3: Product 1 processed from 6185 to 6230
# At machine Machine 3: Product 0 processed from 6230 to 6275
# At machine Machine 3: Product 1 processed from 6456 to 6501
# At machine Machine 3: Product 0 processed from 6501 to 6546
# At machine Machine 3: Product 1 processed from 6546 to 6591
# At machine Machine 3: Product 1 processed from 6591 to 6621
# At machine Machine 3: Product 0 processed from 6996 to 7041
# At machine Machine 3: Product 0 processed from 7041 to 7071
# At machine Machine 3: Product 1 processed from 7071 to 7116
# At machine Machine 3: Product 0 processed from 7116 to 7161
# At machine Machine 3: Product 1 processed from 7161 to 7206
# At machine Machine 3: Product 0 processed from 7206 to 7251
# At machine Machine 3: Product 1 processed from 7251 to 7296
# At machine Machine 3: Product 0 processed from 7296 to 7341
# At machine Machine 3: Product 1 processed from 7341 to 7386
# At machine Machine 3: Product 0 processed from 7386 to 7431
# At machine Machine 3: Product 1 processed from 7431 to 7476
# At machine Machine 3: Product 0 processed from 7476 to 7521
# At machine Machine 3: Product 1 processed from 7776 to 7821
# At machine Machine 3: Product 0 processed from 7821 to 7866
# At machine Machine 3: Product 0 processed from 7866 to 7896
# At machine Machine 3: Product 0 processed from 7896 to 7926
# At machine Machine 3: Product 0 processed from 7926 to 7956
# At machine Machine 3: Product 0 processed from 7956 to 7986
# At machine Machine 3: Product 1 processed from 7986 to 8031
# At machine Machine 3: Product 1 processed from 8031 to 8061
# At machine Machine 3: Product 1 processed from 8061 to 8091
# At machine Machine 3: Product 1 processed from 8118 to 8148
# At machine Machine 3: Product 1 processed from 8148 to 8178
# At machine Machine 3: Product 1 processed from 8178 to 8208
# At machine Machine 3: Product 1 processed from 8208 to 8238
# At machine Machine 3: Product 0 processed from 8358 to 8403
# At machine Machine 3: Product 0 processed from 8403 to 8433
# At machine Machine 3: Product 0 processed from 8433 to 8463
# At machine Machine 3: Product 0 processed from 8463 to 8493
# At machine Machine 3: Product 0 processed from 8598 to 8628
# At machine Machine 3: Product 0 processed from 8628 to 8658
# At machine Machine 3: Product 0 processed from 8658 to 8688
# At machine Machine 3: Product 0 processed from 8688 to 8718
# At machine Machine 3: Product 0 processed from 8838 to 8868
# At machine Machine 3: Product 0 processed from 8868 to 8898
# At machine Machine 3: Product 0 processed from 8898 to 8928
# At machine Machine 3: Product 0 processed from 8928 to 8958
# At machine Machine 3: Product 0 processed from 9078 to 9108
# At machine Machine 3: Product 0 processed from 9108 to 9138
# At machine Machine 3: Product 0 processed from 9138 to 9168
# At machine Machine 3: Product 0 processed from 9168 to 9198
# At machine Machine 3: Product 0 processed from 9318 to 9348
# At machine Machine 3: Product 0 processed from 9348 to 9378
# At machine Machine 3: Product 0 processed from 9378 to 9408
# At machine Machine 3: Product 0 processed from 9408 to 9438
# At machine Machine 3: Product 0 processed from 9558 to 9588
# At machine Machine 3: Product 0 processed from 9588 to 9618
# At machine Machine 3: Product 0 processed from 9618 to 9648
# At machine Machine 3: Product 0 processed from 9648 to 9678
# At machine Machine 3: Product 0 processed from 9798 to 9828
# At machine Machine 3: Product 0 processed from 9828 to 9858
# At machine Machine 3: Product 0 processed from 9858 to 9888
# At machine Machine 3: Product 0 processed from 9888 to 9918
# At machine Machine 3: Product 0 processed from 10038 to 10068
# At machine Machine 3: Product 0 processed from 10068 to 10098
# At machine Machine 3: Product 0 processed from 10098 to 10128
# At machine Machine 3: Product 0 processed from 10128 to 10158
# At machine Machine 3: Product 0 processed from 10278 to 10308
# At machine Machine 3: Product 0 processed from 10308 to 10338
# At machine Machine 3: Product 0 processed from 10338 to 10368
# At machine Machine 3: Product 0 processed from 10368 to 10398
# At machine Machine 3: Product 0 processed from 10518 to 10548
# At machine Machine 3: Product 0 processed from 10548 to 10578
# At machine Machine 3: Product 0 processed from 10578 to 10608
# At machine Machine 3: Product 0 processed from 10608 to 10638
# At machine Machine 3: Product 0 processed from 10758 to 10788
# At machine Machine 3: Product 0 processed from 10788 to 10818
# At machine Machine 3: Product 0 processed from 10818 to 10848
# At machine Machine 3: Product 0 processed from 10848 to 10878
# At machine Machine 3: Product 0 processed from 10998 to 11028
# At machine Machine 3: Product 0 processed from 11028 to 11058
# At machine Machine 3: Product 0 processed from 11058 to 11088
# At machine Machine 3: Product 0 processed from 11088 to 11118
# At machine Machine 3: Product 0 processed from 11238 to 11268
# At machine Machine 3: Product 0 processed from 11268 to 11298
# At machine Machine 3: Product 0 processed from 11298 to 11328
# At machine Machine 3: Product 0 processed from 11328 to 11358
# At machine Machine 3: Product 0 processed from 11478 to 11508
# At machine Machine 3: Product 0 processed from 11508 to 11538
# At machine Machine 3: Product 0 processed from 11538 to 11568
# At machine Machine 3: Product 0 processed from 11568 to 11598
# At machine Machine 3: Product 0 processed from 11718 to 11748
# At machine Machine 3: Product 0 processed from 11748 to 11778
# At machine Machine 3: Product 0 processed from 11778 to 11808
# At machine Machine 3: Product 0 processed from 11808 to 11838
# At machine Machine 3: Product 0 processed from 11958 to 11988
# At machine Machine 3: Product 0 processed from 11988 to 12018
# At machine Machine 3: Product 0 processed from 12018 to 12048
# At machine Machine 3: Product 0 processed from 12048 to 12078
# At machine Machine 3: Product 0 processed from 12198 to 12228
# At machine Machine 3: Product 0 processed from 12228 to 12258
# At machine Machine 3: Product 0 processed from 12258 to 12288
# At machine Machine 3: Product 0 processed from 12288 to 12318
# At machine Machine 3: Product 1 processed from 12498 to 12543
# At machine Machine 3: Product 1 processed from 12543 to 12573
# At machine Machine 3: Product 1 processed from 12573 to 12603
# At machine Machine 3: Product 1 processed from 12603 to 12633
# At machine Machine 3: Product 1 processed from 12798 to 12828
# At machine Machine 3: Product 1 processed from 12828 to 12858
# At machine Machine 3: Product 1 processed from 12858 to 12888
# At machine Machine 3: Product 1 processed from 12888 to 12918
# At machine Machine 3: Product 1 processed from 13098 to 13128
# At machine Machine 3: Product 1 processed from 13128 to 13158
# At machine Machine 3: Product 1 processed from 13158 to 13188
# At machine Machine 3: Product 1 processed from 13188 to 13218
# At machine Machine 3: Product 1 processed from 13398 to 13428
# At machine Machine 3: Product 1 processed from 13428 to 13458
# At machine Machine 3: Product 1 processed from 13458 to 13488
# At machine Machine 3: Product 1 processed from 13488 to 13518
# Demand Met Log:
# Time 663: Demand for Product 0 met
# Time 693: Demand for Product 0 met
# Time 723: Demand for Product 0 met
# Time 753: Demand for Product 0 met
# Time 888: Demand for Product 0 met
# Time 918: Demand for Product 0 met
# Time 948: Demand for Product 0 met
# Time 978: Demand for Product 0 met
# Time 1128: Demand for Product 0 met
# Time 1158: Demand for Product 0 met
# Time 1188: Demand for Product 0 met
# Time 1218: Demand for Product 0 met
# Time 1368: Demand for Product 0 met
# Time 1398: Demand for Product 0 met
# Time 1428: Demand for Product 0 met
# Time 1458: Demand for Product 0 met
# Time 1608: Demand for Product 0 met
# Time 1638: Demand for Product 0 met
# Time 1668: Demand for Product 0 met
# Time 1698: Demand for Product 0 met
# Time 1848: Demand for Product 0 met
# Time 1878: Demand for Product 0 met
# Time 1908: Demand for Product 0 met
# Time 1938: Demand for Product 0 met
# Time 2088: Demand for Product 0 met
# Time 2118: Demand for Product 0 met
# Time 2148: Demand for Product 0 met
# Time 2178: Demand for Product 0 met
# Time 2328: Demand for Product 0 met
# Time 2358: Demand for Product 0 met
# Time 2388: Demand for Product 0 met
# Time 2418: Demand for Product 0 met
# Time 2568: Demand for Product 0 met
# Time 2598: Demand for Product 0 met
# Time 2628: Demand for Product 0 met
# Time 2658: Demand for Product 0 met
# Time 2808: Demand for Product 0 met
# Time 2838: Demand for Product 0 met
# Time 2868: Demand for Product 0 met
# Time 2898: Demand for Product 0 met
# Time 3048: Demand for Product 0 met
# Time 3078: Demand for Product 0 met
# Time 3108: Demand for Product 0 met
# Time 3138: Demand for Product 0 met
# Time 3288: Demand for Product 0 met
# Time 3318: Demand for Product 0 met
# Time 3348: Demand for Product 0 met
# Time 3378: Demand for Product 0 met
# Time 3528: Demand for Product 0 met
# Time 3558: Demand for Product 0 met
# Time 3588: Demand for Product 0 met
# Time 4383: Demand for Product 1 met
# Time 4428: Demand for Product 0 met
# Time 4473: Demand for Product 1 met
# Time 4518: Demand for Product 0 met
# Time 4563: Demand for Product 1 met
# Time 4608: Demand for Product 0 met
# Time 4653: Demand for Product 1 met
# Time 4698: Demand for Product 0 met
# Time 4743: Demand for Product 1 met
# Time 4788: Demand for Product 0 met
# Time 4833: Demand for Product 1 met
# Time 4863: Demand for Product 1 met
# Time 4939: Demand for Product 0 met
# Time 4969: Demand for Product 0 met
# Time 5014: Demand for Product 1 met
# Time 5059: Demand for Product 0 met
# Time 5509: Demand for Product 1 met
# Time 5554: Demand for Product 0 met
# Time 5599: Demand for Product 1 met
# Time 5644: Demand for Product 0 met
# Time 5689: Demand for Product 1 met
# Time 5734: Demand for Product 0 met
# Time 5779: Demand for Product 1 met
# Time 5824: Demand for Product 0 met
# Time 5869: Demand for Product 1 met
# Time 5914: Demand for Product 0 met
# Time 5959: Demand for Product 1 met
# Time 5989: Demand for Product 1 met
# Time 6155: Demand for Product 0 met
# Time 6185: Demand for Product 0 met
# Time 6230: Demand for Product 1 met
# Time 6275: Demand for Product 0 met
# Time 6501: Demand for Product 1 met
# Time 6546: Demand for Product 0 met
# Time 6591: Demand for Product 1 met
# Time 6621: Demand for Product 1 met
# Time 7041: Demand for Product 0 met
# Time 7071: Demand for Product 0 met
# Time 7116: Demand for Product 1 met
# Time 7161: Demand for Product 0 met
# Time 7206: Demand for Product 1 met
# Time 7251: Demand for Product 0 met
# Time 7296: Demand for Product 1 met
# Time 7341: Demand for Product 0 met
# Time 7386: Demand for Product 1 met
# Time 7431: Demand for Product 0 met
# Time 7476: Demand for Product 1 met
# Time 7521: Demand for Product 0 met
# Time 7821: Demand for Product 1 met
# {'queue0': [[148, 149], [144, 147]], 'queue1': [[], []], 'queue2': [[], []], 'queue3': [[], []], 'queue_fin': [[7866, 7896, 7926, 7956, 7986, 8403, 8433, 8463, 8493, 8628, 8658, 8688, 8718, 8868, 8898, 8928, 8958, 9108, 9138, 9168, 9198, 9348, 9378, 9408, 9438, 9588, 9618, 9648, 9678, 9828, 9858, 9888, 9918, 10068, 10098, 10128, 10158, 10308, 10338, 10368, 10398, 10548, 10578, 10608, 10638, 10788, 10818, 10848, 10878, 11028, 11058, 11088, 11118, 11268, 11298, 11328, 11358, 11508, 11538, 11568, 11598, 11748, 11778, 11808, 11838, 11988, 12018, 12048, 12078, 12228, 12258, 12288, 12318], [8031, 8061, 8091, 8148, 8178, 8208, 8238, 12543, 12573, 12603, 12633, 12828, 12858, 12888, 12918, 13128, 13158, 13188, 13218, 13428, 13458, 13488, 13518]], 'demand': [[], []]}

# %%
import matplotlib.pyplot as plt

# Plotting queue sizes including 'queue_fin'
fig, axes = plt.subplots(6, 1, figsize=(10, 15), sharex=True)  # Share x-axis across all subplots and increase to 5 subplots
fig.suptitle('Queue Sizes Over Time', fontsize=16)

queue_names = ['queue0', 'queue1', 'queue2', 'queue3', 'queue_fin','demand']
colors = ['blue', 'green']
labels = ['Product 0', 'Product 1']

# Determine the global minimum and maximum time across all queues for consistent x-axis
all_times = [log[1] for queue in queue_names for log in production_line.logs[queue]]
global_min_time = min(all_times)
global_max_time = max(all_times)

for i, ax in enumerate(axes):
    for product_type in range(2):
        times = [log[1] for log in production_line.logs[queue_names[i]]]
        sizes = [log[0][product_type] for log in production_line.logs[queue_names[i]]]
        ax.plot(times, sizes, color=colors[product_type], label=f'Product {product_type}')
    ax.set_title(f'{queue_names[i]}')
    ax.set_xlim([global_min_time, global_max_time])  # Set consistent x-axis range
    ax.set_xlabel('Time')
    ax.set_ylabel('Number of Units')
    ax.legend()

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
# Setup for Gantt chart plotting using matplotlib
fig, axs = plt.subplots(4, 1, figsize=(14, 10), sharex=True)
fig.suptitle('Gantt Chart for Production Line')

# Color coding for products and setups
colors = {0: 'skyblue', 1: 'lightgreen', 'setup': 'grey'}

machines = ['machine0', 'machine1', 'machine2', 'machine3']
machine_names = ['Batch Machine 0', 'Machine 1', 'Batch Machine 2', 'Machine 3']

# Plot each machine's activities
for ax, machine_name, name in zip(axs, machines, machine_names):
    machine = getattr(production_line, machine_name)
    y = 0
    for log in machine.event_log:
        if len(log) == 4:  # BatchProcessingMachine or Machine with setup
            product, current_time, start_time, finish_time = log
            # Calculate setup time and process time
            setup_time = start_time - current_time
            process_time = finish_time - start_time
            # Plot setup time if exists
            if setup_time > 0:
                ax.broken_barh([(current_time, setup_time)], (y, 0.8), facecolors='grey', edgecolor='black', linewidth=0.5)
            # Plot process time
            ax.broken_barh([(start_time, process_time)], (y, 0.8), facecolors=colors[product], edgecolor='black', linewidth=0.5)
        else:  # For single product processing without batch
            product, current_time, finish_time, _ = log
            process_time = finish_time - current_time
            ax.broken_barh([(current_time, process_time)], (y, 0.8), facecolors=colors[product], edgecolor='black', linewidth=0.5)
    ax.set_ylim(-0.5, 1.5)
    ax.set_yticks([0])
    ax.set_yticklabels([name])
    ax.grid(True)

# Create legend for product colors
patches = [mpatches.Patch(color=colors[key], label=f'Product {key}' if key != 'setup' else 'Setup Time') for key in colors]
fig.legend(handles=patches, loc='upper right')

plt.xlabel('Time')
plt.tight_layout(rect=[0, 0, 1, 0.95])  # Adjust layout to make room for title
plt.show()

# %%
#Next steps
# 1) Introduce a demand forecast into the state space and reward it for meeting future excess demand
# 2) See if it can switch demand patterns quickly 
# 3) Q-learning implementaion to achive the same result
# 4) Write a LP program of this

# %%
queues = {'queue0': [[], []], 'queue1': [[], []], 'queue2': [[], []], 'queue3': [[], []],'queue_fin': [[], []],'demand': [[10,12], [23,45,54]]}
print(len(queues['demand'][0])+len(queues['demand'][1]))
for product_type in range(2):
    print(product_type)
