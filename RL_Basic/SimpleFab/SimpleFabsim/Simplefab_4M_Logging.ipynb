# %%
import random
import pandas as pd

# Map product names to identifiers
product_id_mapping = {'Product 1': 0, 'Product 2': 1}

def generate_events_fixed(quantity, interval, time_period, product_id, event_type):
    """Generate events at fixed intervals with a fixed quantity over a specified time period."""
    num_events = time_period // interval
    times = [i * interval for i in range(num_events)]
    quantities = [quantity] * num_events
    return pd.DataFrame({'Time': times, 'Quantity': quantities, 'Product': product_id, 'Type': event_type})

def generate_events_random(num_events, time_period, max_quantity, product_id, event_type):
    """Generate random events over a specified time period."""
    times = sorted([random.randint(0, time_period) for _ in range(num_events)])
    quantities = [random.randint(1, max_quantity) for _ in range(num_events)]
    return pd.DataFrame({'Time': times, 'Quantity': quantities, 'Product': product_id, 'Type': event_type})

def simulate_events(time_period, product_settings):
    arrivals = []
    demands = []
    for config_name, settings in product_settings.items():
        # Extract the product name (excluding the event type) and map it to its numeric identifier
        product_name = ' '.join(config_name.split()[:-1])
        product_id = product_id_mapping[product_name]
        
        # Generate either fixed or random events for each product
        if settings['interval_type'] == 'fixed':
            df = generate_events_fixed(settings['quantity'], settings['interval'], time_period, product_id, settings['event_type'])
        else:  # Random generation
            num_events = random.randint(10, 20)
            df = generate_events_random(num_events, time_period, settings['max_quantity'], product_id, settings['event_type'])
        
        if settings['event_type'] == 'Arrival':
            arrivals.append(df)
        else:
            demands.append(df)
    
    # Combine all events into separate DataFrames for arrivals and demands, and sort by time
    arrivals_df = pd.concat(arrivals).sort_values('Time').reset_index(drop=True) if arrivals else pd.DataFrame()
    demands_df = pd.concat(demands).sort_values('Time').reset_index(drop=True) if demands else pd.DataFrame()
    return arrivals_df, demands_df

# Set the simulation time period
time_period = 100

# Configuration for each product and event type
product_settings = {
    'Product 1 Arrival': {'event_type': 'Arrival', 'interval_type': 'fixed', 'quantity': 1,'interval': 1},
    'Product 2 Arrival': {'event_type': 'Arrival', 'interval_type': 'fixed', 'quantity': 1, 'interval': 1},
    'Product 1 Demand': {'event_type': 'Demand', 'interval_type': 'fixed', 'quantity': 1, 'interval': 1},
    'Product 2 Demand': {'event_type': 'Demand', 'interval_type': 'fixed', 'quantity': 1, 'interval': 1},
}

# Simulate events for Arrivals and Demands
arrivals_df, demands_df = simulate_events(time_period, product_settings)

# Display the events for Arrivals and Demands
print("Arrivals:")
print(arrivals_df)
print("\nDemands:")
print(demands_df)

#'Product 2 Arrival': {'event_type': 'Arrival', 'interval_type': 'random', 'max_quantity': 5},
# Out:
# Arrivals:
#      Time  Quantity  Product     Type
# 0       0         1        0  Arrival
# 1       0         1        1  Arrival
# 2       1         1        0  Arrival
# 3       1         1        1  Arrival
# 4       2         1        0  Arrival
# ..    ...       ...      ...      ...
# 195    97         1        0  Arrival
# 196    98         1        1  Arrival
# 197    98         1        0  Arrival
# 198    99         1        0  Arrival
# 199    99         1        1  Arrival
#
# [200 rows x 4 columns]
#
# Demands:
#      Time  Quantity  Product    Type
# 0       0         1        0  Demand
# 1       0         1        1  Demand
# 2       1         1        0  Demand
# 3       1         1        1  Demand
# 4       2         1        0  Demand
# ..    ...       ...      ...     ...
# 195    97         1        0  Demand
# 196    98         1        1  Demand
# 197    98         1        0  Demand
# 198    99         1        0  Demand
# 199    99         1        1  Demand
#
# [200 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import numpy as np
from IPython.display import HTML
import os
import matplotlib.pyplot as plt
import plotly.express as px

# %%
class BatchProcessingMachine:
    def __init__(self, processing_times, batch_size):
        self.processing_times = processing_times
        self.batch_size = batch_size
        self.current_product = None
        self.finish_time = 0
        self.busy = False
        self.event_log = []

    def process(self, product, current_time):
        self.busy = True
        self.finish_time = current_time + self.processing_times[product]
        self.current_product = product
        self.event_log.append((self.current_product, current_time, self.finish_time, self.batch_size))
        return self.finish_time

    def update(self, current_time):
        if current_time >= self.finish_time and self.busy:
            self.busy = False
            return self.current_product
        return False
    
    def print_event_log(self, machine_name):
        for event in self.event_log:
            print(f"At machine {machine_name}: Batch of Product {event[0]} processed from {event[1]} to {event[2]}")

# %%
class Machine:
    def __init__(self, processing_times, setup_times):
        self.processing_times = processing_times
        self.setup_times = setup_times
        self.current_product = None
        self.finish_time = 0
        self.busy = False
        self.event_log = []

    def process(self, product, current_time):
        if self.current_product is not None:
            setup_time = self.setup_times[self.current_product][product]
        else:
            setup_time = self.setup_times[None][product]  # Use the setup time from 'None' to the new product
        self.current_product = product
        start_time = current_time + setup_time
        self.finish_time = start_time + self.processing_times[product]
        self.busy = True
        self.event_log.append((product, current_time, start_time, self.finish_time))
        return self.finish_time

    def update(self, current_time):
        if current_time >= self.finish_time and self.busy:
            self.busy = False
            return self.current_product
        return None

    def print_event_log(self, machine_name):
        for event in self.event_log:
            print(f"At machine {machine_name}: Product {event[0]} processed from {event[1]} to {event[3]}")

# %%
import os
class ProductionLine:
    def __init__(self, batch_machine0_times, machine1_times, machine1_setups, batch_machine2_times, machine3_times, machine3_setups, 
                 arrivals_df,demands_df):
        self.machine0 = BatchProcessingMachine(batch_machine0_times, 4)
        self.machine1 = Machine(machine1_times, machine1_setups)
        self.machine2 = BatchProcessingMachine(batch_machine2_times, 4)
        self.machine3 = Machine(machine3_times, machine3_setups)
        self.arrivals_df = arrivals_df
        self.demands_df = demands_df
        self.queues = {'queue0': [[], []], 'queue1': [[], []], 'queue2': [[], []], 'queue3': [[], []],'queue_fin': [[], []],'demand': [[], []]}
        self.logs = {key: [] for key in self.queues}  # Initialize logs for each queue
        self.demand_met_log = []
        self.event_log = []  # Log for capturing all event details

    def add_item_to_queue(self, queue_name, product_name, current_time):
        if queue_name == 'queue_fin':
            # Check if there is demand for this product
            if len(self.queues['demand'][product_name]) > 0:
                self.queues['demand'][product_name].pop(0)  # Remove one demand unit
                self.demand_met_log.append((product_name, current_time))  # Log the demand fulfillment
                queue_sizes = [len(q) for q in self.queues['demand']]
                self.logs['demand'].append((queue_sizes, current_time))
                self.log_current_state(current_time)
                return  # Demand fulfilled, no need to add to queue_fin        
        self.queues[queue_name][product_name].append(current_time)
        queue_sizes = [len(q) for q in self.queues[queue_name]]
        self.logs[queue_name].append((queue_sizes, current_time))
        #self.log_current_state(current_time)

    def log_current_state(self, current_time):
        # Log queue sizes and current products in machines
        log_entry = {
            'Time': current_time,
            'Queue 0 Product 0': len(self.queues['queue0'][0]),
            'Queue 0 Product 1': len(self.queues['queue0'][1]),
            'Queue 1 Product 0': len(self.queues['queue1'][0]),
            'Queue 1 Product 1': len(self.queues['queue1'][1]),
            'Queue 2 Product 0': len(self.queues['queue2'][0]),
            'Queue 2 Product 1': len(self.queues['queue2'][1]),
            'Queue 3 Product 0': len(self.queues['queue3'][0]),
            'Queue 3 Product 1': len(self.queues['queue3'][1]),
            'Demand Queue Product 0': len(self.queues['demand'][0]),
            'Demand Queue Product 1': len(self.queues['demand'][1]),
            'Machine 1 Current Product': 'None' if self.machine1.current_product is None else self.machine1.current_product,
            'Machine 3 Current Product': 'None' if self.machine3.current_product is None else self.machine3.current_product
        }
        self.event_log.append(log_entry)


    def run_step(self, current_time):
        # Handle product arrivals from the DataFrame
        arrivals_this_step = self.arrivals_df[self.arrivals_df['Time'] == current_time]
        for _, row in arrivals_this_step.iterrows():
            self.add_item_to_queue('queue0', row['Product'], current_time)

        # Handle product demand from the DataFrame
        demand_this_step = self.demands_df[self.demands_df['Time'] == current_time]
        for _, row in demand_this_step.iterrows():
            self.add_item_to_queue('demand', row['Product'], current_time)
        
        # Process batches in Machine 0
        for product_type in range(2):
            # When current processing lot is completed
            if current_time >= self.machine0.finish_time and self.machine0.busy:
                finished_product = self.machine0.update(current_time)
                # Transfer the whole batch to the next queue
                for i in range(self.machine0.batch_size):
                    self.add_item_to_queue('queue1', finished_product, current_time)
            total_demand_length = len(self.queues['demand'][0]) + len(self.queues['demand'][1])
            queue_ratio = 0.5 if total_demand_length == 0 else len(self.queues['demand'][product_type]) / total_demand_length  
            #print(f'currenttime is:{current_time} and queue ratio is: {queue_ratio}')
            # Checking if new batch can be started on the machine
            while len(self.queues['queue0'][product_type]) >= self.machine0.batch_size and not self.machine0.busy and queue_ratio >= 0.5:
                temp = len(self.queues['demand'][product_type])
                #print(f'I have entered the loop at time{current_time} machine 0 to produce {product_type} as queue ratio is {queue_ratio}, total demand is {total_demand_length} and length of product quueue is {temp}')
                # Batch is full and machine is not busy
                finish_time = self.machine0.process(product_type,current_time)  # Process batch
                self.queues['queue0'][product_type] = self.queues['queue0'][product_type][self.machine0.batch_size:]
                #logging
                queue_sizes = [len(q) for q in self.queues['queue0']]
                self.logs['queue0'].append((queue_sizes, current_time))
                #self.log_current_state(current_time)

        # Process products at Machine 1
        for product_type in range(2):
            # When current processing lot is completed
            if current_time >= self.machine1.finish_time and self.machine1.busy:
                finished_product1 = self.machine1.update(current_time)
                if finished_product1 is not None:  # Move to next queue if not the last machine
                    self.add_item_to_queue('queue2', finished_product1, current_time)
            total_demand_length = len(self.queues['demand'][0]) + len(self.queues['demand'][1])
            queue_ratio = 0.5 if total_demand_length == 0 else len(self.queues['demand'][product_type]) / total_demand_length  
            # Checking if new product can be started on the machine
            if self.queues['queue1'][product_type] and not self.machine1.busy and queue_ratio >= 0.5:
                product_time = self.queues['queue1'][product_type].pop(0)
                self.machine1.process(product_type, current_time)
                #logging
                queue_sizes = [len(q) for q in self.queues['queue1']]
                self.logs['queue1'].append((queue_sizes, current_time))
                #self.log_current_state(current_time)

        # Process batches in Machine 2
        for product_type in range(2):
            # When current processing lot is completed
            if current_time >= self.machine2.finish_time and self.machine2.busy:
                finished_product2 = self.machine2.update(current_time)
                # Transfer the whole batch to the next queue
                for i in range(self.machine2.batch_size):
                    self.add_item_to_queue('queue3', finished_product2, current_time)
            total_demand_length = len(self.queues['demand'][0]) + len(self.queues['demand'][1])
            queue_ratio = 0.5 if total_demand_length == 0 else len(self.queues['demand'][product_type]) / total_demand_length  
            # Checking if new batch can be started on the machine
            while len(self.queues['queue2'][product_type]) >= self.machine2.batch_size and not self.machine2.busy and queue_ratio >= 0.5:
                # Batch is full and machine is not busy
                finish_time = self.machine2.process(product_type,current_time)  # Process batch
                self.queues['queue2'][product_type] = self.queues['queue2'][product_type][self.machine2.batch_size:]
                #logging
                queue_sizes = [len(q) for q in self.queues['queue2']]
                self.logs['queue2'].append((queue_sizes, current_time))
                #self.log_current_state(current_time)        
        
        # Process products at Machine 3
        for product_type in range(2):
            # When current processing lot is completed
            if current_time >= self.machine3.finish_time and self.machine3.busy:
                finished_product3 = self.machine3.update(current_time)
                if finished_product3 is not None:  # Move to next queue if not the last machine
                    self.add_item_to_queue('queue_fin', finished_product3, current_time)
            total_demand_length = len(self.queues['demand'][0]) + len(self.queues['demand'][1])
            queue_ratio = 0.5 if total_demand_length == 0 else len(self.queues['demand'][product_type]) / total_demand_length          
            # Checking if new product can be started on the machine
            if self.queues['queue3'][product_type] and not self.machine3.busy and queue_ratio >= 0.5:
                product_time = self.queues['queue3'][product_type].pop(0)
                self.machine3.process(product_type, current_time)
                #logging
                queue_sizes = [len(q) for q in self.queues['queue3']]
                self.logs['queue3'].append((queue_sizes, current_time))
                #self.log_current_state(current_time)

        self.log_current_state(current_time)

    def print_demand_met_log(self):
        print("Demand Met Log:")
        for log in self.demand_met_log:
            print(f"Time {log[1]}: Demand for Product {log[0]} met")
    
    def print_logs(self):
        # Printing logs for all queues
        for key in self.queues:
            print(f"{key} Event Log:")
            for log in self.logs[key]:
                print(f"Time {log[1]}: Queue Sizes - Product 0: {log[0][0]}, Product 1: {log[0][1]}")

        # Print machine logs
        print("\nMachine Logs:")
        machine_names = ['Machine 0', 'Machine 1', 'Machine 2', 'Machine 3']
        for i in range(4):
            machine = getattr(self, f'machine{i}')
            machine.print_event_log(machine_names[i])

        self.print_demand_met_log()  # Print the demand met logs

# Example simulation setup
production_line = ProductionLine({0: 240, 1:300}, {0: 30, 1: 30}, {None: {0: 15, 1: 15}, 0: {0: 0, 1: 15}, 1: {0: 15, 1: 0}},
                                {0: 240, 1:300}, {0: 30, 1: 30}, {None: {0: 15, 1: 15}, 0: {0: 0, 1: 15}, 1: {0: 15, 1: 0}}, arrivals_df,demands_df)

for current_time in range(20000):
    production_line.run_step(current_time)
production_line.print_logs()
print(production_line.queues)

# After the simulation, create a DataFrame from the logs
event_log_df = pd.DataFrame(production_line.event_log)
#print(event_log_df)

# Get the current directory where your Python script is located
current_directory = os.getcwd()

# Define the new folder name and path
new_folder = "output_data"
new_folder_path = os.path.join(current_directory, new_folder)

# Create the new folder if it doesn't exist
if not os.path.exists(new_folder_path):
    os.makedirs(new_folder_path)

# Define the filename and complete path
file_name = "final_event_log.csv"
file_path = os.path.join(new_folder_path, file_name)

event_log_df.to_csv(file_path, index=False)
# Out:
# queue0 Event Log:
# Time 0: Queue Sizes - Product 0: 1, Product 1: 0
# Time 0: Queue Sizes - Product 0: 1, Product 1: 1
# Time 1: Queue Sizes - Product 0: 2, Product 1: 1
# Time 1: Queue Sizes - Product 0: 2, Product 1: 2
# Time 2: Queue Sizes - Product 0: 3, Product 1: 2
# Time 2: Queue Sizes - Product 0: 3, Product 1: 3
# Time 3: Queue Sizes - Product 0: 4, Product 1: 3
# Time 3: Queue Sizes - Product 0: 4, Product 1: 4
# Time 3: Queue Sizes - Product 0: 0, Product 1: 4
# Time 4: Queue Sizes - Product 0: 1, Product 1: 4
# Time 4: Queue Sizes - Product 0: 1, Product 1: 5
# Time 5: Queue Sizes - Product 0: 1, Product 1: 6
# Time 5: Queue Sizes - Product 0: 2, Product 1: 6
# Time 6: Queue Sizes - Product 0: 3, Product 1: 6
# Time 6: Queue Sizes - Product 0: 3, Product 1: 7
# Time 7: Queue Sizes - Product 0: 3, Product 1: 8
# Time 7: Queue Sizes - Product 0: 4, Product 1: 8
# Time 8: Queue Sizes - Product 0: 4, Product 1: 9
# Time 8: Queue Sizes - Product 0: 5, Product 1: 9
# Time 9: Queue Sizes - Product 0: 5, Product 1: 10
# Time 9: Queue Sizes - Product 0: 6, Product 1: 10
# Time 10: Queue Sizes - Product 0: 6, Product 1: 11
# Time 10: Queue Sizes - Product 0: 7, Product 1: 11
# Time 11: Queue Sizes - Product 0: 8, Product 1: 11
# Time 11: Queue Sizes - Product 0: 8, Product 1: 12
# Time 12: Queue Sizes - Product 0: 9, Product 1: 12
# Time 12: Queue Sizes - Product 0: 9, Product 1: 13
# Time 13: Queue Sizes - Product 0: 10, Product 1: 13
# Time 13: Queue Sizes - Product 0: 10, Product 1: 14
# Time 14: Queue Sizes - Product 0: 11, Product 1: 14
# Time 14: Queue Sizes - Product 0: 11, Product 1: 15
# Time 15: Queue Sizes - Product 0: 11, Product 1: 16
# Time 15: Queue Sizes - Product 0: 12, Product 1: 16
# Time 16: Queue Sizes - Product 0: 12, Product 1: 17
# Time 16: Queue Sizes - Product 0: 13, Product 1: 17
# Time 17: Queue Sizes - Product 0: 13, Product 1: 18
# Time 17: Queue Sizes - Product 0: 14, Product 1: 18
# Time 18: Queue Sizes - Product 0: 15, Product 1: 18
# Time 18: Queue Sizes - Product 0: 15, Product 1: 19
# Time 19: Queue Sizes - Product 0: 15, Product 1: 20
# Time 19: Queue Sizes - Product 0: 16, Product 1: 20
# Time 20: Queue Sizes - Product 0: 17, Product 1: 20
# Time 20: Queue Sizes - Product 0: 17, Product 1: 21
# Time 21: Queue Sizes - Product 0: 18, Product 1: 21
# Time 21: Queue Sizes - Product 0: 18, Product 1: 22
# Time 22: Queue Sizes - Product 0: 18, Product 1: 23
# Time 22: Queue Sizes - Product 0: 19, Product 1: 23
# Time 23: Queue Sizes - Product 0: 20, Product 1: 23
# Time 23: Queue Sizes - Product 0: 20, Product 1: 24
# Time 24: Queue Sizes - Product 0: 21, Product 1: 24
# Time 24: Queue Sizes - Product 0: 21, Product 1: 25
# Time 25: Queue Sizes - Product 0: 22, Product 1: 25
# Time 25: Queue Sizes - Product 0: 22, Product 1: 26
# Time 26: Queue Sizes - Product 0: 23, Product 1: 26
# Time 26: Queue Sizes - Product 0: 23, Product 1: 27
# Time 27: Queue Sizes - Product 0: 23, Product 1: 28
# Time 27: Queue Sizes - Product 0: 24, Product 1: 28
# Time 28: Queue Sizes - Product 0: 25, Product 1: 28
# Time 28: Queue Sizes - Product 0: 25, Product 1: 29
# Time 29: Queue Sizes - Product 0: 25, Product 1: 30
# Time 29: Queue Sizes - Product 0: 26, Product 1: 30
# Time 30: Queue Sizes - Product 0: 26, Product 1: 31
# Time 30: Queue Sizes - Product 0: 27, Product 1: 31
# Time 31: Queue Sizes - Product 0: 27, Product 1: 32
# Time 31: Queue Sizes - Product 0: 28, Product 1: 32
# Time 32: Queue Sizes - Product 0: 28, Product 1: 33
# Time 32: Queue Sizes - Product 0: 29, Product 1: 33
# Time 33: Queue Sizes - Product 0: 30, Product 1: 33
# Time 33: Queue Sizes - Product 0: 30, Product 1: 34
# Time 34: Queue Sizes - Product 0: 30, Product 1: 35
# Time 34: Queue Sizes - Product 0: 31, Product 1: 35
# Time 35: Queue Sizes - Product 0: 31, Product 1: 36
# Time 35: Queue Sizes - Product 0: 32, Product 1: 36
# Time 36: Queue Sizes - Product 0: 32, Product 1: 37
# Time 36: Queue Sizes - Product 0: 33, Product 1: 37
# Time 37: Queue Sizes - Product 0: 33, Product 1: 38
# Time 37: Queue Sizes - Product 0: 34, Product 1: 38
# Time 38: Queue Sizes - Product 0: 35, Product 1: 38
# Time 38: Queue Sizes - Product 0: 35, Product 1: 39
# Time 39: Queue Sizes - Product 0: 36, Product 1: 39
# Time 39: Queue Sizes - Product 0: 36, Product 1: 40
# Time 40: Queue Sizes - Product 0: 37, Product 1: 40
# Time 40: Queue Sizes - Product 0: 37, Product 1: 41
# Time 41: Queue Sizes - Product 0: 37, Product 1: 42
# Time 41: Queue Sizes - Product 0: 38, Product 1: 42
# Time 42: Queue Sizes - Product 0: 39, Product 1: 42
# Time 42: Queue Sizes - Product 0: 39, Product 1: 43
# Time 43: Queue Sizes - Product 0: 39, Product 1: 44
# Time 43: Queue Sizes - Product 0: 40, Product 1: 44
# Time 44: Queue Sizes - Product 0: 41, Product 1: 44
# Time 44: Queue Sizes - Product 0: 41, Product 1: 45
# Time 45: Queue Sizes - Product 0: 42, Product 1: 45
# Time 45: Queue Sizes - Product 0: 42, Product 1: 46
# Time 46: Queue Sizes - Product 0: 42, Product 1: 47
# Time 46: Queue Sizes - Product 0: 43, Product 1: 47
# Time 47: Queue Sizes - Product 0: 44, Product 1: 47
# Time 47: Queue Sizes - Product 0: 44, Product 1: 48
# Time 48: Queue Sizes - Product 0: 44, Product 1: 49
# Time 48: Queue Sizes - Product 0: 45, Product 1: 49
# Time 49: Queue Sizes - Product 0: 45, Product 1: 50
# Time 49: Queue Sizes - Product 0: 46, Product 1: 50
# Time 50: Queue Sizes - Product 0: 46, Product 1: 51
# Time 50: Queue Sizes - Product 0: 47, Product 1: 51
# Time 51: Queue Sizes - Product 0: 48, Product 1: 51
# Time 51: Queue Sizes - Product 0: 48, Product 1: 52
# Time 52: Queue Sizes - Product 0: 48, Product 1: 53
# Time 52: Queue Sizes - Product 0: 49, Product 1: 53
# Time 53: Queue Sizes - Product 0: 50, Product 1: 53
# Time 53: Queue Sizes - Product 0: 50, Product 1: 54
# Time 54: Queue Sizes - Product 0: 50, Product 1: 55
# Time 54: Queue Sizes - Product 0: 51, Product 1: 55
# Time 55: Queue Sizes - Product 0: 51, Product 1: 56
# Time 55: Queue Sizes - Product 0: 52, Product 1: 56
# Time 56: Queue Sizes - Product 0: 52, Product 1: 57
# Time 56: Queue Sizes - Product 0: 53, Product 1: 57
# Time 57: Queue Sizes - Product 0: 53, Product 1: 58
# Time 57: Queue Sizes - Product 0: 54, Product 1: 58
# Time 58: Queue Sizes - Product 0: 54, Product 1: 59
# Time 58: Queue Sizes - Product 0: 55, Product 1: 59
# Time 59: Queue Sizes - Product 0: 56, Product 1: 59
# Time 59: Queue Sizes - Product 0: 56, Product 1: 60
# Time 60: Queue Sizes - Product 0: 56, Product 1: 61
# Time 60: Queue Sizes - Product 0: 57, Product 1: 61
# Time 61: Queue Sizes - Product 0: 57, Product 1: 62
# Time 61: Queue Sizes - Product 0: 58, Product 1: 62
# Time 62: Queue Sizes - Product 0: 59, Product 1: 62
# Time 62: Queue Sizes - Product 0: 59, Product 1: 63
# Time 63: Queue Sizes - Product 0: 60, Product 1: 63
# Time 63: Queue Sizes - Product 0: 60, Product 1: 64
# Time 64: Queue Sizes - Product 0: 61, Product 1: 64
# Time 64: Queue Sizes - Product 0: 61, Product 1: 65
# Time 65: Queue Sizes - Product 0: 61, Product 1: 66
# Time 65: Queue Sizes - Product 0: 62, Product 1: 66
# Time 66: Queue Sizes - Product 0: 63, Product 1: 66
# Time 66: Queue Sizes - Product 0: 63, Product 1: 67
# Time 67: Queue Sizes - Product 0: 63, Product 1: 68
# Time 67: Queue Sizes - Product 0: 64, Product 1: 68
# Time 68: Queue Sizes - Product 0: 64, Product 1: 69
# Time 68: Queue Sizes - Product 0: 65, Product 1: 69
# Time 69: Queue Sizes - Product 0: 65, Product 1: 70
# Time 69: Queue Sizes - Product 0: 66, Product 1: 70
# Time 70: Queue Sizes - Product 0: 67, Product 1: 70
# Time 70: Queue Sizes - Product 0: 67, Product 1: 71
# Time 71: Queue Sizes - Product 0: 68, Product 1: 71
# Time 71: Queue Sizes - Product 0: 68, Product 1: 72
# Time 72: Queue Sizes - Product 0: 69, Product 1: 72
# Time 72: Queue Sizes - Product 0: 69, Product 1: 73
# Time 73: Queue Sizes - Product 0: 69, Product 1: 74
# Time 73: Queue Sizes - Product 0: 70, Product 1: 74
# Time 74: Queue Sizes - Product 0: 71, Product 1: 74
# Time 74: Queue Sizes - Product 0: 71, Product 1: 75
# Time 75: Queue Sizes - Product 0: 71, Product 1: 76
# Time 75: Queue Sizes - Product 0: 72, Product 1: 76
# Time 76: Queue Sizes - Product 0: 73, Product 1: 76
# Time 76: Queue Sizes - Product 0: 73, Product 1: 77
# Time 77: Queue Sizes - Product 0: 73, Product 1: 78
# Time 77: Queue Sizes - Product 0: 74, Product 1: 78
# Time 78: Queue Sizes - Product 0: 75, Product 1: 78
# Time 78: Queue Sizes - Product 0: 75, Product 1: 79
# Time 79: Queue Sizes - Product 0: 75, Product 1: 80
# Time 79: Queue Sizes - Product 0: 76, Product 1: 80
# Time 80: Queue Sizes - Product 0: 76, Product 1: 81
# Time 80: Queue Sizes - Product 0: 77, Product 1: 81
# Time 81: Queue Sizes - Product 0: 77, Product 1: 82
# Time 81: Queue Sizes - Product 0: 78, Product 1: 82
# Time 82: Queue Sizes - Product 0: 79, Product 1: 82
# Time 82: Queue Sizes - Product 0: 79, Product 1: 83
# Time 83: Queue Sizes - Product 0: 79, Product 1: 84
# Time 83: Queue Sizes - Product 0: 80, Product 1: 84
# Time 84: Queue Sizes - Product 0: 80, Product 1: 85
# Time 84: Queue Sizes - Product 0: 81, Product 1: 85
# Time 85: Queue Sizes - Product 0: 81, Product 1: 86
# Time 85: Queue Sizes - Product 0: 82, Product 1: 86
# Time 86: Queue Sizes - Product 0: 83, Product 1: 86
# Time 86: Queue Sizes - Product 0: 83, Product 1: 87
# Time 87: Queue Sizes - Product 0: 83, Product 1: 88
# Time 87: Queue Sizes - Product 0: 84, Product 1: 88
# Time 88: Queue Sizes - Product 0: 84, Product 1: 89
# Time 88: Queue Sizes - Product 0: 85, Product 1: 89
# Time 89: Queue Sizes - Product 0: 85, Product 1: 90
# Time 89: Queue Sizes - Product 0: 86, Product 1: 90
# Time 90: Queue Sizes - Product 0: 86, Product 1: 91
# Time 90: Queue Sizes - Product 0: 87, Product 1: 91
# Time 91: Queue Sizes - Product 0: 87, Product 1: 92
# Time 91: Queue Sizes - Product 0: 88, Product 1: 92
# Time 92: Queue Sizes - Product 0: 88, Product 1: 93
# Time 92: Queue Sizes - Product 0: 89, Product 1: 93
# Time 93: Queue Sizes - Product 0: 89, Product 1: 94
# Time 93: Queue Sizes - Product 0: 90, Product 1: 94
# Time 94: Queue Sizes - Product 0: 91, Product 1: 94
# Time 94: Queue Sizes - Product 0: 91, Product 1: 95
# Time 95: Queue Sizes - Product 0: 91, Product 1: 96
# Time 95: Queue Sizes - Product 0: 92, Product 1: 96
# Time 96: Queue Sizes - Product 0: 92, Product 1: 97
# Time 96: Queue Sizes - Product 0: 93, Product 1: 97
# Time 97: Queue Sizes - Product 0: 93, Product 1: 98
# Time 97: Queue Sizes - Product 0: 94, Product 1: 98
# Time 98: Queue Sizes - Product 0: 94, Product 1: 99
# Time 98: Queue Sizes - Product 0: 95, Product 1: 99
# Time 99: Queue Sizes - Product 0: 96, Product 1: 99
# Time 99: Queue Sizes - Product 0: 96, Product 1: 100
# Time 243: Queue Sizes - Product 0: 92, Product 1: 100
# Time 483: Queue Sizes - Product 0: 88, Product 1: 100
# Time 723: Queue Sizes - Product 0: 88, Product 1: 96
# Time 1023: Queue Sizes - Product 0: 88, Product 1: 92
# Time 1323: Queue Sizes - Product 0: 88, Product 1: 88
# Time 1623: Queue Sizes - Product 0: 84, Product 1: 88
# Time 1863: Queue Sizes - Product 0: 84, Product 1: 84
# Time 2163: Queue Sizes - Product 0: 80, Product 1: 84
# Time 2403: Queue Sizes - Product 0: 76, Product 1: 84
# Time 2643: Queue Sizes - Product 0: 72, Product 1: 84
# Time 2883: Queue Sizes - Product 0: 68, Product 1: 84
# Time 3123: Queue Sizes - Product 0: 64, Product 1: 84
# Time 3363: Queue Sizes - Product 0: 64, Product 1: 80
# Time 3663: Queue Sizes - Product 0: 64, Product 1: 76
# Time 3963: Queue Sizes - Product 0: 64, Product 1: 72
# Time 4263: Queue Sizes - Product 0: 60, Product 1: 72
# Time 4503: Queue Sizes - Product 0: 60, Product 1: 68
# Time 4803: Queue Sizes - Product 0: 56, Product 1: 68
# Time 5043: Queue Sizes - Product 0: 52, Product 1: 68
# Time 5283: Queue Sizes - Product 0: 48, Product 1: 68
# Time 5523: Queue Sizes - Product 0: 44, Product 1: 68
# Time 5763: Queue Sizes - Product 0: 40, Product 1: 68
# Time 6003: Queue Sizes - Product 0: 40, Product 1: 64
# Time 6303: Queue Sizes - Product 0: 40, Product 1: 60
# Time 6603: Queue Sizes - Product 0: 40, Product 1: 56
# Time 6903: Queue Sizes - Product 0: 36, Product 1: 56
# Time 7143: Queue Sizes - Product 0: 36, Product 1: 52
# Time 7443: Queue Sizes - Product 0: 32, Product 1: 52
# Time 7683: Queue Sizes - Product 0: 28, Product 1: 52
# Time 7923: Queue Sizes - Product 0: 24, Product 1: 52
# Time 8163: Queue Sizes - Product 0: 20, Product 1: 52
# Time 8403: Queue Sizes - Product 0: 16, Product 1: 52
# Time 8643: Queue Sizes - Product 0: 16, Product 1: 48
# Time 8943: Queue Sizes - Product 0: 16, Product 1: 44
# Time 9243: Queue Sizes - Product 0: 16, Product 1: 40
# Time 9543: Queue Sizes - Product 0: 12, Product 1: 40
# Time 9783: Queue Sizes - Product 0: 12, Product 1: 36
# Time 10083: Queue Sizes - Product 0: 8, Product 1: 36
# Time 10323: Queue Sizes - Product 0: 4, Product 1: 36
# Time 10563: Queue Sizes - Product 0: 0, Product 1: 36
# Time 10836: Queue Sizes - Product 0: 0, Product 1: 32
# Time 11136: Queue Sizes - Product 0: 0, Product 1: 28
# Time 11436: Queue Sizes - Product 0: 0, Product 1: 24
# Time 11736: Queue Sizes - Product 0: 0, Product 1: 20
# Time 12036: Queue Sizes - Product 0: 0, Product 1: 16
# Time 12457: Queue Sizes - Product 0: 0, Product 1: 12
# Time 12757: Queue Sizes - Product 0: 0, Product 1: 8
# Time 13057: Queue Sizes - Product 0: 0, Product 1: 4
# Time 13357: Queue Sizes - Product 0: 0, Product 1: 0
# queue1 Event Log:
# Time 243: Queue Sizes - Product 0: 1, Product 1: 0
# Time 243: Queue Sizes - Product 0: 2, Product 1: 0
# Time 243: Queue Sizes - Product 0: 3, Product 1: 0
# Time 243: Queue Sizes - Product 0: 4, Product 1: 0
# Time 243: Queue Sizes - Product 0: 3, Product 1: 0
# Time 288: Queue Sizes - Product 0: 2, Product 1: 0
# Time 318: Queue Sizes - Product 0: 1, Product 1: 0
# Time 348: Queue Sizes - Product 0: 0, Product 1: 0
# Time 483: Queue Sizes - Product 0: 1, Product 1: 0
# Time 483: Queue Sizes - Product 0: 2, Product 1: 0
# Time 483: Queue Sizes - Product 0: 3, Product 1: 0
# Time 483: Queue Sizes - Product 0: 4, Product 1: 0
# Time 483: Queue Sizes - Product 0: 3, Product 1: 0
# Time 513: Queue Sizes - Product 0: 2, Product 1: 0
# Time 543: Queue Sizes - Product 0: 1, Product 1: 0
# Time 573: Queue Sizes - Product 0: 0, Product 1: 0
# Time 723: Queue Sizes - Product 0: 1, Product 1: 0
# Time 723: Queue Sizes - Product 0: 2, Product 1: 0
# Time 723: Queue Sizes - Product 0: 3, Product 1: 0
# Time 723: Queue Sizes - Product 0: 4, Product 1: 0
# Time 1023: Queue Sizes - Product 0: 4, Product 1: 1
# Time 1023: Queue Sizes - Product 0: 4, Product 1: 2
# Time 1023: Queue Sizes - Product 0: 4, Product 1: 3
# Time 1023: Queue Sizes - Product 0: 4, Product 1: 4
# Time 1023: Queue Sizes - Product 0: 4, Product 1: 3
# Time 1068: Queue Sizes - Product 0: 4, Product 1: 2
# Time 1098: Queue Sizes - Product 0: 4, Product 1: 1
# Time 1128: Queue Sizes - Product 0: 4, Product 1: 0
# Time 1323: Queue Sizes - Product 0: 4, Product 1: 1
# Time 1323: Queue Sizes - Product 0: 4, Product 1: 2
# Time 1323: Queue Sizes - Product 0: 4, Product 1: 3
# Time 1323: Queue Sizes - Product 0: 4, Product 1: 4
# Time 1323: Queue Sizes - Product 0: 4, Product 1: 3
# Time 1353: Queue Sizes - Product 0: 4, Product 1: 2
# Time 1383: Queue Sizes - Product 0: 4, Product 1: 1
# Time 1413: Queue Sizes - Product 0: 4, Product 1: 0
# Time 1504: Queue Sizes - Product 0: 3, Product 1: 0
# Time 1594: Queue Sizes - Product 0: 2, Product 1: 0
# Time 1623: Queue Sizes - Product 0: 2, Product 1: 1
# Time 1623: Queue Sizes - Product 0: 2, Product 1: 2
# Time 1623: Queue Sizes - Product 0: 2, Product 1: 3
# Time 1623: Queue Sizes - Product 0: 2, Product 1: 4
# Time 1624: Queue Sizes - Product 0: 1, Product 1: 4
# Time 1654: Queue Sizes - Product 0: 1, Product 1: 3
# Time 1699: Queue Sizes - Product 0: 0, Product 1: 3
# Time 1744: Queue Sizes - Product 0: 0, Product 1: 2
# Time 1789: Queue Sizes - Product 0: 0, Product 1: 1
# Time 1819: Queue Sizes - Product 0: 0, Product 1: 0
# Time 1863: Queue Sizes - Product 0: 1, Product 1: 0
# Time 1863: Queue Sizes - Product 0: 2, Product 1: 0
# Time 1863: Queue Sizes - Product 0: 3, Product 1: 0
# Time 1863: Queue Sizes - Product 0: 4, Product 1: 0
# Time 1864: Queue Sizes - Product 0: 3, Product 1: 0
# Time 1954: Queue Sizes - Product 0: 2, Product 1: 0
# Time 1984: Queue Sizes - Product 0: 1, Product 1: 0
# Time 2044: Queue Sizes - Product 0: 0, Product 1: 0
# Time 2163: Queue Sizes - Product 0: 0, Product 1: 1
# Time 2163: Queue Sizes - Product 0: 0, Product 1: 2
# Time 2163: Queue Sizes - Product 0: 0, Product 1: 3
# Time 2163: Queue Sizes - Product 0: 0, Product 1: 4
# Time 2163: Queue Sizes - Product 0: 0, Product 1: 3
# Time 2208: Queue Sizes - Product 0: 0, Product 1: 2
# Time 2238: Queue Sizes - Product 0: 0, Product 1: 1
# Time 2268: Queue Sizes - Product 0: 0, Product 1: 0
# Time 2403: Queue Sizes - Product 0: 1, Product 1: 0
# Time 2403: Queue Sizes - Product 0: 2, Product 1: 0
# Time 2403: Queue Sizes - Product 0: 3, Product 1: 0
# Time 2403: Queue Sizes - Product 0: 4, Product 1: 0
# Time 2403: Queue Sizes - Product 0: 3, Product 1: 0
# Time 2450: Queue Sizes - Product 0: 2, Product 1: 0
# Time 2480: Queue Sizes - Product 0: 1, Product 1: 0
# Time 2540: Queue Sizes - Product 0: 0, Product 1: 0
# Time 2643: Queue Sizes - Product 0: 1, Product 1: 0
# Time 2643: Queue Sizes - Product 0: 2, Product 1: 0
# Time 2643: Queue Sizes - Product 0: 3, Product 1: 0
# Time 2643: Queue Sizes - Product 0: 4, Product 1: 0
# Time 2643: Queue Sizes - Product 0: 3, Product 1: 0
# Time 2673: Queue Sizes - Product 0: 2, Product 1: 0
# Time 2703: Queue Sizes - Product 0: 1, Product 1: 0
# Time 2733: Queue Sizes - Product 0: 0, Product 1: 0
# Time 2883: Queue Sizes - Product 0: 1, Product 1: 0
# Time 2883: Queue Sizes - Product 0: 2, Product 1: 0
# Time 2883: Queue Sizes - Product 0: 3, Product 1: 0
# Time 2883: Queue Sizes - Product 0: 4, Product 1: 0
# Time 2883: Queue Sizes - Product 0: 3, Product 1: 0
# Time 2913: Queue Sizes - Product 0: 2, Product 1: 0
# Time 2943: Queue Sizes - Product 0: 1, Product 1: 0
# Time 2991: Queue Sizes - Product 0: 0, Product 1: 0
# Time 3123: Queue Sizes - Product 0: 1, Product 1: 0
# Time 3123: Queue Sizes - Product 0: 2, Product 1: 0
# Time 3123: Queue Sizes - Product 0: 3, Product 1: 0
# Time 3123: Queue Sizes - Product 0: 4, Product 1: 0
# Time 3123: Queue Sizes - Product 0: 3, Product 1: 0
# Time 3171: Queue Sizes - Product 0: 2, Product 1: 0
# Time 3201: Queue Sizes - Product 0: 1, Product 1: 0
# Time 3363: Queue Sizes - Product 0: 2, Product 1: 0
# Time 3363: Queue Sizes - Product 0: 3, Product 1: 0
# Time 3363: Queue Sizes - Product 0: 4, Product 1: 0
# Time 3363: Queue Sizes - Product 0: 5, Product 1: 0
# Time 3663: Queue Sizes - Product 0: 5, Product 1: 1
# Time 3663: Queue Sizes - Product 0: 5, Product 1: 2
# Time 3663: Queue Sizes - Product 0: 5, Product 1: 3
# Time 3663: Queue Sizes - Product 0: 5, Product 1: 4
# Time 3663: Queue Sizes - Product 0: 5, Product 1: 3
# Time 3708: Queue Sizes - Product 0: 5, Product 1: 2
# Time 3738: Queue Sizes - Product 0: 5, Product 1: 1
# Time 3768: Queue Sizes - Product 0: 5, Product 1: 0
# Time 3963: Queue Sizes - Product 0: 5, Product 1: 1
# Time 3963: Queue Sizes - Product 0: 5, Product 1: 2
# Time 3963: Queue Sizes - Product 0: 5, Product 1: 3
# Time 3963: Queue Sizes - Product 0: 5, Product 1: 4
# Time 3963: Queue Sizes - Product 0: 5, Product 1: 3
# Time 3993: Queue Sizes - Product 0: 5, Product 1: 2
# Time 4023: Queue Sizes - Product 0: 5, Product 1: 1
# Time 4053: Queue Sizes - Product 0: 5, Product 1: 0
# Time 4144: Queue Sizes - Product 0: 4, Product 1: 0
# Time 4234: Queue Sizes - Product 0: 3, Product 1: 0
# Time 4263: Queue Sizes - Product 0: 3, Product 1: 1
# Time 4263: Queue Sizes - Product 0: 3, Product 1: 2
# Time 4263: Queue Sizes - Product 0: 3, Product 1: 3
# Time 4263: Queue Sizes - Product 0: 3, Product 1: 4
# Time 4264: Queue Sizes - Product 0: 2, Product 1: 4
# Time 4294: Queue Sizes - Product 0: 2, Product 1: 3
# Time 4339: Queue Sizes - Product 0: 1, Product 1: 3
# Time 4384: Queue Sizes - Product 0: 1, Product 1: 2
# Time 4429: Queue Sizes - Product 0: 0, Product 1: 2
# Time 4474: Queue Sizes - Product 0: 0, Product 1: 1
# Time 4503: Queue Sizes - Product 0: 1, Product 1: 1
# Time 4503: Queue Sizes - Product 0: 2, Product 1: 1
# Time 4503: Queue Sizes - Product 0: 3, Product 1: 1
# Time 4503: Queue Sizes - Product 0: 4, Product 1: 1
# Time 4519: Queue Sizes - Product 0: 3, Product 1: 1
# Time 4564: Queue Sizes - Product 0: 3, Product 1: 0
# Time 4609: Queue Sizes - Product 0: 2, Product 1: 0
# Time 4684: Queue Sizes - Product 0: 1, Product 1: 0
# Time 4714: Queue Sizes - Product 0: 0, Product 1: 0
# Time 4803: Queue Sizes - Product 0: 0, Product 1: 1
# Time 4803: Queue Sizes - Product 0: 0, Product 1: 2
# Time 4803: Queue Sizes - Product 0: 0, Product 1: 3
# Time 4803: Queue Sizes - Product 0: 0, Product 1: 4
# Time 4803: Queue Sizes - Product 0: 0, Product 1: 3
# Time 4848: Queue Sizes - Product 0: 0, Product 1: 2
# Time 4878: Queue Sizes - Product 0: 0, Product 1: 1
# Time 4908: Queue Sizes - Product 0: 0, Product 1: 0
# Time 5043: Queue Sizes - Product 0: 1, Product 1: 0
# Time 5043: Queue Sizes - Product 0: 2, Product 1: 0
# Time 5043: Queue Sizes - Product 0: 3, Product 1: 0
# Time 5043: Queue Sizes - Product 0: 4, Product 1: 0
# Time 5043: Queue Sizes - Product 0: 3, Product 1: 0
# Time 5090: Queue Sizes - Product 0: 2, Product 1: 0
# Time 5120: Queue Sizes - Product 0: 1, Product 1: 0
# Time 5180: Queue Sizes - Product 0: 0, Product 1: 0
# Time 5283: Queue Sizes - Product 0: 1, Product 1: 0
# Time 5283: Queue Sizes - Product 0: 2, Product 1: 0
# Time 5283: Queue Sizes - Product 0: 3, Product 1: 0
# Time 5283: Queue Sizes - Product 0: 4, Product 1: 0
# Time 5283: Queue Sizes - Product 0: 3, Product 1: 0
# Time 5313: Queue Sizes - Product 0: 2, Product 1: 0
# Time 5343: Queue Sizes - Product 0: 1, Product 1: 0
# Time 5373: Queue Sizes - Product 0: 0, Product 1: 0
# Time 5523: Queue Sizes - Product 0: 1, Product 1: 0
# Time 5523: Queue Sizes - Product 0: 2, Product 1: 0
# Time 5523: Queue Sizes - Product 0: 3, Product 1: 0
# Time 5523: Queue Sizes - Product 0: 4, Product 1: 0
# Time 5523: Queue Sizes - Product 0: 3, Product 1: 0
# Time 5553: Queue Sizes - Product 0: 2, Product 1: 0
# Time 5583: Queue Sizes - Product 0: 1, Product 1: 0
# Time 5631: Queue Sizes - Product 0: 0, Product 1: 0
# Time 5763: Queue Sizes - Product 0: 1, Product 1: 0
# Time 5763: Queue Sizes - Product 0: 2, Product 1: 0
# Time 5763: Queue Sizes - Product 0: 3, Product 1: 0
# Time 5763: Queue Sizes - Product 0: 4, Product 1: 0
# Time 5763: Queue Sizes - Product 0: 3, Product 1: 0
# Time 5811: Queue Sizes - Product 0: 2, Product 1: 0
# Time 5841: Queue Sizes - Product 0: 1, Product 1: 0
# Time 6003: Queue Sizes - Product 0: 2, Product 1: 0
# Time 6003: Queue Sizes - Product 0: 3, Product 1: 0
# Time 6003: Queue Sizes - Product 0: 4, Product 1: 0
# Time 6003: Queue Sizes - Product 0: 5, Product 1: 0
# Time 6303: Queue Sizes - Product 0: 5, Product 1: 1
# Time 6303: Queue Sizes - Product 0: 5, Product 1: 2
# Time 6303: Queue Sizes - Product 0: 5, Product 1: 3
# Time 6303: Queue Sizes - Product 0: 5, Product 1: 4
# Time 6303: Queue Sizes - Product 0: 5, Product 1: 3
# Time 6348: Queue Sizes - Product 0: 5, Product 1: 2
# Time 6378: Queue Sizes - Product 0: 5, Product 1: 1
# Time 6408: Queue Sizes - Product 0: 5, Product 1: 0
# Time 6603: Queue Sizes - Product 0: 5, Product 1: 1
# Time 6603: Queue Sizes - Product 0: 5, Product 1: 2
# Time 6603: Queue Sizes - Product 0: 5, Product 1: 3
# Time 6603: Queue Sizes - Product 0: 5, Product 1: 4
# Time 6603: Queue Sizes - Product 0: 5, Product 1: 3
# Time 6633: Queue Sizes - Product 0: 5, Product 1: 2
# Time 6663: Queue Sizes - Product 0: 5, Product 1: 1
# Time 6693: Queue Sizes - Product 0: 5, Product 1: 0
# Time 6784: Queue Sizes - Product 0: 4, Product 1: 0
# Time 6874: Queue Sizes - Product 0: 3, Product 1: 0
# Time 6903: Queue Sizes - Product 0: 3, Product 1: 1
# Time 6903: Queue Sizes - Product 0: 3, Product 1: 2
# Time 6903: Queue Sizes - Product 0: 3, Product 1: 3
# Time 6903: Queue Sizes - Product 0: 3, Product 1: 4
# Time 6904: Queue Sizes - Product 0: 2, Product 1: 4
# Time 6934: Queue Sizes - Product 0: 2, Product 1: 3
# Time 6979: Queue Sizes - Product 0: 1, Product 1: 3
# Time 7024: Queue Sizes - Product 0: 1, Product 1: 2
# Time 7069: Queue Sizes - Product 0: 0, Product 1: 2
# Time 7114: Queue Sizes - Product 0: 0, Product 1: 1
# Time 7143: Queue Sizes - Product 0: 1, Product 1: 1
# Time 7143: Queue Sizes - Product 0: 2, Product 1: 1
# Time 7143: Queue Sizes - Product 0: 3, Product 1: 1
# Time 7143: Queue Sizes - Product 0: 4, Product 1: 1
# Time 7159: Queue Sizes - Product 0: 3, Product 1: 1
# Time 7204: Queue Sizes - Product 0: 3, Product 1: 0
# Time 7249: Queue Sizes - Product 0: 2, Product 1: 0
# Time 7324: Queue Sizes - Product 0: 1, Product 1: 0
# Time 7354: Queue Sizes - Product 0: 0, Product 1: 0
# Time 7443: Queue Sizes - Product 0: 0, Product 1: 1
# Time 7443: Queue Sizes - Product 0: 0, Product 1: 2
# Time 7443: Queue Sizes - Product 0: 0, Product 1: 3
# Time 7443: Queue Sizes - Product 0: 0, Product 1: 4
# Time 7443: Queue Sizes - Product 0: 0, Product 1: 3
# Time 7488: Queue Sizes - Product 0: 0, Product 1: 2
# Time 7518: Queue Sizes - Product 0: 0, Product 1: 1
# Time 7548: Queue Sizes - Product 0: 0, Product 1: 0
# Time 7683: Queue Sizes - Product 0: 1, Product 1: 0
# Time 7683: Queue Sizes - Product 0: 2, Product 1: 0
# Time 7683: Queue Sizes - Product 0: 3, Product 1: 0
# Time 7683: Queue Sizes - Product 0: 4, Product 1: 0
# Time 7683: Queue Sizes - Product 0: 3, Product 1: 0
# Time 7730: Queue Sizes - Product 0: 2, Product 1: 0
# Time 7760: Queue Sizes - Product 0: 1, Product 1: 0
# Time 7820: Queue Sizes - Product 0: 0, Product 1: 0
# Time 7923: Queue Sizes - Product 0: 1, Product 1: 0
# Time 7923: Queue Sizes - Product 0: 2, Product 1: 0
# Time 7923: Queue Sizes - Product 0: 3, Product 1: 0
# Time 7923: Queue Sizes - Product 0: 4, Product 1: 0
# Time 7923: Queue Sizes - Product 0: 3, Product 1: 0
# Time 7953: Queue Sizes - Product 0: 2, Product 1: 0
# Time 7983: Queue Sizes - Product 0: 1, Product 1: 0
# Time 8013: Queue Sizes - Product 0: 0, Product 1: 0
# Time 8163: Queue Sizes - Product 0: 1, Product 1: 0
# Time 8163: Queue Sizes - Product 0: 2, Product 1: 0
# Time 8163: Queue Sizes - Product 0: 3, Product 1: 0
# Time 8163: Queue Sizes - Product 0: 4, Product 1: 0
# Time 8163: Queue Sizes - Product 0: 3, Product 1: 0
# Time 8193: Queue Sizes - Product 0: 2, Product 1: 0
# Time 8223: Queue Sizes - Product 0: 1, Product 1: 0
# Time 8271: Queue Sizes - Product 0: 0, Product 1: 0
# Time 8403: Queue Sizes - Product 0: 1, Product 1: 0
# Time 8403: Queue Sizes - Product 0: 2, Product 1: 0
# Time 8403: Queue Sizes - Product 0: 3, Product 1: 0
# Time 8403: Queue Sizes - Product 0: 4, Product 1: 0
# Time 8403: Queue Sizes - Product 0: 3, Product 1: 0
# Time 8451: Queue Sizes - Product 0: 2, Product 1: 0
# Time 8481: Queue Sizes - Product 0: 1, Product 1: 0
# Time 8643: Queue Sizes - Product 0: 2, Product 1: 0
# Time 8643: Queue Sizes - Product 0: 3, Product 1: 0
# Time 8643: Queue Sizes - Product 0: 4, Product 1: 0
# Time 8643: Queue Sizes - Product 0: 5, Product 1: 0
# Time 8943: Queue Sizes - Product 0: 5, Product 1: 1
# Time 8943: Queue Sizes - Product 0: 5, Product 1: 2
# Time 8943: Queue Sizes - Product 0: 5, Product 1: 3
# Time 8943: Queue Sizes - Product 0: 5, Product 1: 4
# Time 8943: Queue Sizes - Product 0: 5, Product 1: 3
# Time 8988: Queue Sizes - Product 0: 5, Product 1: 2
# Time 9018: Queue Sizes - Product 0: 5, Product 1: 1
# Time 9048: Queue Sizes - Product 0: 5, Product 1: 0
# Time 9243: Queue Sizes - Product 0: 5, Product 1: 1
# Time 9243: Queue Sizes - Product 0: 5, Product 1: 2
# Time 9243: Queue Sizes - Product 0: 5, Product 1: 3
# Time 9243: Queue Sizes - Product 0: 5, Product 1: 4
# Time 9243: Queue Sizes - Product 0: 5, Product 1: 3
# Time 9273: Queue Sizes - Product 0: 5, Product 1: 2
# Time 9303: Queue Sizes - Product 0: 5, Product 1: 1
# Time 9333: Queue Sizes - Product 0: 5, Product 1: 0
# Time 9424: Queue Sizes - Product 0: 4, Product 1: 0
# Time 9514: Queue Sizes - Product 0: 3, Product 1: 0
# Time 9543: Queue Sizes - Product 0: 3, Product 1: 1
# Time 9543: Queue Sizes - Product 0: 3, Product 1: 2
# Time 9543: Queue Sizes - Product 0: 3, Product 1: 3
# Time 9543: Queue Sizes - Product 0: 3, Product 1: 4
# Time 9544: Queue Sizes - Product 0: 2, Product 1: 4
# Time 9574: Queue Sizes - Product 0: 2, Product 1: 3
# Time 9619: Queue Sizes - Product 0: 1, Product 1: 3
# Time 9664: Queue Sizes - Product 0: 1, Product 1: 2
# Time 9709: Queue Sizes - Product 0: 0, Product 1: 2
# Time 9754: Queue Sizes - Product 0: 0, Product 1: 1
# Time 9783: Queue Sizes - Product 0: 1, Product 1: 1
# Time 9783: Queue Sizes - Product 0: 2, Product 1: 1
# Time 9783: Queue Sizes - Product 0: 3, Product 1: 1
# Time 9783: Queue Sizes - Product 0: 4, Product 1: 1
# Time 9799: Queue Sizes - Product 0: 3, Product 1: 1
# Time 9844: Queue Sizes - Product 0: 3, Product 1: 0
# Time 9889: Queue Sizes - Product 0: 2, Product 1: 0
# Time 9964: Queue Sizes - Product 0: 1, Product 1: 0
# Time 9994: Queue Sizes - Product 0: 0, Product 1: 0
# Time 10083: Queue Sizes - Product 0: 0, Product 1: 1
# Time 10083: Queue Sizes - Product 0: 0, Product 1: 2
# Time 10083: Queue Sizes - Product 0: 0, Product 1: 3
# Time 10083: Queue Sizes - Product 0: 0, Product 1: 4
# Time 10083: Queue Sizes - Product 0: 0, Product 1: 3
# Time 10128: Queue Sizes - Product 0: 0, Product 1: 2
# Time 10158: Queue Sizes - Product 0: 0, Product 1: 1
# Time 10188: Queue Sizes - Product 0: 0, Product 1: 0
# Time 10323: Queue Sizes - Product 0: 1, Product 1: 0
# Time 10323: Queue Sizes - Product 0: 2, Product 1: 0
# Time 10323: Queue Sizes - Product 0: 3, Product 1: 0
# Time 10323: Queue Sizes - Product 0: 4, Product 1: 0
# Time 10323: Queue Sizes - Product 0: 3, Product 1: 0
# Time 10370: Queue Sizes - Product 0: 2, Product 1: 0
# Time 10400: Queue Sizes - Product 0: 1, Product 1: 0
# Time 10460: Queue Sizes - Product 0: 0, Product 1: 0
# Time 10563: Queue Sizes - Product 0: 1, Product 1: 0
# Time 10563: Queue Sizes - Product 0: 2, Product 1: 0
# Time 10563: Queue Sizes - Product 0: 3, Product 1: 0
# Time 10563: Queue Sizes - Product 0: 4, Product 1: 0
# Time 10563: Queue Sizes - Product 0: 3, Product 1: 0
# Time 10593: Queue Sizes - Product 0: 2, Product 1: 0
# Time 10623: Queue Sizes - Product 0: 1, Product 1: 0
# Time 10653: Queue Sizes - Product 0: 0, Product 1: 0
# Time 10803: Queue Sizes - Product 0: 1, Product 1: 0
# Time 10803: Queue Sizes - Product 0: 2, Product 1: 0
# Time 10803: Queue Sizes - Product 0: 3, Product 1: 0
# Time 10803: Queue Sizes - Product 0: 4, Product 1: 0
# Time 10803: Queue Sizes - Product 0: 3, Product 1: 0
# Time 10833: Queue Sizes - Product 0: 2, Product 1: 0
# Time 10863: Queue Sizes - Product 0: 1, Product 1: 0
# Time 10911: Queue Sizes - Product 0: 0, Product 1: 0
# Time 11136: Queue Sizes - Product 0: 0, Product 1: 1
# Time 11136: Queue Sizes - Product 0: 0, Product 1: 2
# Time 11136: Queue Sizes - Product 0: 0, Product 1: 3
# Time 11136: Queue Sizes - Product 0: 0, Product 1: 4
# Time 11136: Queue Sizes - Product 0: 0, Product 1: 3
# Time 11181: Queue Sizes - Product 0: 0, Product 1: 2
# Time 11211: Queue Sizes - Product 0: 0, Product 1: 1
# Time 11241: Queue Sizes - Product 0: 0, Product 1: 0
# Time 11436: Queue Sizes - Product 0: 0, Product 1: 1
# Time 11436: Queue Sizes - Product 0: 0, Product 1: 2
# Time 11436: Queue Sizes - Product 0: 0, Product 1: 3
# Time 11436: Queue Sizes - Product 0: 0, Product 1: 4
# Time 11436: Queue Sizes - Product 0: 0, Product 1: 3
# Time 11466: Queue Sizes - Product 0: 0, Product 1: 2
# Time 11496: Queue Sizes - Product 0: 0, Product 1: 1
# Time 11526: Queue Sizes - Product 0: 0, Product 1: 0
# Time 11736: Queue Sizes - Product 0: 0, Product 1: 1
# Time 11736: Queue Sizes - Product 0: 0, Product 1: 2
# Time 11736: Queue Sizes - Product 0: 0, Product 1: 3
# Time 11736: Queue Sizes - Product 0: 0, Product 1: 4
# Time 11736: Queue Sizes - Product 0: 0, Product 1: 3
# Time 11766: Queue Sizes - Product 0: 0, Product 1: 2
# Time 11796: Queue Sizes - Product 0: 0, Product 1: 1
# Time 11826: Queue Sizes - Product 0: 0, Product 1: 0
# Time 12036: Queue Sizes - Product 0: 0, Product 1: 1
# Time 12036: Queue Sizes - Product 0: 0, Product 1: 2
# Time 12036: Queue Sizes - Product 0: 0, Product 1: 3
# Time 12036: Queue Sizes - Product 0: 0, Product 1: 4
# Time 12036: Queue Sizes - Product 0: 0, Product 1: 3
# Time 12066: Queue Sizes - Product 0: 0, Product 1: 2
# Time 12096: Queue Sizes - Product 0: 0, Product 1: 1
# Time 12126: Queue Sizes - Product 0: 0, Product 1: 0
# Time 12336: Queue Sizes - Product 0: 0, Product 1: 1
# Time 12336: Queue Sizes - Product 0: 0, Product 1: 2
# Time 12336: Queue Sizes - Product 0: 0, Product 1: 3
# Time 12336: Queue Sizes - Product 0: 0, Product 1: 4
# Time 12457: Queue Sizes - Product 0: 0, Product 1: 3
# Time 12487: Queue Sizes - Product 0: 0, Product 1: 2
# Time 12517: Queue Sizes - Product 0: 0, Product 1: 1
# Time 12547: Queue Sizes - Product 0: 0, Product 1: 0
# Time 12757: Queue Sizes - Product 0: 0, Product 1: 1
# Time 12757: Queue Sizes - Product 0: 0, Product 1: 2
# Time 12757: Queue Sizes - Product 0: 0, Product 1: 3
# Time 12757: Queue Sizes - Product 0: 0, Product 1: 4
# Time 12757: Queue Sizes - Product 0: 0, Product 1: 3
# Time 12787: Queue Sizes - Product 0: 0, Product 1: 2
# Time 12817: Queue Sizes - Product 0: 0, Product 1: 1
# Time 12847: Queue Sizes - Product 0: 0, Product 1: 0
# Time 13057: Queue Sizes - Product 0: 0, Product 1: 1
# Time 13057: Queue Sizes - Product 0: 0, Product 1: 2
# Time 13057: Queue Sizes - Product 0: 0, Product 1: 3
# Time 13057: Queue Sizes - Product 0: 0, Product 1: 4
# Time 13057: Queue Sizes - Product 0: 0, Product 1: 3
# Time 13087: Queue Sizes - Product 0: 0, Product 1: 2
# Time 13117: Queue Sizes - Product 0: 0, Product 1: 1
# Time 13147: Queue Sizes - Product 0: 0, Product 1: 0
# Time 13357: Queue Sizes - Product 0: 0, Product 1: 1
# Time 13357: Queue Sizes - Product 0: 0, Product 1: 2
# Time 13357: Queue Sizes - Product 0: 0, Product 1: 3
# Time 13357: Queue Sizes - Product 0: 0, Product 1: 4
# Time 13357: Queue Sizes - Product 0: 0, Product 1: 3
# Time 13387: Queue Sizes - Product 0: 0, Product 1: 2
# Time 13417: Queue Sizes - Product 0: 0, Product 1: 1
# Time 13447: Queue Sizes - Product 0: 0, Product 1: 0
# Time 13657: Queue Sizes - Product 0: 0, Product 1: 1
# Time 13657: Queue Sizes - Product 0: 0, Product 1: 2
# Time 13657: Queue Sizes - Product 0: 0, Product 1: 3
# Time 13657: Queue Sizes - Product 0: 0, Product 1: 4
# Time 13657: Queue Sizes - Product 0: 0, Product 1: 3
# Time 13687: Queue Sizes - Product 0: 0, Product 1: 2
# Time 13717: Queue Sizes - Product 0: 0, Product 1: 1
# Time 13747: Queue Sizes - Product 0: 0, Product 1: 0
# queue2 Event Log:
# Time 288: Queue Sizes - Product 0: 1, Product 1: 0
# Time 318: Queue Sizes - Product 0: 2, Product 1: 0
# Time 348: Queue Sizes - Product 0: 3, Product 1: 0
# Time 378: Queue Sizes - Product 0: 4, Product 1: 0
# Time 378: Queue Sizes - Product 0: 0, Product 1: 0
# Time 513: Queue Sizes - Product 0: 1, Product 1: 0
# Time 543: Queue Sizes - Product 0: 2, Product 1: 0
# Time 573: Queue Sizes - Product 0: 3, Product 1: 0
# Time 603: Queue Sizes - Product 0: 4, Product 1: 0
# Time 618: Queue Sizes - Product 0: 0, Product 1: 0
# Time 1068: Queue Sizes - Product 0: 0, Product 1: 1
# Time 1098: Queue Sizes - Product 0: 0, Product 1: 2
# Time 1128: Queue Sizes - Product 0: 0, Product 1: 3
# Time 1158: Queue Sizes - Product 0: 0, Product 1: 4
# Time 1158: Queue Sizes - Product 0: 0, Product 1: 0
# Time 1353: Queue Sizes - Product 0: 0, Product 1: 1
# Time 1383: Queue Sizes - Product 0: 0, Product 1: 2
# Time 1413: Queue Sizes - Product 0: 0, Product 1: 3
# Time 1443: Queue Sizes - Product 0: 0, Product 1: 4
# Time 1458: Queue Sizes - Product 0: 0, Product 1: 0
# Time 1549: Queue Sizes - Product 0: 1, Product 1: 0
# Time 1624: Queue Sizes - Product 0: 2, Product 1: 0
# Time 1654: Queue Sizes - Product 0: 3, Product 1: 0
# Time 1699: Queue Sizes - Product 0: 3, Product 1: 1
# Time 1744: Queue Sizes - Product 0: 4, Product 1: 1
# Time 1774: Queue Sizes - Product 0: 0, Product 1: 1
# Time 1789: Queue Sizes - Product 0: 0, Product 1: 2
# Time 1819: Queue Sizes - Product 0: 0, Product 1: 3
# Time 1849: Queue Sizes - Product 0: 0, Product 1: 4
# Time 1909: Queue Sizes - Product 0: 1, Product 1: 4
# Time 1984: Queue Sizes - Product 0: 2, Product 1: 4
# Time 2014: Queue Sizes - Product 0: 3, Product 1: 4
# Time 2014: Queue Sizes - Product 0: 3, Product 1: 0
# Time 2074: Queue Sizes - Product 0: 4, Product 1: 0
# Time 2208: Queue Sizes - Product 0: 4, Product 1: 1
# Time 2238: Queue Sizes - Product 0: 4, Product 1: 2
# Time 2268: Queue Sizes - Product 0: 4, Product 1: 3
# Time 2298: Queue Sizes - Product 0: 4, Product 1: 4
# Time 2314: Queue Sizes - Product 0: 4, Product 1: 0
# Time 2448: Queue Sizes - Product 0: 5, Product 1: 0
# Time 2480: Queue Sizes - Product 0: 6, Product 1: 0
# Time 2510: Queue Sizes - Product 0: 7, Product 1: 0
# Time 2570: Queue Sizes - Product 0: 8, Product 1: 0
# Time 2630: Queue Sizes - Product 0: 4, Product 1: 0
# Time 2673: Queue Sizes - Product 0: 5, Product 1: 0
# Time 2703: Queue Sizes - Product 0: 6, Product 1: 0
# Time 2733: Queue Sizes - Product 0: 7, Product 1: 0
# Time 2763: Queue Sizes - Product 0: 8, Product 1: 0
# Time 2870: Queue Sizes - Product 0: 4, Product 1: 0
# Time 2913: Queue Sizes - Product 0: 5, Product 1: 0
# Time 2943: Queue Sizes - Product 0: 6, Product 1: 0
# Time 2973: Queue Sizes - Product 0: 7, Product 1: 0
# Time 3021: Queue Sizes - Product 0: 8, Product 1: 0
# Time 3110: Queue Sizes - Product 0: 4, Product 1: 0
# Time 3153: Queue Sizes - Product 0: 5, Product 1: 0
# Time 3201: Queue Sizes - Product 0: 6, Product 1: 0
# Time 3231: Queue Sizes - Product 0: 7, Product 1: 0
# Time 3708: Queue Sizes - Product 0: 7, Product 1: 1
# Time 3738: Queue Sizes - Product 0: 7, Product 1: 2
# Time 3768: Queue Sizes - Product 0: 7, Product 1: 3
# Time 3798: Queue Sizes - Product 0: 7, Product 1: 4
# Time 3798: Queue Sizes - Product 0: 7, Product 1: 0
# Time 3993: Queue Sizes - Product 0: 7, Product 1: 1
# Time 4023: Queue Sizes - Product 0: 7, Product 1: 2
# Time 4053: Queue Sizes - Product 0: 7, Product 1: 3
# Time 4083: Queue Sizes - Product 0: 7, Product 1: 4
# Time 4098: Queue Sizes - Product 0: 7, Product 1: 0
# Time 4189: Queue Sizes - Product 0: 8, Product 1: 0
# Time 4264: Queue Sizes - Product 0: 9, Product 1: 0
# Time 4294: Queue Sizes - Product 0: 10, Product 1: 0
# Time 4339: Queue Sizes - Product 0: 10, Product 1: 1
# Time 4384: Queue Sizes - Product 0: 11, Product 1: 1
# Time 4414: Queue Sizes - Product 0: 7, Product 1: 1
# Time 4429: Queue Sizes - Product 0: 7, Product 1: 2
# Time 4474: Queue Sizes - Product 0: 8, Product 1: 2
# Time 4519: Queue Sizes - Product 0: 8, Product 1: 3
# Time 4564: Queue Sizes - Product 0: 9, Product 1: 3
# Time 4609: Queue Sizes - Product 0: 9, Product 1: 4
# Time 4654: Queue Sizes - Product 0: 10, Product 1: 4
# Time 4654: Queue Sizes - Product 0: 10, Product 1: 0
# Time 4714: Queue Sizes - Product 0: 11, Product 1: 0
# Time 4744: Queue Sizes - Product 0: 12, Product 1: 0
# Time 4848: Queue Sizes - Product 0: 12, Product 1: 1
# Time 4878: Queue Sizes - Product 0: 12, Product 1: 2
# Time 4908: Queue Sizes - Product 0: 12, Product 1: 3
# Time 4938: Queue Sizes - Product 0: 12, Product 1: 4
# Time 4954: Queue Sizes - Product 0: 12, Product 1: 0
# Time 5088: Queue Sizes - Product 0: 13, Product 1: 0
# Time 5120: Queue Sizes - Product 0: 14, Product 1: 0
# Time 5150: Queue Sizes - Product 0: 15, Product 1: 0
# Time 5210: Queue Sizes - Product 0: 16, Product 1: 0
# Time 5270: Queue Sizes - Product 0: 12, Product 1: 0
# Time 5313: Queue Sizes - Product 0: 13, Product 1: 0
# Time 5343: Queue Sizes - Product 0: 14, Product 1: 0
# Time 5373: Queue Sizes - Product 0: 15, Product 1: 0
# Time 5403: Queue Sizes - Product 0: 16, Product 1: 0
# Time 5510: Queue Sizes - Product 0: 12, Product 1: 0
# Time 5553: Queue Sizes - Product 0: 13, Product 1: 0
# Time 5583: Queue Sizes - Product 0: 14, Product 1: 0
# Time 5613: Queue Sizes - Product 0: 15, Product 1: 0
# Time 5661: Queue Sizes - Product 0: 16, Product 1: 0
# Time 5750: Queue Sizes - Product 0: 12, Product 1: 0
# Time 5793: Queue Sizes - Product 0: 13, Product 1: 0
# Time 5841: Queue Sizes - Product 0: 14, Product 1: 0
# Time 5871: Queue Sizes - Product 0: 15, Product 1: 0
# Time 6348: Queue Sizes - Product 0: 15, Product 1: 1
# Time 6378: Queue Sizes - Product 0: 15, Product 1: 2
# Time 6408: Queue Sizes - Product 0: 15, Product 1: 3
# Time 6438: Queue Sizes - Product 0: 15, Product 1: 4
# Time 6438: Queue Sizes - Product 0: 15, Product 1: 0
# Time 6633: Queue Sizes - Product 0: 15, Product 1: 1
# Time 6663: Queue Sizes - Product 0: 15, Product 1: 2
# Time 6693: Queue Sizes - Product 0: 15, Product 1: 3
# Time 6723: Queue Sizes - Product 0: 15, Product 1: 4
# Time 6738: Queue Sizes - Product 0: 15, Product 1: 0
# Time 6829: Queue Sizes - Product 0: 16, Product 1: 0
# Time 6904: Queue Sizes - Product 0: 17, Product 1: 0
# Time 6934: Queue Sizes - Product 0: 18, Product 1: 0
# Time 6979: Queue Sizes - Product 0: 18, Product 1: 1
# Time 7024: Queue Sizes - Product 0: 19, Product 1: 1
# Time 7054: Queue Sizes - Product 0: 15, Product 1: 1
# Time 7069: Queue Sizes - Product 0: 15, Product 1: 2
# Time 7114: Queue Sizes - Product 0: 16, Product 1: 2
# Time 7159: Queue Sizes - Product 0: 16, Product 1: 3
# Time 7204: Queue Sizes - Product 0: 17, Product 1: 3
# Time 7249: Queue Sizes - Product 0: 17, Product 1: 4
# Time 7294: Queue Sizes - Product 0: 18, Product 1: 4
# Time 7294: Queue Sizes - Product 0: 18, Product 1: 0
# Time 7354: Queue Sizes - Product 0: 19, Product 1: 0
# Time 7384: Queue Sizes - Product 0: 20, Product 1: 0
# Time 7488: Queue Sizes - Product 0: 20, Product 1: 1
# Time 7518: Queue Sizes - Product 0: 20, Product 1: 2
# Time 7548: Queue Sizes - Product 0: 20, Product 1: 3
# Time 7578: Queue Sizes - Product 0: 20, Product 1: 4
# Time 7594: Queue Sizes - Product 0: 20, Product 1: 0
# Time 7728: Queue Sizes - Product 0: 21, Product 1: 0
# Time 7760: Queue Sizes - Product 0: 22, Product 1: 0
# Time 7790: Queue Sizes - Product 0: 23, Product 1: 0
# Time 7850: Queue Sizes - Product 0: 24, Product 1: 0
# Time 7910: Queue Sizes - Product 0: 20, Product 1: 0
# Time 7953: Queue Sizes - Product 0: 21, Product 1: 0
# Time 7983: Queue Sizes - Product 0: 22, Product 1: 0
# Time 8013: Queue Sizes - Product 0: 23, Product 1: 0
# Time 8043: Queue Sizes - Product 0: 24, Product 1: 0
# Time 8150: Queue Sizes - Product 0: 20, Product 1: 0
# Time 8193: Queue Sizes - Product 0: 21, Product 1: 0
# Time 8223: Queue Sizes - Product 0: 22, Product 1: 0
# Time 8253: Queue Sizes - Product 0: 23, Product 1: 0
# Time 8301: Queue Sizes - Product 0: 24, Product 1: 0
# Time 8390: Queue Sizes - Product 0: 20, Product 1: 0
# Time 8433: Queue Sizes - Product 0: 21, Product 1: 0
# Time 8481: Queue Sizes - Product 0: 22, Product 1: 0
# Time 8511: Queue Sizes - Product 0: 23, Product 1: 0
# Time 8988: Queue Sizes - Product 0: 23, Product 1: 1
# Time 9018: Queue Sizes - Product 0: 23, Product 1: 2
# Time 9048: Queue Sizes - Product 0: 23, Product 1: 3
# Time 9078: Queue Sizes - Product 0: 23, Product 1: 4
# Time 9078: Queue Sizes - Product 0: 23, Product 1: 0
# Time 9273: Queue Sizes - Product 0: 23, Product 1: 1
# Time 9303: Queue Sizes - Product 0: 23, Product 1: 2
# Time 9333: Queue Sizes - Product 0: 23, Product 1: 3
# Time 9363: Queue Sizes - Product 0: 23, Product 1: 4
# Time 9378: Queue Sizes - Product 0: 23, Product 1: 0
# Time 9469: Queue Sizes - Product 0: 24, Product 1: 0
# Time 9544: Queue Sizes - Product 0: 25, Product 1: 0
# Time 9574: Queue Sizes - Product 0: 26, Product 1: 0
# Time 9619: Queue Sizes - Product 0: 26, Product 1: 1
# Time 9664: Queue Sizes - Product 0: 27, Product 1: 1
# Time 9694: Queue Sizes - Product 0: 23, Product 1: 1
# Time 9709: Queue Sizes - Product 0: 23, Product 1: 2
# Time 9754: Queue Sizes - Product 0: 24, Product 1: 2
# Time 9799: Queue Sizes - Product 0: 24, Product 1: 3
# Time 9844: Queue Sizes - Product 0: 25, Product 1: 3
# Time 9889: Queue Sizes - Product 0: 25, Product 1: 4
# Time 9934: Queue Sizes - Product 0: 26, Product 1: 4
# Time 9934: Queue Sizes - Product 0: 26, Product 1: 0
# Time 9994: Queue Sizes - Product 0: 27, Product 1: 0
# Time 10024: Queue Sizes - Product 0: 28, Product 1: 0
# Time 10128: Queue Sizes - Product 0: 28, Product 1: 1
# Time 10158: Queue Sizes - Product 0: 28, Product 1: 2
# Time 10188: Queue Sizes - Product 0: 28, Product 1: 3
# Time 10218: Queue Sizes - Product 0: 28, Product 1: 4
# Time 10234: Queue Sizes - Product 0: 28, Product 1: 0
# Time 10368: Queue Sizes - Product 0: 29, Product 1: 0
# Time 10400: Queue Sizes - Product 0: 30, Product 1: 0
# Time 10430: Queue Sizes - Product 0: 31, Product 1: 0
# Time 10490: Queue Sizes - Product 0: 32, Product 1: 0
# Time 10550: Queue Sizes - Product 0: 28, Product 1: 0
# Time 10593: Queue Sizes - Product 0: 29, Product 1: 0
# Time 10623: Queue Sizes - Product 0: 30, Product 1: 0
# Time 10653: Queue Sizes - Product 0: 31, Product 1: 0
# Time 10683: Queue Sizes - Product 0: 32, Product 1: 0
# Time 10790: Queue Sizes - Product 0: 28, Product 1: 0
# Time 10833: Queue Sizes - Product 0: 29, Product 1: 0
# Time 10863: Queue Sizes - Product 0: 30, Product 1: 0
# Time 10893: Queue Sizes - Product 0: 31, Product 1: 0
# Time 10941: Queue Sizes - Product 0: 32, Product 1: 0
# Time 11030: Queue Sizes - Product 0: 28, Product 1: 0
# Time 11181: Queue Sizes - Product 0: 28, Product 1: 1
# Time 11211: Queue Sizes - Product 0: 28, Product 1: 2
# Time 11241: Queue Sizes - Product 0: 28, Product 1: 3
# Time 11271: Queue Sizes - Product 0: 28, Product 1: 4
# Time 11271: Queue Sizes - Product 0: 28, Product 1: 0
# Time 11466: Queue Sizes - Product 0: 28, Product 1: 1
# Time 11496: Queue Sizes - Product 0: 28, Product 1: 2
# Time 11526: Queue Sizes - Product 0: 28, Product 1: 3
# Time 11556: Queue Sizes - Product 0: 28, Product 1: 4
# Time 11571: Queue Sizes - Product 0: 28, Product 1: 0
# Time 11766: Queue Sizes - Product 0: 28, Product 1: 1
# Time 11796: Queue Sizes - Product 0: 28, Product 1: 2
# Time 11826: Queue Sizes - Product 0: 28, Product 1: 3
# Time 11856: Queue Sizes - Product 0: 28, Product 1: 4
# Time 11871: Queue Sizes - Product 0: 28, Product 1: 0
# Time 12066: Queue Sizes - Product 0: 28, Product 1: 1
# Time 12096: Queue Sizes - Product 0: 28, Product 1: 2
# Time 12126: Queue Sizes - Product 0: 28, Product 1: 3
# Time 12156: Queue Sizes - Product 0: 28, Product 1: 4
# Time 12171: Queue Sizes - Product 0: 24, Product 1: 4
# Time 12411: Queue Sizes - Product 0: 20, Product 1: 4
# Time 12487: Queue Sizes - Product 0: 20, Product 1: 5
# Time 12517: Queue Sizes - Product 0: 20, Product 1: 6
# Time 12547: Queue Sizes - Product 0: 20, Product 1: 7
# Time 12577: Queue Sizes - Product 0: 20, Product 1: 8
# Time 12651: Queue Sizes - Product 0: 16, Product 1: 8
# Time 12787: Queue Sizes - Product 0: 16, Product 1: 9
# Time 12817: Queue Sizes - Product 0: 16, Product 1: 10
# Time 12847: Queue Sizes - Product 0: 16, Product 1: 11
# Time 12877: Queue Sizes - Product 0: 16, Product 1: 12
# Time 12891: Queue Sizes - Product 0: 16, Product 1: 8
# Time 13087: Queue Sizes - Product 0: 16, Product 1: 9
# Time 13117: Queue Sizes - Product 0: 16, Product 1: 10
# Time 13147: Queue Sizes - Product 0: 16, Product 1: 11
# Time 13177: Queue Sizes - Product 0: 16, Product 1: 12
# Time 13191: Queue Sizes - Product 0: 16, Product 1: 8
# Time 13387: Queue Sizes - Product 0: 16, Product 1: 9
# Time 13417: Queue Sizes - Product 0: 16, Product 1: 10
# Time 13447: Queue Sizes - Product 0: 16, Product 1: 11
# Time 13477: Queue Sizes - Product 0: 16, Product 1: 12
# Time 13491: Queue Sizes - Product 0: 16, Product 1: 8
# Time 13687: Queue Sizes - Product 0: 16, Product 1: 9
# Time 13717: Queue Sizes - Product 0: 16, Product 1: 10
# Time 13747: Queue Sizes - Product 0: 16, Product 1: 11
# Time 13777: Queue Sizes - Product 0: 16, Product 1: 12
# Time 13791: Queue Sizes - Product 0: 12, Product 1: 12
# Time 14031: Queue Sizes - Product 0: 8, Product 1: 12
# Time 14271: Queue Sizes - Product 0: 4, Product 1: 12
# Time 14511: Queue Sizes - Product 0: 4, Product 1: 8
# Time 14811: Queue Sizes - Product 0: 4, Product 1: 4
# Time 15111: Queue Sizes - Product 0: 4, Product 1: 0
# Time 15411: Queue Sizes - Product 0: 0, Product 1: 0
# queue3 Event Log:
# Time 618: Queue Sizes - Product 0: 1, Product 1: 0
# Time 618: Queue Sizes - Product 0: 2, Product 1: 0
# Time 618: Queue Sizes - Product 0: 3, Product 1: 0
# Time 618: Queue Sizes - Product 0: 4, Product 1: 0
# Time 618: Queue Sizes - Product 0: 3, Product 1: 0
# Time 858: Queue Sizes - Product 0: 4, Product 1: 0
# Time 858: Queue Sizes - Product 0: 5, Product 1: 0
# Time 858: Queue Sizes - Product 0: 6, Product 1: 0
# Time 858: Queue Sizes - Product 0: 7, Product 1: 0
# Time 1458: Queue Sizes - Product 0: 7, Product 1: 1
# Time 1458: Queue Sizes - Product 0: 7, Product 1: 2
# Time 1458: Queue Sizes - Product 0: 7, Product 1: 3
# Time 1458: Queue Sizes - Product 0: 7, Product 1: 4
# Time 1458: Queue Sizes - Product 0: 7, Product 1: 3
# ...
# At machine Machine 3: Product 1 processed from 5675 to 5720
# At machine Machine 3: Product 0 processed from 5720 to 5765
# At machine Machine 3: Product 1 processed from 5765 to 5810
# At machine Machine 3: Product 0 processed from 5810 to 5855
# At machine Machine 3: Product 1 processed from 6738 to 6783
# At machine Machine 3: Product 0 processed from 6783 to 6828
# At machine Machine 3: Product 1 processed from 6828 to 6873
# At machine Machine 3: Product 0 processed from 6873 to 6918
# At machine Machine 3: Product 1 processed from 6918 to 6963
# At machine Machine 3: Product 0 processed from 6963 to 7008
# At machine Machine 3: Product 1 processed from 7008 to 7053
# At machine Machine 3: Product 0 processed from 7053 to 7098
# At machine Machine 3: Product 1 processed from 7098 to 7143
# At machine Machine 3: Product 0 processed from 7143 to 7188
# At machine Machine 3: Product 1 processed from 7188 to 7233
# At machine Machine 3: Product 0 processed from 7233 to 7278
# At machine Machine 3: Product 1 processed from 7278 to 7323
# At machine Machine 3: Product 0 processed from 7323 to 7368
# At machine Machine 3: Product 1 processed from 7368 to 7413
# At machine Machine 3: Product 0 processed from 7413 to 7458
# At machine Machine 3: Product 1 processed from 7594 to 7639
# At machine Machine 3: Product 0 processed from 7639 to 7684
# At machine Machine 3: Product 1 processed from 7684 to 7729
# At machine Machine 3: Product 0 processed from 7729 to 7774
# At machine Machine 3: Product 1 processed from 7774 to 7819
# At machine Machine 3: Product 0 processed from 7819 to 7864
# At machine Machine 3: Product 1 processed from 7864 to 7909
# At machine Machine 3: Product 1 processed from 7909 to 7939
# At machine Machine 3: Product 0 processed from 8150 to 8195
# At machine Machine 3: Product 0 processed from 8195 to 8225
# At machine Machine 3: Product 1 processed from 8225 to 8270
# At machine Machine 3: Product 0 processed from 8270 to 8315
# At machine Machine 3: Product 1 processed from 8315 to 8360
# At machine Machine 3: Product 0 processed from 8360 to 8405
# At machine Machine 3: Product 1 processed from 8405 to 8450
# At machine Machine 3: Product 0 processed from 8450 to 8495
# At machine Machine 3: Product 1 processed from 9378 to 9423
# At machine Machine 3: Product 0 processed from 9423 to 9468
# At machine Machine 3: Product 1 processed from 9468 to 9513
# At machine Machine 3: Product 0 processed from 9513 to 9558
# At machine Machine 3: Product 1 processed from 9558 to 9603
# At machine Machine 3: Product 0 processed from 9603 to 9648
# At machine Machine 3: Product 1 processed from 9648 to 9693
# At machine Machine 3: Product 0 processed from 9693 to 9738
# At machine Machine 3: Product 1 processed from 9738 to 9783
# At machine Machine 3: Product 0 processed from 9783 to 9828
# At machine Machine 3: Product 1 processed from 9828 to 9873
# At machine Machine 3: Product 0 processed from 9873 to 9918
# At machine Machine 3: Product 1 processed from 9918 to 9963
# At machine Machine 3: Product 0 processed from 9963 to 10008
# At machine Machine 3: Product 1 processed from 10008 to 10053
# At machine Machine 3: Product 0 processed from 10053 to 10098
# At machine Machine 3: Product 1 processed from 10234 to 10279
# At machine Machine 3: Product 0 processed from 10279 to 10324
# At machine Machine 3: Product 1 processed from 10324 to 10369
# At machine Machine 3: Product 0 processed from 10369 to 10414
# At machine Machine 3: Product 1 processed from 10414 to 10459
# At machine Machine 3: Product 0 processed from 10459 to 10504
# At machine Machine 3: Product 1 processed from 10504 to 10549
# At machine Machine 3: Product 1 processed from 10549 to 10579
# At machine Machine 3: Product 0 processed from 10790 to 10835
# At machine Machine 3: Product 0 processed from 10835 to 10865
# At machine Machine 3: Product 1 processed from 10865 to 10910
# At machine Machine 3: Product 0 processed from 10910 to 10955
# At machine Machine 3: Product 1 processed from 10955 to 11000
# At machine Machine 3: Product 0 processed from 11000 to 11045
# At machine Machine 3: Product 1 processed from 11045 to 11090
# At machine Machine 3: Product 0 processed from 11090 to 11135
# At machine Machine 3: Product 1 processed from 11571 to 11616
# At machine Machine 3: Product 0 processed from 11616 to 11661
# At machine Machine 3: Product 1 processed from 11661 to 11706
# At machine Machine 3: Product 0 processed from 11706 to 11751
# At machine Machine 3: Product 1 processed from 11751 to 11796
# At machine Machine 3: Product 0 processed from 11796 to 11841
# At machine Machine 3: Product 1 processed from 11841 to 11886
# At machine Machine 3: Product 0 processed from 11886 to 11931
# At machine Machine 3: Product 1 processed from 11931 to 11976
# At machine Machine 3: Product 0 processed from 11976 to 12021
# At machine Machine 3: Product 1 processed from 12021 to 12066
# At machine Machine 3: Product 0 processed from 12066 to 12111
# At machine Machine 3: Product 1 processed from 12111 to 12156
# At machine Machine 3: Product 0 processed from 12156 to 12201
# At machine Machine 3: Product 1 processed from 12201 to 12246
# At machine Machine 3: Product 1 processed from 12246 to 12276
# At machine Machine 3: Product 0 processed from 12411 to 12456
# At machine Machine 3: Product 0 processed from 12456 to 12486
# At machine Machine 3: Product 1 processed from 12486 to 12531
# At machine Machine 3: Product 0 processed from 12531 to 12576
# At machine Machine 3: Product 1 processed from 12576 to 12621
# At machine Machine 3: Product 0 processed from 12621 to 12666
# At machine Machine 3: Product 1 processed from 12666 to 12711
# At machine Machine 3: Product 0 processed from 12711 to 12756
# At machine Machine 3: Product 1 processed from 13191 to 13236
# At machine Machine 3: Product 0 processed from 13236 to 13281
# At machine Machine 3: Product 1 processed from 13281 to 13326
# At machine Machine 3: Product 0 processed from 13326 to 13371
# At machine Machine 3: Product 1 processed from 13371 to 13416
# At machine Machine 3: Product 0 processed from 13416 to 13461
# At machine Machine 3: Product 1 processed from 13461 to 13506
# At machine Machine 3: Product 0 processed from 13506 to 13551
# At machine Machine 3: Product 1 processed from 13551 to 13596
# At machine Machine 3: Product 0 processed from 13596 to 13641
# At machine Machine 3: Product 1 processed from 13641 to 13686
# At machine Machine 3: Product 0 processed from 13686 to 13731
# At machine Machine 3: Product 1 processed from 13731 to 13776
# At machine Machine 3: Product 0 processed from 13776 to 13821
# At machine Machine 3: Product 1 processed from 13821 to 13866
# At machine Machine 3: Product 1 processed from 13866 to 13896
# At machine Machine 3: Product 0 processed from 14031 to 14076
# At machine Machine 3: Product 0 processed from 14076 to 14106
# At machine Machine 3: Product 1 processed from 14106 to 14151
# At machine Machine 3: Product 0 processed from 14151 to 14196
# At machine Machine 3: Product 1 processed from 14196 to 14241
# At machine Machine 3: Product 0 processed from 14241 to 14286
# At machine Machine 3: Product 1 processed from 14286 to 14331
# At machine Machine 3: Product 0 processed from 14331 to 14376
# At machine Machine 3: Product 1 processed from 14811 to 14856
# At machine Machine 3: Product 0 processed from 14856 to 14901
# At machine Machine 3: Product 1 processed from 14901 to 14946
# At machine Machine 3: Product 0 processed from 14946 to 14991
# At machine Machine 3: Product 1 processed from 14991 to 15036
# At machine Machine 3: Product 0 processed from 15036 to 15081
# At machine Machine 3: Product 1 processed from 15081 to 15126
# At machine Machine 3: Product 0 processed from 15126 to 15171
# At machine Machine 3: Product 1 processed from 15171 to 15216
# At machine Machine 3: Product 0 processed from 15216 to 15261
# At machine Machine 3: Product 1 processed from 15261 to 15306
# At machine Machine 3: Product 0 processed from 15306 to 15351
# At machine Machine 3: Product 1 processed from 15351 to 15396
# At machine Machine 3: Product 0 processed from 15396 to 15441
# At machine Machine 3: Product 1 processed from 15441 to 15486
# At machine Machine 3: Product 1 processed from 15486 to 15516
# At machine Machine 3: Product 0 processed from 15651 to 15696
# At machine Machine 3: Product 0 processed from 15696 to 15726
# At machine Machine 3: Product 1 processed from 15726 to 15771
# At machine Machine 3: Product 0 processed from 15771 to 15816
# At machine Machine 3: Product 1 processed from 15816 to 15861
# At machine Machine 3: Product 0 processed from 15861 to 15906
# At machine Machine 3: Product 1 processed from 15906 to 15951
# Demand Met Log:
# Time 663: Demand for Product 0 met
# Time 1503: Demand for Product 1 met
# Time 1548: Demand for Product 0 met
# Time 1593: Demand for Product 1 met
# Time 1638: Demand for Product 0 met
# Time 1683: Demand for Product 1 met
# Time 1728: Demand for Product 0 met
# Time 1773: Demand for Product 1 met
# Time 1818: Demand for Product 0 met
# Time 1863: Demand for Product 1 met
# Time 1908: Demand for Product 0 met
# Time 1953: Demand for Product 1 met
# Time 1998: Demand for Product 0 met
# Time 2043: Demand for Product 1 met
# Time 2088: Demand for Product 0 met
# Time 2133: Demand for Product 1 met
# Time 2178: Demand for Product 0 met
# Time 2359: Demand for Product 1 met
# Time 2404: Demand for Product 0 met
# Time 2449: Demand for Product 1 met
# Time 2494: Demand for Product 0 met
# Time 2539: Demand for Product 1 met
# Time 2584: Demand for Product 0 met
# Time 2629: Demand for Product 1 met
# Time 2659: Demand for Product 1 met
# Time 2915: Demand for Product 0 met
# Time 2945: Demand for Product 0 met
# Time 2990: Demand for Product 1 met
# Time 3035: Demand for Product 0 met
# Time 3080: Demand for Product 1 met
# Time 3125: Demand for Product 0 met
# Time 3170: Demand for Product 1 met
# Time 3215: Demand for Product 0 met
# Time 4143: Demand for Product 1 met
# Time 4188: Demand for Product 0 met
# Time 4233: Demand for Product 1 met
# Time 4278: Demand for Product 0 met
# Time 4323: Demand for Product 1 met
# Time 4368: Demand for Product 0 met
# Time 4413: Demand for Product 1 met
# Time 4458: Demand for Product 0 met
# Time 4503: Demand for Product 1 met
# Time 4548: Demand for Product 0 met
# Time 4593: Demand for Product 1 met
# Time 4638: Demand for Product 0 met
# Time 4683: Demand for Product 1 met
# Time 4728: Demand for Product 0 met
# Time 4773: Demand for Product 1 met
# Time 4818: Demand for Product 0 met
# Time 4999: Demand for Product 1 met
# Time 5044: Demand for Product 0 met
# Time 5089: Demand for Product 1 met
# Time 5134: Demand for Product 0 met
# Time 5179: Demand for Product 1 met
# Time 5224: Demand for Product 0 met
# Time 5269: Demand for Product 1 met
# Time 5299: Demand for Product 1 met
# Time 5555: Demand for Product 0 met
# Time 5585: Demand for Product 0 met
# Time 5630: Demand for Product 1 met
# Time 5675: Demand for Product 0 met
# Time 5720: Demand for Product 1 met
# Time 5765: Demand for Product 0 met
# Time 5810: Demand for Product 1 met
# Time 5855: Demand for Product 0 met
# Time 6783: Demand for Product 1 met
# Time 6828: Demand for Product 0 met
# Time 6873: Demand for Product 1 met
# Time 6918: Demand for Product 0 met
# Time 6963: Demand for Product 1 met
# Time 7008: Demand for Product 0 met
# Time 7053: Demand for Product 1 met
# Time 7098: Demand for Product 0 met
# Time 7143: Demand for Product 1 met
# Time 7188: Demand for Product 0 met
# Time 7233: Demand for Product 1 met
# Time 7278: Demand for Product 0 met
# Time 7323: Demand for Product 1 met
# Time 7368: Demand for Product 0 met
# Time 7413: Demand for Product 1 met
# Time 7458: Demand for Product 0 met
# Time 7639: Demand for Product 1 met
# Time 7684: Demand for Product 0 met
# Time 7729: Demand for Product 1 met
# Time 7774: Demand for Product 0 met
# Time 7819: Demand for Product 1 met
# Time 7864: Demand for Product 0 met
# Time 7909: Demand for Product 1 met
# Time 7939: Demand for Product 1 met
# Time 8195: Demand for Product 0 met
# Time 8225: Demand for Product 0 met
# Time 8270: Demand for Product 1 met
# Time 8315: Demand for Product 0 met
# Time 8360: Demand for Product 1 met
# Time 8405: Demand for Product 0 met
# Time 8450: Demand for Product 1 met
# Time 8495: Demand for Product 0 met
# Time 9423: Demand for Product 1 met
# Time 9468: Demand for Product 0 met
# Time 9513: Demand for Product 1 met
# Time 9558: Demand for Product 0 met
# Time 9603: Demand for Product 1 met
# Time 9648: Demand for Product 0 met
# Time 9693: Demand for Product 1 met
# Time 9738: Demand for Product 0 met
# Time 9783: Demand for Product 1 met
# Time 9828: Demand for Product 0 met
# Time 9873: Demand for Product 1 met
# Time 9918: Demand for Product 0 met
# Time 9963: Demand for Product 1 met
# Time 10008: Demand for Product 0 met
# Time 10053: Demand for Product 1 met
# Time 10098: Demand for Product 0 met
# Time 10279: Demand for Product 1 met
# Time 10324: Demand for Product 0 met
# Time 10369: Demand for Product 1 met
# Time 10414: Demand for Product 0 met
# Time 10459: Demand for Product 1 met
# Time 10504: Demand for Product 0 met
# Time 10549: Demand for Product 1 met
# Time 10579: Demand for Product 1 met
# Time 10835: Demand for Product 0 met
# Time 10865: Demand for Product 0 met
# Time 10910: Demand for Product 1 met
# Time 10955: Demand for Product 0 met
# Time 11000: Demand for Product 1 met
# Time 11045: Demand for Product 0 met
# Time 11090: Demand for Product 1 met
# Time 11135: Demand for Product 0 met
# Time 11616: Demand for Product 1 met
# Time 11661: Demand for Product 0 met
# Time 11706: Demand for Product 1 met
# Time 11751: Demand for Product 0 met
# Time 11796: Demand for Product 1 met
# Time 11841: Demand for Product 0 met
# Time 11886: Demand for Product 1 met
# Time 11931: Demand for Product 0 met
# Time 11976: Demand for Product 1 met
# Time 12021: Demand for Product 0 met
# Time 12066: Demand for Product 1 met
# Time 12111: Demand for Product 0 met
# Time 12156: Demand for Product 1 met
# Time 12201: Demand for Product 0 met
# Time 12246: Demand for Product 1 met
# Time 12276: Demand for Product 1 met
# Time 12456: Demand for Product 0 met
# Time 12486: Demand for Product 0 met
# Time 12531: Demand for Product 1 met
# Time 12576: Demand for Product 0 met
# Time 12621: Demand for Product 1 met
# Time 12666: Demand for Product 0 met
# Time 12711: Demand for Product 1 met
# Time 12756: Demand for Product 0 met
# Time 13236: Demand for Product 1 met
# Time 13281: Demand for Product 0 met
# Time 13326: Demand for Product 1 met
# Time 13371: Demand for Product 0 met
# Time 13416: Demand for Product 1 met
# Time 13461: Demand for Product 0 met
# Time 13506: Demand for Product 1 met
# Time 13551: Demand for Product 0 met
# Time 13596: Demand for Product 1 met
# Time 13641: Demand for Product 0 met
# Time 13686: Demand for Product 1 met
# Time 13731: Demand for Product 0 met
# Time 13776: Demand for Product 1 met
# Time 13821: Demand for Product 0 met
# Time 13866: Demand for Product 1 met
# Time 13896: Demand for Product 1 met
# Time 14076: Demand for Product 0 met
# Time 14106: Demand for Product 0 met
# Time 14151: Demand for Product 1 met
# Time 14196: Demand for Product 0 met
# Time 14241: Demand for Product 1 met
# Time 14286: Demand for Product 0 met
# Time 14331: Demand for Product 1 met
# Time 14376: Demand for Product 0 met
# Time 14856: Demand for Product 1 met
# Time 14901: Demand for Product 0 met
# Time 14946: Demand for Product 1 met
# Time 14991: Demand for Product 0 met
# Time 15036: Demand for Product 1 met
# Time 15081: Demand for Product 0 met
# Time 15126: Demand for Product 1 met
# Time 15171: Demand for Product 0 met
# Time 15216: Demand for Product 1 met
# Time 15261: Demand for Product 0 met
# Time 15306: Demand for Product 1 met
# Time 15351: Demand for Product 0 met
# Time 15396: Demand for Product 1 met
# Time 15441: Demand for Product 0 met
# Time 15486: Demand for Product 1 met
# Time 15516: Demand for Product 1 met
# Time 15696: Demand for Product 0 met
# Time 15726: Demand for Product 0 met
# Time 15771: Demand for Product 1 met
# Time 15816: Demand for Product 0 met
# Time 15861: Demand for Product 1 met
# Time 15906: Demand for Product 0 met
# Time 15951: Demand for Product 1 met
# {'queue0': [[], []], 'queue1': [[], []], 'queue2': [[], []], 'queue3': [[], []], 'queue_fin': [[], []], 'demand': [[], []]}

# %%
import matplotlib.pyplot as plt

# Plotting queue sizes including 'queue_fin'
fig, axes = plt.subplots(6, 1, figsize=(10, 15), sharex=True)  # Share x-axis across all subplots and increase to 5 subplots
fig.suptitle('Queue Sizes Over Time', fontsize=16)

queue_names = ['queue0', 'queue1', 'queue2', 'queue3', 'queue_fin','demand']
colors = ['blue', 'green']
labels = ['Product 0', 'Product 1']

# Determine the global minimum and maximum time across all queues for consistent x-axis
all_times = [log[1] for queue in queue_names for log in production_line.logs[queue]]
global_min_time = min(all_times)
global_max_time = max(all_times)

for i, ax in enumerate(axes):
    for product_type in range(2):
        times = [log[1] for log in production_line.logs[queue_names[i]]]
        sizes = [log[0][product_type] for log in production_line.logs[queue_names[i]]]
        ax.plot(times, sizes, color=colors[product_type], label=f'Product {product_type}')
    ax.set_title(f'{queue_names[i]}')
    ax.set_xlim([global_min_time, global_max_time])  # Set consistent x-axis range
    ax.set_xlabel('Time')
    ax.set_ylabel('Number of Units')
    ax.legend()

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
# Setup for Gantt chart plotting using matplotlib
fig, axs = plt.subplots(4, 1, figsize=(14, 10), sharex=True)
fig.suptitle('Gantt Chart for Production Line')

# Color coding for products and setups
colors = {0: 'skyblue', 1: 'lightgreen', 'setup': 'grey'}

machines = ['machine0', 'machine1', 'machine2', 'machine3']
machine_names = ['Batch Machine 0', 'Machine 1', 'Batch Machine 2', 'Machine 3']

# Plot each machine's activities
for ax, machine_name, name in zip(axs, machines, machine_names):
    machine = getattr(production_line, machine_name)
    y = 0
    for log in machine.event_log:
        if len(log) == 4:  # BatchProcessingMachine or Machine with setup
            product, current_time, start_time, finish_time = log
            # Calculate setup time and process time
            setup_time = start_time - current_time
            process_time = finish_time - start_time
            # Plot setup time if exists
            if setup_time > 0:
                ax.broken_barh([(current_time, setup_time)], (y, 0.8), facecolors='grey', edgecolor='black', linewidth=0.5)
            # Plot process time
            ax.broken_barh([(start_time, process_time)], (y, 0.8), facecolors=colors[product], edgecolor='black', linewidth=0.5)
        else:  # For single product processing without batch
            product, current_time, finish_time, _ = log
            process_time = finish_time - current_time
            ax.broken_barh([(current_time, process_time)], (y, 0.8), facecolors=colors[product], edgecolor='black', linewidth=0.5)
    ax.set_ylim(-0.5, 1.5)
    ax.set_yticks([0])
    ax.set_yticklabels([name])
    ax.grid(True)

# Create legend for product colors
patches = [mpatches.Patch(color=colors[key], label=f'Product {key}' if key != 'setup' else 'Setup Time') for key in colors]
fig.legend(handles=patches, loc='upper right')

plt.xlabel('Time')
plt.tight_layout(rect=[0, 0, 1, 0.95])  # Adjust layout to make room for title
plt.show()

# %%
#Next steps
# 1) Introduce a demand forecast into the state space and reward it for meeting future excess demand
# 2) See if it can switch demand patterns quickly 
# 3) Q-learning implementaion to achive the same result
# 4) Write a LP program of this

# %%
queues = {'queue0': [[], []], 'queue1': [[], []], 'queue2': [[], []], 'queue3': [[], []],'queue_fin': [[], []],'demand': [[10,12], [23,45,54]]}
print(len(queues['demand'][0])+len(queues['demand'][1]))
for product_type in range(2):
    print(product_type)
